# %% [markdown]
# # 4.- Running the MCMC

# %% [markdown]
# Nauyaca uses a Parallel-Tempering sampling algorithm ($\texttt{ptemcee}$; Vousden et al., 2015) to explore the parameter space at different walker temperatures. This method allows the walkers do not get stuck in local high probability regions due to the exchange between high and low temperature walkers. The posteriors are drawn from the walkers at temperature 0.
#
# Let's import Nauyaca and other useful libraries for analisys

# %%
import nauyaca_local as nau

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# As before, let's load the Planetary System object

# %%
PS = nau.PlanetarySystem.load_json('SystemX.json')
print(PS)
# Out:
# --> Parameter -ecc- of planet -Planet-b- set to lower physical limit: 1e-06
# --> Parameter -ecc- of planet -Planet-c- set to lower physical limit: 1e-06
#
#  =========== Planetary System Summary ===========
# --> Parameter -ecc- of planet -Planet-b- set to lower physical limit: 1e-06
# --> Parameter -ecc- of planet -Planet-c- set to lower physical limit: 1e-06
#
# System: SystemX
# Mstar: 0.9132 Msun |  Rstar: 0.8632 Rsun
# Number of planets: 2
# Planet information:
# ------
# Planet1: Planet-b
#   Boundaries:
#     mass: (1, 20.0)  [M_earth]
#     period: (5.35, 5.36)  [d]
#     ecc: (1e-06, 0.2)
#     inclination: (85, 95)  [deg]
#     argument: (0.0, 360)  [deg]
#     mean_anomaly: (0.0, 360)  [deg]
#     ascending_node: (88.36, 88.36)  [deg]
#   TTVs: True
# ------
# Planet2: Planet-c
#   Boundaries:
#     mass: (1, 100)  [M_earth]
#     period: (11.83, 11.84)  [d]
#     ecc: (1e-06, 0.2)
#     inclination: (85, 95)  [deg]
#     argument: (0.0, 360)  [deg]
#     mean_anomaly: (0.0, 360)  [deg]
#     ascending_node: (0.0, 180.0)  [deg]
#   TTVs: True
#
# Simulation attributes:
# Reference epoch of the solutions (T0JD): 0.0 [JD]
# Total time of TTVs data (Ftime): 200 [days]
# Timestep of the simulations (dt): 0.15 [days]

# %% [markdown]
# ## 4.1 Initializing walkers

# %% [markdown]
# Before running the MCMC, we need to decide which the initial prior will be. The prior is all that information that you can provide as initial guess for the exploration. We refer to $walker$ as those data that represent a point in the parameter space. Initial walkers constitute a group of data points in the space of $\mathrm{N_{dim}}$ dimensions that are initially supplied to the MCMC.
#
# For our current problem, the number of dimensions to explore is:

# %%
PS.ndim
# Out:
# 13

# %% [markdown]
# Thus, each walker will be an array of $\mathrm{N_{dim}}$ dimensions.
#
# Let's define the main parameters to run the MCMC. We will run the MCMC along 2000 iterations saving each 20 steps.

# %%
Ntemps = 8        # Number of temperatures
Nwalkers =150    # Number of walkers per temperature
Tmax = 50        # Maximum temperature. If None, then Parallel-Tempering chose an appropiate maximum temperature

Itmax = 2500      # Maximum number of steps
Intra_steps = 50 # Number of steps to save the chains

# %% [markdown]
# Nauyaca provides 4 forms of easily initialize walkers through the 'initial_walkers' function in the 'utils' module. Additionally, you can provide your own walkers' initial position as long as they are inside the valid boundaries.
#
# **IMPORTANT:** Initial walkers should be provided in an array of shape (Ntemps, Nwalkers, Ndim)
#
# Let's generate these 4 ways of initial walkers and plot them using the 'Plots' module

# %%
nauplot = nau.Plots_c(PS)

# %% [markdown]
# ###  4.1.1 Uniform distribution
#
# For all the planetary parameters, initialize walkers from an uniform distribution
# along the established boundaries for each planet. Using this option is unnecesary to run optimizers previously. We call it from the 'utils' module

# %%
walkers_uniform = nau.utils.init_walkers(PS, 
                                distribution="Uniform", 
                                ntemps=Ntemps, 
                                nwalkers=Nwalkers)
# Out:
# --> Selected distribution: Uniform

# %%
# Show the initial uniform population 
nauplot.plot_hist(chains=walkers_uniform)

# %% [markdown]
# **Note:** If there are constant values in the planet's boundaries, then that parameter will be skipped and values will not appear in the initial walkers. Here, panels without information corresponds to planet parameters that remain as fixed. In this case, the constant parameter(s) and its value correspond to:

# %%
for constant in PS.constant_params.keys():
    param = PS.params_names_all.split()[constant]
    value = PS.constant_params[constant]
    print(f"{param}: {value}")
# Out:
# ascending_node1: 88.36

# %% [markdown]
# ### 4.1.2 Gaussian distribution
#
# In order to use this function, you need to provide the information comming from the optimizers saved in the **_cube.opt** file. Let's load the results from the optimizers that we got in the previous tutorial:

# %%
RESULTS_opt = np.genfromtxt(f'{PS.system_name}_cube.opt')

# %% [markdown]
# Provide the results directly from the optimizers (through opt_data argument) and construct a gaussian with the mean and standard deviation of the solutions along each dimension. In opt_data, pass RESULTS_opt (from optimizers or from file). Argument 'fbest' selects a fraction of the best solutions and discard the rest. For example, fbest=.1 takes the best 10% of the solutions, according to their $\chi^2$

# %%
walkers_gaussian = nau.utils.init_walkers(PS, 
                                   distribution = "Gaussian",
                                   opt_data = RESULTS_opt, 
                                   fbest = 0.5,
                                   ntemps = Ntemps, 
                                   nwalkers = Nwalkers)
# Out:
# --> Selected distribution: Gaussian
#     20 of 40 solutions taken

# %% [markdown]
# **Note:** the walkers_gaussian variable contains the walkers information normalized between 0 and 1. Try printing that variable to corroborate. That's a map between the physical boundaries and the hypercube with which Nauyaca internally works. However, we can visualize the physical results when passing that variable to the Plots module:

# %%
nauplot.plot_hist(chains=walkers_gaussian)

# %% [markdown]
# That will be the initial distribution of walkers

# %% [markdown]
# ### 4.1.3 Picked distribution
#
# Provide the results of the optimizers (through opt_data argument) to construct a discrete distribution by randomly selecting values around the optimizer solutions. In opt_data, pass RESULTS_opt (from optimizers) or results_opt (from file) fbest selects a fraction of the best solutions and discard the rest. For example, .5 takes the 50% of the solutions with the best $\chi^2$

# %%
walkers_picked = nau.utils.init_walkers(PS, 
                                 distribution = "Picked", 
                                 opt_data = RESULTS_opt, 
                                 fbest = .5,
                                 ntemps = Ntemps, 
                                 nwalkers = Nwalkers)
# Out:
# --> Selected distribution: Picked
#     20 of 40 solutions taken

# %%
nauplot.plot_hist(chains=walkers_picked)

# %% [markdown]
# ### 4.1.4 Ladder distribution

# %% [markdown]
# Provide the results of the optimizers (through opt_data argument).
# This method separate the solutions from optimizers in chunks corresponding to the number of temperatures. Then, each temperature draw their own walkers by following the rule:
# First temperature draw walkers from the first chunk (which includes the solution with the topmost solution). Second temperature draw walkers from first and second chunks. Third temperature draw walkers from first, second and third chunks. The same rule follows for the rest of the temperatures.
#
# In opt_data, pass RESULTS_opt (from optimizers) or results_opt (from file). fbest selects a fraction of the best solutions and discard the rest. For example, .5 takes the 50% of the solutions with the best $\chi^2$

# %%
walkers_ladder = nau.utils.init_walkers(PS, 
                                distribution = "Ladder",
                                opt_data = RESULTS_opt, 
                                fbest = 0.2,
                                ntemps = Ntemps, 
                                nwalkers = Nwalkers)
# Out:
# --> Selected distribution: Ladder
#     8 of 40 solutions taken

# %%
nauplot.plot_hist(chains=walkers_ladder)

# %% [markdown]
# ## 4.2 Running the MCMC

# %% [markdown]
# Let's run the MCMC using the initial walkers from the Ladder distribution generated above. Also provide the necessary keyword arguments. Many of them were defined at the beggining of section 3.1

# %%
nauMCMC = nau.MCMC(
            PS,                             # Planetary System object
            p0 = walkers_ladder,            # Initial population of walkers 
            tmax = Tmax,                    # Maximum temperature
            itmax = 50, #Itmax,                  # Maximum nomber of iterations (steps)
            intra_steps = 5, #Intra_steps,      # Save data each this number of steps
            cores = 8,                      # Number of cores to run in parallel
            suffix='')

# %%
RESULTS_mcmc = nauMCMC.run()
# Out:
#  =========== PARALLEL-TEMPERING MCMC ===========
#
# --> Starting date:  2021-02-05 20:47
# --> Reference epoch of the solutions:  0.0  [JD]
# --> Results will be saved at:  ./SystemX.hdf5
#
# --> MCMC parameters:
#       -ntemps: 8
#       -nwalkers: 150
#       -itmax: 50
#       -intra_steps: 5
#
# --------- Iteration:  5
#  Mean tau: -0.0
#  Accepted swap fraction in Temp 0:  0.295
#  Mean acceptance fraction Temp 0:  0.265
#  Mean likelihood:  -4962083.282228
#  Maximum likelihood:  (0, 86) -5666.505629
#  Current mean likelihood dispersion:  0.0
#  Saving time: 0.01280 sec
#  Elapsed time:  0.0638 min
# --------- Iteration:  10
#  Mean tau: -0.0
#  Accepted swap fraction in Temp 0:  0.171
#  Mean acceptance fraction Temp 0:  0.241
#  Mean likelihood:  -1583527.600319
#  Maximum likelihood:  (0, 86) -5666.505629
#  Current mean likelihood dispersion:  1689277.840955
#  Saving time: 0.01225 sec
#  Elapsed time:  0.1131 min
# --------- Iteration:  15
#  Mean tau: -0.0
#  Accepted swap fraction in Temp 0:  0.127
#  Mean acceptance fraction Temp 0:  0.219
#  Mean likelihood:  -678190.142077
#  Maximum likelihood:  (0, 93) -3769.046711
#  Current mean likelihood dispersion:  452668.729121
#  Saving time: 0.01253 sec
#  Elapsed time:  0.1637 min
# --------- Iteration:  20
#  Mean tau: -0.0
#  Accepted swap fraction in Temp 0:  0.1
#  Mean acceptance fraction Temp 0:  0.2
#  Mean likelihood:  -339418.841853
#  Maximum likelihood:  (0, 149) -2323.391437
#  Current mean likelihood dispersion:  525167.540467
#  Saving time: 0.01306 sec
#  Elapsed time:  0.215 min
# --------- Iteration:  25
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.085
#  Mean acceptance fraction Temp 0:  0.189
#  Mean likelihood:  -162283.503402
#  Maximum likelihood:  (0, 149) -2323.391437
#  Current mean likelihood dispersion:  214035.973564
#  Saving time: 0.01395 sec
#  Elapsed time:  0.2693 min
# --------- Iteration:  30
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.072
#  Mean acceptance fraction Temp 0:  0.179
#  Mean likelihood:  -99039.03849
#  Maximum likelihood:  (0, 39) -228.065858
#  Current mean likelihood dispersion:  224930.669153
#  Saving time: 0.01195 sec
#  Elapsed time:  0.3218 min
# --------- Iteration:  35
#  Mean tau: -0.0
#  Accepted swap fraction in Temp 0:  0.064
#  Mean acceptance fraction Temp 0:  0.17
#  Mean likelihood:  -57025.886749
#  Maximum likelihood:  (0, 39) -228.065858
#  Current mean likelihood dispersion:  107746.604416
#  Saving time: 0.01140 sec
#  Elapsed time:  0.3748 min
# --------- Iteration:  40
#  Mean tau: -0.0
#  Accepted swap fraction in Temp 0:  0.058
#  Mean acceptance fraction Temp 0:  0.164
#  Mean likelihood:  -34849.687304
#  Maximum likelihood:  (0, 99) -179.06385
#  Current mean likelihood dispersion:  109428.16753
#  Saving time: 0.01263 sec
#  Elapsed time:  0.4291 min
# --------- Iteration:  45
#  Mean tau: -0.0
#  Accepted swap fraction in Temp 0:  0.055
#  Mean acceptance fraction Temp 0:  0.159
#  Mean likelihood:  -22937.920513
#  Maximum likelihood:  (0, 99) -179.06385
#  Current mean likelihood dispersion:  50678.602386
#  Saving time: 0.03916 sec
#  Elapsed time:  0.4945 min
# --------- Iteration:  50
#  Mean tau: -0.0
#  Accepted swap fraction in Temp 0:  0.052
#  Mean acceptance fraction Temp 0:  0.153
#  Mean likelihood:  -13509.11454
#  Maximum likelihood:  (0, 99) -179.06385
#  Current mean likelihood dispersion:  51665.38629
#  Saving time: 0.01518 sec
#  Elapsed time:  0.5584 min
#
# --> Maximum number of iterations reached in MCMC
# --> Best solutions from the ./SystemX.hdf5 will be written at: ./SystemX.best
# --> Reference epoch of the solutions:  0.0  [JD]
# --> Iterations performed:  50
# --> Elapsed time in MCMC: 0.5585 minutes

# %% [markdown]
# After the mcmc run ends, it returns the sampler object from $\texttt{ptemcee}$, with the following attributes:

# %%
RESULTS_mcmc.__dict__.keys()
# Out:
# dict_keys(['_random', '_likeprior', 'a', 'nwalkers', 'dim', 'adaptation_time', 'adaptation_lag', '_betas', 'pool', '_chain', '_logposterior', '_loglikelihood', '_beta_history', '_time', '_p0', '_logposterior0', '_loglikelihood0', 'nswap', 'nswap_accepted', 'nprop', 'nprop_accepted'])

# %% [markdown]
# We will deeply inspect these attributes in the following tutorial.

# %% [markdown]
# Okey, at this point there are two files that have been saved with the following extesions:
#
# * **.hdf5:** It contains the main results from the MCMC run. It will be useful for posterior analysis. It also can be provided to the Plots module to plot default figures from Nauyaca. This file is portable and is useful to restart an MCMC in other time or in another computer.
#
# * **.best:** It is a file containing the best solution (normalized) of each saved iteration. It correspond to the solution with the 'Maximum likelihood' indicated in the outputs.

# %% [markdown]
# ## 4.3 Results (fast version)

# %% [markdown]
# For the following analysis, let's make a burnin of the first 25% of the chains. Also remember that results are taken from temperature 0.

# %%
burn = 0.25  # Fractional lenght of the initial chains to be discarted
T = 0        # Target temperature

# %% [markdown]
# **MCMC Summary**
#
# An easy way to summarize the current MCMC run is through the mcmc_summary method in utils, passing the name of the .hdf5 file.

# %%
posteriors = nau.utils.mcmc_summary(PS, hdf5_file=f'{PS.system_name}.hdf5', burnin=burn)
# Out:
# --> Planetary System:  SystemX
#     Stellar mass:  0.9132
#     Stellar radius:  0.8632
#     Number of planets:  2
# --> Planets:
#        Planet1: Planet-b
#        Planet2: Planet-c
#
# --------------------------
# --> MCMC parameters
#     Ntemps:  8
#     Nwalkers per temperature:  150
#     Number of iterations:  50
#     Thining:  5
#     Burnin:  0.25
#     Chain shape:  (150, 8, 13)
# --------------------------
#       RESULTS
# --> Results in File:   SystemX.hdf5
# --> Reference epoch of the solutions:  0  [JD]
# --> Best solution in MCMC
#     Logl:  -179.06385
#           mass period ecc inclination argument mean_anomaly ascending_node
# Planet1: 7.39   5.3544   0.12   93.4822   287.7536   27.0835   88.36
# Planet2: 39.8519   11.8333   0.0248   87.903   260.4707   5.5739   100.1877
# --------------------------
# --> MCMC medians and 1-sigma errors
#              mass1      7.32 ^{+0.93}_{-0.2}
#            period1      5.3536 ^{+0.0009}_{-0.0005}
#               ecc1      0.092 ^{+0.028}_{-0.015}
#       inclination1      93.37 ^{+0.12}_{-0.17}
#          argument1      274.74 ^{+13.25}_{-7.56}
#      mean_anomaly1      43.68 ^{+8.85}_{-17.14}
#              mass2      71.36 ^{+16.02}_{-31.54}
#            period2      11.83 ^{+0.0}_{-0.0}
#               ecc2      0.06 ^{+0.01}_{-0.03}
#       inclination2      89.63 ^{+0.62}_{-1.75}
#          argument2      203.43 ^{+60.11}_{-32.23}
#      mean_anomaly2      90.42 ^{+23.77}_{-47.04}
#    ascending_node2      98.46 ^{+0.95}_{-1.82}

# %% [markdown]
# That function prints a summary of the MCMC run where we can see the best solution found along the entire run and the medians of the posteriors with 1-$\sigma$ erros, corresponding to percentiles 16 and 84. Furthermore, it returns a dictionary with the flatten chains of each planetary parameter:

# %%
posteriors
# Out:
# {'mass1': array([8.09239889, 8.08502855, 8.11807862, ..., 7.80017353, 7.75334265,
#         7.7546344 ]),
#  'period1': array([5.35442183, 5.35442877, 5.35443869, ..., 5.35434282, 5.35439228,
#         5.35438871]),
#  'ecc1': array([0.10011057, 0.1001573 , 0.10027148, ..., 0.10276208, 0.103898  ,
#         0.10397688]),
#  'inclination1': array([93.23880838, 93.24839544, 93.23249649, ..., 93.3683973 ,
#         93.37620298, 93.37468697]),
#  'argument1': array([285.68597421, 285.90113973, 286.01987534, ..., 284.76869098,
#         285.86075672, 285.76972977]),
#  'mean_anomaly1': array([30.40008158, 30.13902102, 29.99029725, ..., 31.41908602,
#         30.05281076, 30.16006733]),
#  'mass2': array([46.8360966 , 46.72731002, 46.29732597, ..., 48.04789579,
#         46.30066367, 46.32558402]),
#  'period2': array([11.83362792, 11.83362368, 11.83363249, ..., 11.83357067,
#         11.83356217, 11.8335629 ]),
#  'ecc2': array([0.04613366, 0.04602145, 0.04593031, ..., 0.04772051, 0.04868723,
#         0.04850279]),
#  'inclination2': array([88.5665381 , 88.55745724, 88.55093309, ..., 88.38360905,
#         88.24239663, 88.24690781]),
#  'argument2': array([209.81269625, 209.9098221 , 210.14755239, ..., 208.62274401,
#         207.15150869, 207.35332936]),
#  'mean_anomaly2': array([60.43171393, 60.31862668, 60.06054197, ..., 61.83826196,
#         63.47348352, 63.24385432]),
#  'ascending_node2': array([95.26533948, 95.43682997, 95.36457387, ..., 96.3160173 ,
#         97.58037458, 97.44979408])}

# %% [markdown]
# Now, it's easier to analyze individual parameters.
#
# Let's plot for example, the posterior of the 'mass1' and calculate the mean:

# %%
plt.hist(posteriors['mass1']);

mean = np.mean(posteriors['mass1'])
print(f"Mean: {mean}")
# Out:
# Mean: 7.990892338556163

# %% [markdown]
# All the results saved in the .hdf5 file can be accessed through the method 'get_mcmc_results'. First, let's print which keys are available by passin the hdf5 file and the which_keys set to True

# %%
nau.utils.get_mcmc_results(f'{PS.system_name}.hdf5', which_keys=True)
# Out:
# Available keywords:
#  ['ACC_FRAC0', 'AUTOCORR', 'BESTLOGL', 'BESTSOLS', 'BETAS', 'BOUNDS', 'BOUNDSP', 'CHAINS', 'COL_NAMES', 'CORES', 'INDEX', 'INTRA_STEPS', 'ITER_LAST', 'ITMAX', 'MEANLOGL', 'MSTAR', 'NAME', 'NDIM', 'NPLA', 'NTEMPS', 'NWALKERS', 'REF_EPOCH', 'RSTAR', 'p0']

# %% [markdown]
# These keys correspond to the main features of the MCMC saved in the .hdf5 file.
#
#
# Now, let's use the same function to extract ALL the results in the hdf5 file, which will return in a dictionary:

# %%
results_hdf5 =  nau.utils.get_mcmc_results(f'{PS.system_name}.hdf5')
results_hdf5
# Out:
# {'ACC_FRAC0': array([[0.29466667, 0.394     , 0.526     , 0.58866667, 0.58733333,
#          0.52      , 0.39133333, 0.29866667],
#         [0.17133333, 0.232     , 0.31533333, 0.365     , 0.385     ,
#          0.35733333, 0.26666667, 0.19666667],
#         [0.12711111, 0.16888889, 0.22777778, 0.27155556, 0.29488889,
#          0.27133333, 0.19755556, 0.144     ],
#         [0.1       , 0.13383333, 0.18333333, 0.22016667, 0.2395    ,
#          0.22066667, 0.15883333, 0.114     ],
#         [0.08453333, 0.11146667, 0.15253333, 0.18386667, 0.2024    ,
#          0.18653333, 0.13293333, 0.09653333],
#         [0.07222222, 0.09588889, 0.13388889, 0.16344444, 0.18033333,
#          0.16488889, 0.11533333, 0.08288889],
#         [0.06419048, 0.08580952, 0.12209524, 0.14933333, 0.16304762,
#          0.14838095, 0.10314286, 0.07371429],
#         [0.0575    , 0.07691667, 0.11241667, 0.13766667, 0.14783333,
#          0.135     , 0.09375   , 0.06633333],
#         [0.05466667, 0.07133333, 0.10340741, 0.12740741, 0.13622222,
#          0.12437037, 0.08688889, 0.06148148],
#         [0.05186667, 0.066     , 0.0954    , 0.11893333, 0.12773333,
#          0.11666667, 0.08093333, 0.0568    ]]),
#         [1.        , 0.57533176, 0.32936682, 0.188512  , 0.10747963,
#          0.06106184, 0.03465111, 0.02      ],
#         [1.        , 0.57555907, 0.32967532, 0.18858619, 0.10749453,
#          0.06104562, 0.03462896, 0.02      ],
#         [1.        , 0.57565642, 0.33007209, 0.18859786, 0.10749831,
#          0.06104684, 0.03460944, 0.02      ],
#         [1.        , 0.57552667, 0.33016961, 0.1886619 , 0.10749148,
#          0.06104989, 0.03459649, 0.02      ],
#         [1.        , 0.5753159 , 0.33029627, 0.18874619, 0.10753418,
#          0.0610444 , 0.03457583, 0.02      ]]),
#  'BOUNDS': array([[1.000e+00, 2.000e+01],
#         [5.350e+00, 5.360e+00],
#         [1.000e-06, 2.000e-01],
#         [8.500e+01, 9.500e+01],
#         [0.000e+00, 3.600e+02],
#         [0.000e+00, 3.600e+02],
#         [1.000e+00, 1.000e+02],
#         [1.183e+01, 1.184e+01],
#         [1.000e-06, 2.000e-01],
#         [8.500e+01, 9.500e+01],
#         [0.000e+00, 3.600e+02],
#         [0.000e+00, 3.600e+02],
#         [0.000e+00, 1.800e+02]]),
#  'BOUNDSP': array([[ 1.000e+00,  2.000e+01],
#         [ 5.350e+00,  5.360e+00],
#         [ 1.000e-06,  2.000e-01],
#         [ 8.500e+01,  9.500e+01],
#         [ 0.000e+00,  7.200e+02],
#         [-3.600e+02,  3.600e+02],
#         [ 1.000e+00,  1.000e+02],
#         [ 1.183e+01,  1.184e+01],
#         [ 1.000e-06,  2.000e-01],
#         [ 8.500e+01,  9.500e+01],
#         [ 0.000e+00,  7.200e+02],
#         [-3.600e+02,  3.600e+02],
#         [ 0.000e+00,  1.800e+02]]),
#  'CHAINS': array([[[[3.15897361e-01, 2.97047910e-01, 4.33337235e-01, ...,
#            3.80189431e-01, 6.42555921e-01, 5.47243488e-01],
#           [3.15897361e-01, 2.97047910e-01, 4.33337235e-01, ...,
#            3.80189431e-01, 6.42555921e-01, 5.47243488e-01],
#           [3.12954999e-01, 2.87099455e-01, 4.15312512e-01, ...,
#            3.81259788e-01, 6.20349184e-01, 5.43812596e-01],
#           ...,
#           [3.70574133e-01, 3.14818429e-01, 3.84347268e-01, ...,
#            3.79666101e-01, 5.93239492e-01, 5.39823823e-01],
#           [3.52729783e-01, 3.02497817e-01, 3.91432398e-01, ...,
#            3.80264377e-01, 5.99427461e-01, 5.41576057e-01],
#           [3.52729783e-01, 3.02497817e-01, 3.91432398e-01, ...,
#            3.80264377e-01, 5.99427461e-01, 5.41576057e-01]],
#
#          [[3.31727208e-01, 4.46919800e-01, 6.15737487e-01, ...,
#            3.68978219e-01, 8.75084354e-01, 5.47283885e-01],
#           [3.31727208e-01, 4.46919800e-01, 6.15737487e-01, ...,
#            3.68978219e-01, 8.75084354e-01, 5.47283885e-01],
#           [3.31727208e-01, 4.46919800e-01, 6.15737487e-01, ...,
#            3.68978219e-01, 8.75084354e-01, 5.47283885e-01],
#           ...,
#           [3.31268670e-01, 4.48561855e-01, 6.15718020e-01, ...,
#           [8.17506421e-01, 5.84130779e-01, 9.76005171e-01, ...,
#            8.48548686e-01, 4.15911597e-01, 1.67736700e-01],
#           ...,
#           [8.15439543e-01, 5.64687801e-01, 9.81442219e-01, ...,
#            8.55701119e-01, 4.09560545e-01, 1.62496112e-01],
#           [7.97540708e-01, 5.59248722e-01, 9.63396967e-01, ...,
#            8.58705868e-01, 4.25509950e-01, 1.84565016e-01],
#           [8.12279166e-01, 5.74531464e-01, 9.61822688e-01, ...,
#            8.63970378e-01, 4.35246127e-01, 1.85912845e-01]],
#
#          [[3.19040168e-01, 4.20250622e-01, 5.99814082e-01, ...,
#            3.91490741e-01, 8.54806461e-01, 5.45520718e-01],
#           [3.36233373e-01, 4.43839746e-01, 6.14878085e-01, ...,
#            4.05814748e-01, 8.33046739e-01, 5.52628052e-01],
#           [3.36233373e-01, 4.43839746e-01, 6.14878085e-01, ...,
#            4.05814748e-01, 8.33046739e-01, 5.52628052e-01],
#           ...,
#           [3.32713303e-01, 3.78294134e-01, 5.12627854e-01, ...,
#            3.78059911e-01, 7.30529311e-01, 5.50950676e-01],
#           [3.37358759e-01, 3.93880962e-01, 5.12851843e-01, ...,
#            3.81764725e-01, 6.94030407e-01, 5.44539169e-01],
#           [3.36990290e-01, 3.84469279e-01, 5.04058192e-01, ...,
#            3.78652109e-01, 7.15316456e-01, 5.54353847e-01]]]]),
#  'COL_NAMES': 'mass1  period1  ecc1  inclination1  argument1  mean_anomaly1  mass2  period2  ecc2  inclination2  argument2  mean_anomaly2  ascending_node2',
#  'CORES': array([8]),
#  'INDEX': array([9]),
#  'INTRA_STEPS': array([5]),
#  'ITER_LAST': array([50]),
#  'ITMAX': array([50]),
#  'MEANLOGL': array([-4962083.28222825, -1583527.6003191 ,  -678190.1420774 ,
#          -339418.84185275,  -162283.50340175,   -99039.03848961,
#           -57025.88674919,   -34849.68730376,   -22937.92051259,
#           -13509.11453995]),
#  'MSTAR': array([0.9132]),
#  'NAME': 'SystemX',
#  'NDIM': array([13]),
#  'NPLA': array([2]),
#  'NTEMPS': array([8]),
#  'NWALKERS': array([150]),
#  'REF_EPOCH': array([0]),
#  'RSTAR': array([0.8632]),
#  'p0': array([[[0.34610585, 0.43847371, 0.61646276, ..., 0.38646014,
#           0.83392949, 0.51852582],
#          [0.33359064, 0.45283021, 0.61406183, ..., 0.37020884,
#           0.87502188, 0.55136784],
#          [0.33397726, 0.43905426, 0.6106879 , ..., 0.40856829,
#           0.85145125, 0.56300256],
#          ...,
#          [0.38150943, 0.47684237, 0.62186768, ..., 0.34093118,
#           0.82485878, 0.53719313],
#          [0.34316218, 0.45273782, 0.6344295 , ..., 0.37812036,
#           0.86027172, 0.53143841],
#          [0.35328085, 0.45377835, 0.62892927, ..., 0.36618624,
#           0.87564727, 0.56902619]],
#
#         [[0.30492127, 0.27968208, 0.42583715, ..., 0.38363907,
#           0.6283364 , 0.55759463],
#          [0.30794158, 0.27175467, 0.43881824, ..., 0.39943166,
#           0.6148382 , 0.55080829],
#          [0.31137645, 0.29781103, 0.418867  , ..., 0.37538376,
#           0.60148005, 0.54664793],
#          ...,
#          [0.32039832, 0.46676219, 0.62996681, ..., 0.36008469,
#           0.85943749, 0.54164118],
#          [0.32355379, 0.45587423, 0.61483847, ..., 0.3689003 ,
#           0.85840848, 0.55607877],
#          [0.3363915 , 0.28095653, 0.43422532, ..., 0.39720578,
#           0.62286113, 0.55871756]],
#
#         [[0.33351864, 0.44905055, 0.61837547, ..., 0.37110203,
#           0.87517565, 0.54857467],
#          [0.38387815, 0.46513733, 0.62107503, ..., 0.39634368,
#           0.8354412 , 0.52615518],
#          [0.32435944, 0.44792921, 0.60027145, ..., 0.36380144,
#           0.85916595, 0.54524307],
#          ...,
#          [0.31389749, 0.27855106, 0.41044314, ..., 0.3823789 ,
#           0.61633842, 0.54755174],
#          [0.36203169, 0.49060748, 0.64809767, ..., 0.3631049 ,
#           0.83281543, 0.51233007],
#          [0.29297166, 0.32114396, 0.43198675, ..., 0.3905788 ,
#           0.6323229 , 0.57793816]],
#
#         ...,
#
#         [[0.78655265, 0.55828967, 0.95590859, ..., 0.82932639,
#           0.43175731, 0.18203264],
#          [0.33574288, 0.4362274 , 0.63493039, ..., 0.3912867 ,
#           0.88177234, 0.5368833 ],
#          [0.36169842, 0.43194698, 0.63917226, ..., 0.40492237,
#           0.84824627, 0.56735318],
#          ...,
#          [0.80921308, 0.52622914, 0.9805154 , ..., 0.86877134,
#           0.42559425, 0.16920688],
#          [0.33405772, 0.41474599, 0.56329273, ..., 0.42914861,
#           0.81157423, 0.54694473],
#          [0.30642745, 0.27549676, 0.39491544, ..., 0.40806963,
#           0.62611011, 0.55549144]],
#
#         [[0.35967978, 0.48564639, 0.59482561, ..., 0.35345702,
#           0.8185431 , 0.55430687],
#          [0.32815776, 0.34111087, 0.37331369, ..., 0.42910135,
#           0.5583638 , 0.56135741],
#          [0.35405664, 0.43969943, 0.59572957, ..., 0.39381004,
#           0.87475435, 0.56224928],
#          ...,
#          [0.32536433, 0.44117754, 0.62491123, ..., 0.37734014,
#           0.86028118, 0.54524119],
#          [0.35352361, 0.45952551, 0.61902612, ..., 0.3954811 ,
#           0.85523453, 0.53491996],
#          [0.8015296 , 0.52066751, 0.95657537, ..., 0.83549387,
#           0.43982808, 0.15918726]],
#
#         [[0.70186219, 0.50880621, 0.2164054 , ..., 0.39010329,
#           0.41630863, 0.49977961],
#          [0.29340996, 0.48645466, 0.41867461, ..., 0.34658902,
#           0.10318848, 0.66831679],
#          [0.78500062, 0.53250184, 0.93582424, ..., 0.86857273,
#           0.43302135, 0.17906299],
#          ...,
#          [0.42963811, 0.47098795, 0.15794202, ..., 0.86271531,
#           0.04632744, 0.50211802],
#          [0.84437425, 0.57837457, 0.93012771, ..., 0.8348773 ,
#           0.40478941, 0.23158638],
#          [0.0026136 , 0.42407132, 0.60638953, ..., 0.85386337,
#           0.58306951, 0.58788348]]])}

# %% [markdown]
# If you want just specific results from the hdf5 file, pass a list with the keyword names through the -keywords- argument in get_mcmc_results().
#
# Not all the attributes in RESULTS_mcmc are stored in the .hdf5 file (ie., in the results_hdf5 variable) but just those necessary to analize the MCMC performance and many properties of the planetary system.
#
# Let's access, for example, to the mean autocorrelation of the chains:

# %%
results_hdf5['AUTOCORR']
# Out:
# array([-1.60128321e-17,  1.33440267e-16,  2.88230978e-16,  4.21671245e-16,
#         2.99973721e-16,  3.99253280e-16,  6.68268859e-16,  3.82172926e-16,
#         7.44062931e-16,  7.92101427e-16,  7.44062931e-16,  5.66854256e-16,
#         7.47265497e-16,  1.19882736e-15,  1.54683958e-15,  9.58634881e-16,
#         7.22712488e-16,  8.32667268e-16,  1.01734860e-15,  8.54017711e-16,
#         8.25194613e-16,  8.41207446e-16,  1.17854444e-15,  1.15932904e-15,
#         8.95651075e-16,  9.00988685e-16,  1.54470454e-15,  1.10488541e-15,
#         1.17961196e-15,  1.28316161e-15,  1.00026824e-15,  1.40699418e-15,
#         1.61836356e-15,  7.98506560e-16,  7.59008241e-16,  1.05150931e-15,
#         1.08780506e-15,  9.34081872e-16,  8.38004879e-16,  7.70750984e-16,
#         7.15239833e-16,  5.35896114e-16,  5.81799566e-16,  6.13825230e-16,
#         5.36963636e-16,  3.59754961e-16,  3.01041243e-16,  2.06031773e-16,
#         9.60769925e-17,  3.72565227e-16])

# %% [markdown]
# ### 4.3.1 Visualization

# %% [markdown]
# An easy way of looking into the results is generating descriptive figures using the 'Plots' module.

# %%
# Instantiate the Plots module

nauplot = nau.Plots_c(PS, burnin=burn, hdf5_file=f'{PS.system_name}.hdf5', temperature=T)

# %% [markdown]
# **MCMC performance**
#
# We can take a look into the MCMC performance

# %%
nauplot.plot_monitor()

# %% [markdown]
# It shows the movement of the adaptive temperatures, the swap between walkers of different temperatures, the Mean log likelihood and the Mean log likelihood, and the mean autocorrelation time.

# %% [markdown]
# **Histograms**
#
# Take a look into the posterior distributions, and set as titles the median and errors within $1-\sigma$

# %%
nauplot.plot_hist(titles=True)

# %% [markdown]
# **Chains**
#
# If you are interested in visualizing the chains movement, use the  'plot_chains' method:

# %%
nauplot.plot_chains(plot_means=True)  # Plot the mean movement of the chains as black lines

# %% [markdown]
# **Corner plot**
#
# hAnd now a corner plot to visualize possible correlations between variables

# %%
nauplot.plot_corner(color='blue', titles=True)

# %% [markdown]
# **TTVs**
#
# In order to visualize the TTVs that the posteriors represent, use the function 'plot_TTVs'. It takes solutions from the MCMC chains to calculate the mid-transit times and the resulting TTVs. Two modes are available: mode 'random' take random samples from the chains; 'best' take the best solutions from the chains until complete -nsols-.

# %%
nauplot.plot_TTVs(mode='best',  # Take random samples from the posteriors.
                  nsols=1)       # Number of solutions to draw
plt.savefig('TTVs_mcmc.png')
# Out:
# E3
# best

# %% [markdown]
# That's a much better fitting than the done before with the optimizers. Compare yourself the images in the current directory.

# %% [markdown]
# **At this point, we have seen how the MCMC module works. We also see the fast way of getting the results and how visualize them. If you are interested in going further in Nauyaca, the next tutoril will show all that extra fetures in the modules. See you there!**

# %% [markdown]
# _______________
