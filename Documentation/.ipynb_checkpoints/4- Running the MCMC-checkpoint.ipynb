# %% [markdown]
# # 4.- Running the MCMC

# %% [markdown]
# Nauyaca uses a Parallel-Tempering sampling algorithm ($\texttt{ptemcee}$; Vousden et al., 2015) to explore the parameter space at different walker temperatures. This method allows the walkers do not get stuck in local high probability regions due to the exchange between high and low temperature walkers. The posteriors are drawn from the walkers at temperature 0.
#
# Let's import Nauyaca and other useful libraries for analisys

# %%
import nauyaca_local as nau

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# As before, let's load the Planetary System object

# %%
PS = nau.PlanetarySystem.load_json('SystemX.json')
print(PS)
# Out:
# --> Parameter -ecc- of planet -Planet-b- set to lower physical limit: 1e-06
# --> Parameter -ecc- of planet -Planet-c- set to lower physical limit: 1e-06
#
#  =========== Planetary System Summary ===========
# --> Parameter -ecc- of planet -Planet-b- set to lower physical limit: 1e-06
# --> Parameter -ecc- of planet -Planet-c- set to lower physical limit: 1e-06
#
# System: SystemX
# Mstar: 0.9132 Msun |  Rstar: 0.8632 Rsun
# Number of planets: 2
# Planet information:
# ------
# Planet: Planet-b
#   Boundaries:
#     mass: (1, 20.0)  [M_earth]
#     period: (5.35, 5.36)  [d]
#     ecc: (1e-06, 0.2)
#     inclination: (85, 95)  [deg]
#     argument: (0.0, 360)  [deg]
#     mean_anomaly: (0.0, 360)  [deg]
#     ascending_node: (88.36, 88.36)  [deg]
#   TTVs: True
# ------
# Planet: Planet-c
#   Boundaries:
#     mass: (1, 100)  [M_earth]
#     period: (11.83, 11.84)  [d]
#     ecc: (1e-06, 0.2)
#     inclination: (85, 95)  [deg]
#     argument: (0.0, 360)  [deg]
#     mean_anomaly: (0.0, 360)  [deg]
#     ascending_node: (0.0, 180.0)  [deg]
#   TTVs: True
#
# Simulation attributes:
# Reference epoch of the solutions (T0JD): 0.0 [JD]
# Total time of TTVs data (Ftime): 200 [days]
# Timestep of the simulations (dt): 0.15 [days]

# %% [markdown]
# ## 4.1 Initializing walkers

# %% [markdown]
# Before running the MCMC, we need to decide which the initial prior will be. The prior is all that information that you can provide as initial guess for the exploration. We refer to $walker$ as those data that represent a point in the parameter space. Initial walkers constitute a group of data points in the space of $\mathrm{N_{dim}}$ dimensions that are initially supplied to the MCMC.
#
# For our current problem, the number of dimensions to explore is:

# %%
PS.ndim
# Out:
# 13

# %% [markdown]
# Thus, each walker will be an array of $\mathrm{N_{dim}}$ dimensions.
#
# Let's define the main parameters to run the MCMC. We will run the MCMC along 2000 iterations saving each 20 steps.

# %%
Ntemps = 8        # Number of temperatures
Nwalkers = 150    # Number of walkers per temperature
Tmax = 50        # Maximum temperature. If None, then Parallel-Tempering chose an appropiate maximum temperature

Itmax = 2500      # Maximum number of steps
Conver_steps = 50 # Number of steps to save the chains

# %% [markdown]
# Nauyaca provides 4 forms of easily initialize walkers through the 'initial_walkers' function in the 'utils' module. Additionally, you can provide your own walkers' initial position as long as they are inside the valid boundaries.
#
# **IMPORTANT:** Initial walkers should be provided in an array of shape (Ntemps, Nwalkers, Ndim)
#
# Let's generate these 4 ways of initial walkers and plot them using the 'Plots' module

# %%
nauplot = nau.Plots_c(PS)

# %% [markdown]
# ###  4.1.1 Uniform distribution
#
# For all the planetary parameters, initialize walkers from an uniform distribution
# along the established boundaries for each planet. Using this option is unnecesary to run optimizers previously. We call it from the 'utils' module

# %%
walkers_uniform = nau.utils.init_walkers(PS, 
                                distribution="Uniform", 
                                ntemps=Ntemps, 
                                nwalkers=Nwalkers)
# Out:
# --> Selected distribution: Uniform

# %%
# Show the initial uniform population 
nauplot.plot_hist(chains=walkers_uniform)

# %% [markdown]
# **Note:** If there are constant values in the planet's boundaries, then that parameter will be skipped and values will not appear in the initial walkers. Here, panels without information corresponds to planet parameters that remain as fixed. In this case, the constant parameter(s) and its value correspond to:

# %%
for constant in PS.constant_params.keys():
    param = PS.params_names_all.split()[constant]
    value = PS.constant_params[constant]
    print(f"{param}: {value}")
# Out:
# ascending_node1: 88.36

# %% [markdown]
# ### 4.1.2 Gaussian distribution
#
# In order to use this function, you need to provide the information comming from the optimizers saved in the **_cube.opt** file. Let's load the results from the optimizers that we got in the previous tutorial:

# %%
RESULTS_opt = np.genfromtxt(f'{PS.system_name}_cube.opt')

# %% [markdown]
# Provide the results directly from the optimizers (through opt_data argument) and construct a gaussian with the mean and standard deviation of the solutions along each dimension. In opt_data, pass RESULTS_opt (from optimizers or from file). Argument 'fbest' selects a fraction of the best solutions and discard the rest. For example, fbest=.1 takes the best 10% of the solutions, according to their $\chi^2$

# %%
walkers_gaussian = nau.utils.init_walkers(PS, 
                                   distribution = "Gaussian",
                                   opt_data = RESULTS_opt, 
                                   fbest = 0.5,
                                   ntemps = Ntemps, 
                                   nwalkers = Nwalkers)
# Out:
# --> Selected distribution: Gaussian
#     20 of 40 solutions taken

# %% [markdown]
# **Note:** the walkers_gaussian variable contains the walkers information normalized between 0 and 1. Try printing that variable to corroborate. That's a map between the physical boundaries and the hypercube with which Nauyaca internally works. However, we can visualize the physical results when passing that variable to the Plots module:

# %%
nauplot.plot_hist(chains=walkers_gaussian)

# %% [markdown]
# That will be the initial distribution of walkers

# %% [markdown]
# ### 4.1.3 Picked distribution
#
# Provide the results of the optimizers (through opt_data argument) to construct a discrete distribution by randomly selecting values around the optimizer solutions. In opt_data, pass RESULTS_opt (from optimizers) or results_opt (from file) fbest selects a fraction of the best solutions and discard the rest. For example, .5 takes the 50% of the solutions with the best $\chi^2$

# %%
walkers_picked = nau.utils.init_walkers(PS, 
                                 distribution = "Picked", 
                                 opt_data = RESULTS_opt, 
                                 fbest = .5,
                                 ntemps = Ntemps, 
                                 nwalkers = Nwalkers)
# Out:
# --> Selected distribution: Picked
#     20 of 40 solutions taken

# %%
walkers_picked.shape
# Out:
# (8, 80, 13)

# %%
nauplot.plot_hist(chains=walkers_picked)

# %% [markdown]
# ### 4.1.4 Ladder distribution

# %% [markdown]
# Provide the results of the optimizers (through opt_data argument).
# This method separate the solutions from optimizers in chunks corresponding to the number of temperatures. Then, each temperature draw their own walkers by following the rule:
# First temperature draw walkers from the first chunk (which includes the solution with the topmost solution). Second temperature draw walkers from first and second chunks. Third temperature draw walkers from first, second and third chunks. The same rule follows for the rest of the temperatures.
#
# In opt_data, pass RESULTS_opt (from optimizers) or results_opt (from file). fbest selects a fraction of the best solutions and discard the rest. For example, .5 takes the 50% of the solutions with the best $\chi^2$

# %%
walkers_ladder = nau.utils.init_walkers(PS, 
                                distribution = "Ladder",
                                opt_data = RESULTS_opt, 
                                fbest = 0.2,
                                ntemps = Ntemps, 
                                nwalkers = Nwalkers)
# Out:
# --> Selected distribution: Ladder
#     8 of 40 solutions taken

# %%
nauplot.plot_hist(chains=walkers_ladder)

# %% [markdown]
# ## 4.2 Running the MCMC

# %% [markdown]
# Let's run the MCMC using the initial walkers from the Ladder distribution generated above. Also provide the necessary keyword arguments. Many of them were defined at the beggining of section 3.1

# %%
nauMCMC = nau.MCMC(
            PS,                             # Planetary System object
            p0 = walkers_ladder,            # Initial population of walkers 
            nwalkers = Nwalkers,            # Number of walkers
            ntemps = Ntemps,                # Number of temperatures
            tmax = Tmax,                    # Maximum temperature
            itmax = Itmax,                  # Maximum nomber of iterations (steps)
            conver_steps = Conver_steps,    # Save data each this number of steps
            cores = 8)                      # Number of cores to run in parallel

# %%
RESULTS_mcmc = nauMCMC.run()
# Out:
#  =========== PARALLEL-TEMPERING MCMC ===========
#
# --> Starting date:  2021-02-02 17:09
# --> Reference epoch of the solutions:  0.0  [JD]
# --> Results will be saved at:  ./SystemX.hdf5
#
# --------- Iteration:  50
#  Mean tau: -0.0
#  Accepted swap fraction in Temp 0:  0.049
#  Mean acceptance fraction Temp 0:  0.161
#  Mean likelihood:  -6754.410479
#  Maximum likelihood:  (0, 122) -27.731208
#  Current mean likelihood dispersion:  0.0
#  Saving time: 0.01924 sec
#  Elapsed time:  0.4982 min
# --------- Iteration:  100
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.036
#  Mean acceptance fraction Temp 0:  0.14
#  Mean likelihood:  -332.51027
#  Maximum likelihood:  (0, 146) 150.574513
#  Current mean likelihood dispersion:  3210.950104
#  Saving time: 0.01888 sec
#  Elapsed time:  1.0447 min
# --------- Iteration:  150
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.031
#  Mean acceptance fraction Temp 0:  0.125
#  Mean likelihood:  167.54562
#  Maximum likelihood:  (0, 71) 284.713996
#  Current mean likelihood dispersion:  250.027945
#  Saving time: 0.02124 sec
#  Elapsed time:  1.7211 min
# --------- Iteration:  200
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.12
#  Mean likelihood:  272.70744
#  Maximum likelihood:  (0, 123) 344.958478
#  Current mean likelihood dispersion:  264.029329
#  Saving time: 0.02302 sec
#  Elapsed time:  2.4834 min
# --------- Iteration:  250
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.112
#  Mean likelihood:  307.036965
#  Maximum likelihood:  (0, 111) 349.516689
#  Current mean likelihood dispersion:  59.343969
#  Saving time: 0.02162 sec
#  Elapsed time:  3.2832 min
# --------- Iteration:  300
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.021
#  Mean acceptance fraction Temp 0:  0.105
#  Mean likelihood:  320.755328
#  Maximum likelihood:  (0, 68) 349.112196
#  Current mean likelihood dispersion:  60.034036
#  Saving time: 0.02416 sec
#  Elapsed time:  4.0238 min
# --------- Iteration:  350
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.018
#  Mean acceptance fraction Temp 0:  0.099
#  Mean likelihood:  324.878212
#  Maximum likelihood:  (0, 99) 348.962865
#  Current mean likelihood dispersion:  20.512811
#  Saving time: 0.02842 sec
#  Elapsed time:  4.7504 min
# --------- Iteration:  400
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.093
#  Mean likelihood:  327.377028
#  Maximum likelihood:  (0, 110) 354.030705
#  Current mean likelihood dispersion:  20.184132
#  Saving time: 0.02731 sec
#  Elapsed time:  5.4725 min
# --------- Iteration:  450
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.088
#  Mean likelihood:  329.072604
#  Maximum likelihood:  (0, 107) 351.408875
#  Current mean likelihood dispersion:  7.905758
#  Saving time: 0.02391 sec
#  Elapsed time:  6.2918 min
# --------- Iteration:  500
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.019
#  Mean acceptance fraction Temp 0:  0.084
#  Mean likelihood:  329.976365
#  Maximum likelihood:  (0, 20) 354.615038
#  Current mean likelihood dispersion:  7.830378
#  Saving time: 0.03451 sec
#  Elapsed time:  6.9878 min
# --------- Iteration:  550
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.021
#  Mean acceptance fraction Temp 0:  0.08
#  Mean likelihood:  330.865251
#  Maximum likelihood:  (0, 110) 354.241676
#  Current mean likelihood dispersion:  3.454276
#  Saving time: 0.04524 sec
#  Elapsed time:  7.9324 min
# --------- Iteration:  600
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.022
#  Mean acceptance fraction Temp 0:  0.077
#  Mean likelihood:  332.200107
#  Maximum likelihood:  (0, 24) 355.044031
#  Current mean likelihood dispersion:  3.653112
#  Saving time: 0.03996 sec
#  Elapsed time:  8.7911 min
# --------- Iteration:  650
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.074
#  Mean likelihood:  333.335903
#  Maximum likelihood:  (0, 110) 354.921499
#  Current mean likelihood dispersion:  2.67097
#  Saving time: 0.03459 sec
#  Elapsed time:  9.6012 min
# --------- Iteration:  700
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.026
#  Mean acceptance fraction Temp 0:  0.071
#  Mean likelihood:  334.261449
#  Maximum likelihood:  (0, 80) 356.096103
#  Current mean likelihood dispersion:  2.923334
#  Saving time: 0.02271 sec
#  Elapsed time:  10.454 min
# --------- Iteration:  750
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.028
#  Mean acceptance fraction Temp 0:  0.069
#  Mean likelihood:  335.195527
#  Maximum likelihood:  (0, 143) 359.545203
#  Current mean likelihood dispersion:  2.518646
#  Saving time: 0.02644 sec
#  Elapsed time:  11.3149 min
# --------- Iteration:  800
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.029
#  Mean acceptance fraction Temp 0:  0.067
#  Mean likelihood:  335.766774
#  Maximum likelihood:  (0, 143) 359.826893
#  Current mean likelihood dispersion:  2.721576
#  Saving time: 0.02469 sec
#  Elapsed time:  12.1756 min
# --------- Iteration:  850
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.03
#  Mean acceptance fraction Temp 0:  0.065
#  Mean likelihood:  336.801466
#  Maximum likelihood:  (0, 143) 359.876598
#  Current mean likelihood dispersion:  2.54666
#  Saving time: 0.02997 sec
#  Elapsed time:  13.004 min
# --------- Iteration:  900
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.031
#  Mean acceptance fraction Temp 0:  0.063
#  Mean likelihood:  337.719206
#  Maximum likelihood:  (0, 143) 359.231134
#  Current mean likelihood dispersion:  2.792255
#  Saving time: 0.02604 sec
#  Elapsed time:  13.8391 min
# --------- Iteration:  950
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.031
#  Mean acceptance fraction Temp 0:  0.061
#  Mean likelihood:  338.297342
#  Maximum likelihood:  (0, 16) 359.756186
#  Current mean likelihood dispersion:  2.692783
#  Saving time: 0.02046 sec
#  Elapsed time:  14.6892 min
# --------- Iteration:  1000
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.031
#  Mean acceptance fraction Temp 0:  0.06
#  Mean likelihood:  339.508671
#  Maximum likelihood:  (0, 16) 360.26982
#  Current mean likelihood dispersion:  2.951868
#  Saving time: 0.03593 sec
#  Elapsed time:  15.5484 min
# --------- Iteration:  1050
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.032
#  Mean acceptance fraction Temp 0:  0.058
#  Mean likelihood:  339.655849
#  Maximum likelihood:  (0, 105) 361.396988
#  Current mean likelihood dispersion:  2.790533
#  Saving time: 0.02650 sec
#  Elapsed time:  16.4165 min
# --------- Iteration:  1100
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.032
#  Mean acceptance fraction Temp 0:  0.057
#  Mean likelihood:  340.528446
#  Maximum likelihood:  (0, 16) 360.444384
#  Current mean likelihood dispersion:  2.976362
#  Saving time: 0.02761 sec
#  Elapsed time:  17.2332 min
# --------- Iteration:  1150
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.033
#  Mean acceptance fraction Temp 0:  0.056
#  Mean likelihood:  340.923084
#  Maximum likelihood:  (0, 16) 360.569149
#  Current mean likelihood dispersion:  2.771361
#  Saving time: 0.04193 sec
#  Elapsed time:  18.2169 min
# --------- Iteration:  1200
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.033
#  Mean acceptance fraction Temp 0:  0.055
#  Mean likelihood:  342.357608
#  Maximum likelihood:  (0, 127) 360.634196
#  Current mean likelihood dispersion:  3.019192
#  Saving time: 0.02627 sec
#  Elapsed time:  19.0458 min
# --------- Iteration:  1250
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.033
#  Mean acceptance fraction Temp 0:  0.054
#  Mean likelihood:  342.781087
#  Maximum likelihood:  (0, 127) 362.140905
#  Current mean likelihood dispersion:  2.925154
#  Saving time: 0.04646 sec
#  Elapsed time:  19.9674 min
# --------- Iteration:  1300
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.034
#  Mean acceptance fraction Temp 0:  0.053
#  Mean likelihood:  343.64082
#  Maximum likelihood:  (0, 91) 362.777919
#  Current mean likelihood dispersion:  3.14314
#  Saving time: 0.03696 sec
#  Elapsed time:  20.9263 min
# --------- Iteration:  1350
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.034
#  Mean acceptance fraction Temp 0:  0.052
#  Mean likelihood:  343.858805
#  Maximum likelihood:  (0, 127) 364.692133
#  Current mean likelihood dispersion:  3.04472
#  Saving time: 0.02202 sec
#  Elapsed time:  21.7099 min
# --------- Iteration:  1400
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.034
#  Mean acceptance fraction Temp 0:  0.051
#  Mean likelihood:  344.583204
#  Maximum likelihood:  (0, 127) 361.918938
#  Current mean likelihood dispersion:  3.215271
#  Saving time: 0.02034 sec
#  Elapsed time:  22.4627 min
# --------- Iteration:  1450
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.035
#  Mean acceptance fraction Temp 0:  0.05
#  Mean likelihood:  344.979911
#  Maximum likelihood:  (0, 87) 364.266224
#  Current mean likelihood dispersion:  3.110926
#  Saving time: 0.02281 sec
#  Elapsed time:  23.2299 min
# --------- Iteration:  1500
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.035
#  Mean acceptance fraction Temp 0:  0.05
#  Mean likelihood:  345.984668
#  Maximum likelihood:  (0, 16) 365.904633
#  Current mean likelihood dispersion:  3.297645
#  Saving time: 0.02854 sec
#  Elapsed time:  24.0197 min
# --------- Iteration:  1550
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.035
#  Mean acceptance fraction Temp 0:  0.049
#  Mean likelihood:  346.256913
#  Maximum likelihood:  (0, 41) 363.605377
#  Current mean likelihood dispersion:  3.211432
#  Saving time: 0.02596 sec
#  Elapsed time:  24.7892 min
# --------- Iteration:  1600
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.035
#  Mean acceptance fraction Temp 0:  0.049
#  Mean likelihood:  346.901972
#  Maximum likelihood:  (0, 20) 366.175211
#  Current mean likelihood dispersion:  3.366831
#  Saving time: 0.02569 sec
#  Elapsed time:  25.602 min
# --------- Iteration:  1650
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.035
#  Mean acceptance fraction Temp 0:  0.048
#  Mean likelihood:  347.930077
#  Maximum likelihood:  (0, 20) 366.175211
#  Current mean likelihood dispersion:  3.301133
#  Saving time: 0.03922 sec
#  Elapsed time:  26.3801 min
# --------- Iteration:  1700
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.035
#  Mean acceptance fraction Temp 0:  0.048
#  Mean likelihood:  348.7369
#  Maximum likelihood:  (0, 20) 366.175211
#  Current mean likelihood dispersion:  3.5107
#  Saving time: 0.02706 sec
#  Elapsed time:  27.1999 min
# --------- Iteration:  1750
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.035
#  Mean acceptance fraction Temp 0:  0.047
#  Mean likelihood:  350.058142
#  Maximum likelihood:  (0, 127) 369.154472
#  Current mean likelihood dispersion:  3.553124
#  Saving time: 0.02755 sec
#  Elapsed time:  27.9858 min
# --------- Iteration:  1800
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.034
#  Mean acceptance fraction Temp 0:  0.047
#  Mean likelihood:  350.628251
#  Maximum likelihood:  (0, 127) 367.396875
#  Current mean likelihood dispersion:  3.798289
#  Saving time: 0.02862 sec
#  Elapsed time:  28.7712 min
# --------- Iteration:  1850
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.034
#  Mean acceptance fraction Temp 0:  0.046
#  Mean likelihood:  351.444184
#  Maximum likelihood:  (0, 20) 367.591492
#  Current mean likelihood dispersion:  3.846615
#  Saving time: 0.02910 sec
#  Elapsed time:  29.5851 min
# --------- Iteration:  1900
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.033
#  Mean acceptance fraction Temp 0:  0.046
#  Mean likelihood:  352.081756
#  Maximum likelihood:  (0, 91) 368.152813
#  Current mean likelihood dispersion:  4.080923
#  Saving time: 0.03134 sec
#  Elapsed time:  30.3457 min
# --------- Iteration:  1950
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.033
#  Mean acceptance fraction Temp 0:  0.046
#  Mean likelihood:  352.739539
#  Maximum likelihood:  (0, 91) 368.316334
#  Current mean likelihood dispersion:  4.098668
#  Saving time: 0.03211 sec
#  Elapsed time:  31.1372 min
# --------- Iteration:  2000
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.032
#  Mean acceptance fraction Temp 0:  0.046
#  Mean likelihood:  353.332712
#  Maximum likelihood:  (0, 91) 368.11871
#  Current mean likelihood dispersion:  4.311243
#  Saving time: 0.02351 sec
#  Elapsed time:  31.9559 min
# --------- Iteration:  2050
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.032
#  Mean acceptance fraction Temp 0:  0.045
#  Mean likelihood:  353.33027
#  Maximum likelihood:  (0, 68) 368.753845
#  Current mean likelihood dispersion:  4.303862
#  Saving time: 0.02513 sec
#  Elapsed time:  32.7441 min
# --------- Iteration:  2100
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.031
#  Mean acceptance fraction Temp 0:  0.045
#  Mean likelihood:  354.006717
#  Maximum likelihood:  (0, 20) 368.405209
#  Current mean likelihood dispersion:  4.46505
#  Saving time: 0.02750 sec
#  Elapsed time:  33.5087 min
# --------- Iteration:  2150
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.031
#  Mean acceptance fraction Temp 0:  0.045
#  Mean likelihood:  354.188589
#  Maximum likelihood:  (0, 138) 369.550543
#  Current mean likelihood dispersion:  4.385539
#  Saving time: 0.02784 sec
#  Elapsed time:  34.2783 min
# --------- Iteration:  2200
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.031
#  Mean acceptance fraction Temp 0:  0.044
#  Mean likelihood:  354.286526
#  Maximum likelihood:  (0, 132) 369.85597
#  Current mean likelihood dispersion:  4.489383
#  Saving time: 0.02372 sec
#  Elapsed time:  35.0713 min
# --------- Iteration:  2250
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.031
#  Mean acceptance fraction Temp 0:  0.044
#  Mean likelihood:  354.919193
#  Maximum likelihood:  (0, 142) 368.4815
#  Current mean likelihood dispersion:  4.396884
#  Saving time: 0.03504 sec
#  Elapsed time:  35.8768 min
# --------- Iteration:  2300
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.03
#  Mean acceptance fraction Temp 0:  0.044
#  Mean likelihood:  355.423539
#  Maximum likelihood:  (0, 40) 368.949978
#  Current mean likelihood dispersion:  4.509506
#  Saving time: 0.02521 sec
#  Elapsed time:  36.7136 min
# --------- Iteration:  2350
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.03
#  Mean acceptance fraction Temp 0:  0.044
#  Mean likelihood:  355.365118
#  Maximum likelihood:  (0, 40) 368.949978
#  Current mean likelihood dispersion:  4.356011
#  Saving time: 0.03746 sec
#  Elapsed time:  37.5395 min
# --------- Iteration:  2400
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.03
#  Mean acceptance fraction Temp 0:  0.043
#  Mean likelihood:  355.340316
#  Maximum likelihood:  (0, 132) 370.097257
#  Current mean likelihood dispersion:  4.414964
#  Saving time: 0.02734 sec
#  Elapsed time:  38.3769 min
# --------- Iteration:  2450
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.029
#  Mean acceptance fraction Temp 0:  0.043
#  Mean likelihood:  355.432148
#  Maximum likelihood:  (0, 132) 370.097257
#  Current mean likelihood dispersion:  4.27377
#  Saving time: 0.02926 sec
#  Elapsed time:  39.0986 min
# --------- Iteration:  2500
#  Mean tau: 0.0
#  Accepted swap fraction in Temp 0:  0.029
#  Mean acceptance fraction Temp 0:  0.043
#  Mean likelihood:  356.051017
#  Maximum likelihood:  (0, 81) 370.057549
#  Current mean likelihood dispersion:  4.332823
#  Saving time: 0.02891 sec
#  Elapsed time:  39.8684 min
#
# --> Maximum number of iterations reached in MCMC
# --> Best solutions from the ./SystemX.hdf5 will be written at: .best
# --> Reference epoch of the solutions:  0.0  [JD]
# --> Iterations performed:  2500
# --> Elapsed time in MCMC: 39.8689 minutes

# %% [markdown]
# After the mcmc run ends, it returns the sampler object from $\texttt{ptemcee}$, with the following attributes:

# %%
RESULTS_mcmc.__dict__.keys()
# Out:
# dict_keys(['_random', '_likeprior', 'a', 'nwalkers', 'dim', 'adaptation_time', 'adaptation_lag', '_betas', 'pool', '_chain', '_logposterior', '_loglikelihood', '_beta_history', '_time', '_p0', '_logposterior0', '_loglikelihood0', 'nswap', 'nswap_accepted', 'nprop', 'nprop_accepted'])

# %% [markdown]
# We will deeply inspect these attributes in the following tutorial.

# %% [markdown]
# Okey, at this point there are two files that have been saved with the following extesions:
#
# * **.hdf5:** It contains the main results from the MCMC run. It will be useful for posterior analysis. It also can be provided to the Plots module to plot default figures from Nauyaca. This file is portable and is useful to restart an MCMC in other time or in another computer.
#
# * **.best:** It is a file containing the best solution (normalized) of each saved iteration. It correspond to the solution with the 'Maximum likelihood' indicated in the outputs.

# %% [markdown]
# ## 4.3 Results (fast version)

# %% [markdown]
# For the following analysis, let's make a burnin of the first 25% of the chains. Also remember that results are taken from temperature 0.

# %%
burn = 0.25  # Fractional lenght of the initial chains to be discarted
T = 0        # Target temperature

# %% [markdown]
# **MCMC Summary**
#
# An easy way to summarize the current MCMC run is through the mcmc_summary method in utils, passing the name of the .hdf5 file.

# %%
posteriors = nau.utils.mcmc_summary(PS, hdf5_file=f'{PS.system_name}.hdf5', burning=burn)
# Out:
# -->Planetary System:  SystemX
#    Stellar mass:  0.9132
#    Stellar radius:  0.8632
#    Number of planets:  2
# --------------------------
# -->MCMC parameters
#    Ntemps:  8
#    Nwalkers per temperature:  150
#    Number of iterations:  2500
#    Thining:  50
#    Burning:  0.25
#    Chain shape:  (150, 38, 13)
# --------------------------
#       RESULTS
# -->Results in File:   SystemX.hdf5
# -->Reference epoch of the solutions:  0  [JD]
# -->Best solution in MCMC
#    Best chi2 solution:  370.09726
#    0.3485   0.4433   0.5323   0.843   0.9382   0.3603   0.4499
#    0.3539   0.2688   0.2884   0.3769   0.6848   0.5641
# --------------------------
# -->MCMC medians and 1-sigma errors
#              mass1      7.99 ^{+0.18}_{-0.19}
#            period1      5.3544 ^{+0.0001}_{-0.0002}
#               ecc1      0.103 ^{+0.002}_{-0.002}
#       inclination1      93.3 ^{+0.11}_{-0.11}
#          argument1      286.13 ^{+1.74}_{-3.71}
#      mean_anomaly1      29.73 ^{+4.48}_{-2.13}
#              mass2      46.76 ^{+4.07}_{-2.62}
#            period2      11.83 ^{+0.0}_{-0.0}
#               ecc2       0.05 ^{+0.0}_{-0.0}
#       inclination2      88.45 ^{+0.28}_{-0.17}
#          argument2      212.47 ^{+10.98}_{-4.74}
#      mean_anomaly2      57.57 ^{+5.21}_{-11.82}
#    ascending_node2      98.44 ^{+1.92}_{-2.72}

# %% [markdown]
# That function prints a summary of the MCMC run and the medians of the posteriors with 1-$\sigma$ erros, corresponding to percentiles 16 and 84. Furthermore, it returns a dictionary with the flatten chains of each planetary parameter:

# %%
posteriors
# Out:
# {'mass1': array([8.09239889, 8.08502855, 8.11807862, ..., 7.80017353, 7.75334265,
#         7.7546344 ]),
#  'period1': array([5.35442183, 5.35442877, 5.35443869, ..., 5.35434282, 5.35439228,
#         5.35438871]),
#  'ecc1': array([0.10011057, 0.1001573 , 0.10027148, ..., 0.10276208, 0.103898  ,
#         0.10397688]),
#  'inclination1': array([93.23880838, 93.24839544, 93.23249649, ..., 93.3683973 ,
#         93.37620298, 93.37468697]),
#  'argument1': array([285.68597421, 285.90113973, 286.01987534, ..., 284.76869098,
#         285.86075672, 285.76972977]),
#  'mean_anomaly1': array([30.40008158, 30.13902102, 29.99029725, ..., 31.41908602,
#         30.05281076, 30.16006733]),
#  'mass2': array([46.8360966 , 46.72731002, 46.29732597, ..., 48.04789579,
#         46.30066367, 46.32558402]),
#  'period2': array([11.83362792, 11.83362368, 11.83363249, ..., 11.83357067,
#         11.83356217, 11.8335629 ]),
#  'ecc2': array([0.04613366, 0.04602145, 0.04593031, ..., 0.04772051, 0.04868723,
#         0.04850279]),
#  'inclination2': array([88.5665381 , 88.55745724, 88.55093309, ..., 88.38360905,
#         88.24239663, 88.24690781]),
#  'argument2': array([209.81269625, 209.9098221 , 210.14755239, ..., 208.62274401,
#         207.15150869, 207.35332936]),
#  'mean_anomaly2': array([60.43171393, 60.31862668, 60.06054197, ..., 61.83826196,
#         63.47348352, 63.24385432]),
#  'ascending_node2': array([95.26533948, 95.43682997, 95.36457387, ..., 96.3160173 ,
#         97.58037458, 97.44979408])}

# %% [markdown]
# Now, it's easier to analyze individual parameters.
#
# Let's plot for example, the posterior of the 'mass1' and calculate the mean:

# %%
plt.hist(posteriors['mass1']);

mean = np.mean(posteriors['mass1'])
print(f"Mean: {mean}")
# Out:
# Mean: 7.990892338556163

# %% [markdown]
# All the results saved in the .hdf5 file can be accessed through the method 'get_mcmc_results', which will return a dictionary:

# %%
results_hdf5 =  nau.utils.get_mcmc_results(f'{PS.system_name}.hdf5')

print( results_hdf5.keys() )  # Results saved in the .hdf5 file
# Out:
# dict_keys(['ACC_FRAC0', 'AUTOCORR', 'BESTLOGL', 'BESTSOLS', 'BETAS', 'BOUNDS', 'BOUNDSP', 'CHAINS', 'COL_NAMES', 'CONVER_STEPS', 'CORES', 'INDEX', 'ITER_LAST', 'ITMAX', 'MEANLOGL', 'MSTAR', 'NAME', 'NDIM', 'NPLA', 'NTEMPS', 'NWALKERS', 'REF_EPOCH', 'RSTAR', 'p0'])

# %% [markdown]
# These keys correspond to the main features of the MCMC saved in the .hdf5 file.
#
# Not all the attributes in RESULTS_mcmc are stored in the .hdf5 file but just those necessary to analize the MCMC performance and many properties of the planetary system.
#
# Let's access, for example, to the mean autocorrelation of the chains:

# %%
results_hdf5['AUTOCORR']
# Out:
# array([-1.60128321e-17,  1.33440267e-16,  2.88230978e-16,  4.21671245e-16,
#         2.99973721e-16,  3.99253280e-16,  6.68268859e-16,  3.82172926e-16,
#         7.44062931e-16,  7.92101427e-16,  7.44062931e-16,  5.66854256e-16,
#         7.47265497e-16,  1.19882736e-15,  1.54683958e-15,  9.58634881e-16,
#         7.22712488e-16,  8.32667268e-16,  1.01734860e-15,  8.54017711e-16,
#         8.25194613e-16,  8.41207446e-16,  1.17854444e-15,  1.15932904e-15,
#         8.95651075e-16,  9.00988685e-16,  1.54470454e-15,  1.10488541e-15,
#         1.17961196e-15,  1.28316161e-15,  1.00026824e-15,  1.40699418e-15,
#         1.61836356e-15,  7.98506560e-16,  7.59008241e-16,  1.05150931e-15,
#         1.08780506e-15,  9.34081872e-16,  8.38004879e-16,  7.70750984e-16,
#         7.15239833e-16,  5.35896114e-16,  5.81799566e-16,  6.13825230e-16,
#         5.36963636e-16,  3.59754961e-16,  3.01041243e-16,  2.06031773e-16,
#         9.60769925e-17,  3.72565227e-16])

# %% [markdown]
# ### 4.3.1 Visualization

# %% [markdown]
# An easy way of looking into the results is generating descriptive figures using the 'Plots' module.

# %%
# Instantiate the Plots module

nauplot = nau.Plots_c(PS, burning=burn, hdf5_file=f'{PS.system_name}.hdf5', temperature=T)

# %% [markdown]
# **MCMC performance**
#
# We can take a look into the MCMC performance

# %%
nauplot.plot_monitor()

# %% [markdown]
# It shows the movement of the adaptive temperatures, the swap between walkers of different temperatures, the Mean log likelihood and the Mean log likelihood, and the mean autocorrelation time.

# %% [markdown]
# **Histograms**
#
# Take a look into the posterior distributions, and set as titles the median and errors within $1-\sigma$

# %%
nauplot.plot_hist(titles=True)

# %% [markdown]
# **Chains**
#
# If you are interested in visualizing the chains movement, use the  'plot_chains' method:

# %%
nauplot.plot_chains(plot_means=True)  # Plot the mean movement of the chains as black lines

# %% [markdown]
# **Corner plot**
#
# hAnd now a corner plot to visualize possible correlations between variables

# %%
nauplot.plot_corner(color='blue', titles=True)

# %% [markdown]
# **TTVs**
#
# In order to visualize the TTVs that the posteriors represent, use the function 'plot_TTVs'. It takes solutions from the MCMC chains to calculate the mid-transit times and the resulting TTVs. Two modes are available: mode 'random' take random samples from the chains; 'best' take the best solutions from the chains until complete -nsols-.

# %%
nauplot.plot_TTVs(mode='random',  # Take random samples from the posteriors.
                  nsols=10)       # Number of solutions to draw
plt.savefig('TTVs_mcmc.png')
# Out:
# E3
# random

# %% [markdown]
# That's a much better fitting than the done before with the optimizers. Compare yourself the images in the current directory.

# %% [markdown]
# **At this point, we have seen how the MCMC module works. We also see the fast way of getting the results and how visualize them. If you are interested in going further in Nauyaca, the next tutoril will show all that extra fetures in the modules. See you there!**

# %% [markdown]
# _______________
