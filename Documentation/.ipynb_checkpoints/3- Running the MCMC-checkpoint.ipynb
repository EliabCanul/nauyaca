# %% [markdown]
# # 3.- Running the MCMC

# %% [markdown]
# Nauyaca uses a Parallel-Tempering sampling algorithm to explore the parameter space at different walker temperatures. This method allows the walkers do not get stuck in local high probability regions due to the exchange between high and low temperature walkers. The posteriors are drawn from the walkers at temperature 0.
#
# Let's import the main modules for the MCMC analisys.

# %%
import nauyaca_local as nau

from nauyaca_local import MCMC

from nauyaca_local import plots # Useful pre-fabricated plots

import matplotlib.pyplot as plt

# %% [markdown]
# As before, let's load the Planetary System object

# %%
PS = nau.utils.load_pickle('SystemX.pkl')
print(PS)
# Out:
#  =========== Planetary System Summary ===========
# System: SystemX
# Mstar: 0.91 Msun |  Rstar: 1.18 Rsun
# Number of planets: 2
# Planet information:
# ------
# Planet: Planet-b
#   Boundaries:
#     mass: [0.1, 20.0]  [M_earth]
#     period: [33.616, 33.618]  [d]
#     ecc: [1e-05, 0.2]
#     inclination: [88, 90.0]  [deg]
#     argument: [0.0, 360]  [deg]
#     mean_anomaly: [0.0, 360]  [deg]
#     ascending_node: [180.0, 180]  [deg]
#   TTVs: True
# ------
# Planet: Planet-c
#   Boundaries:
#     mass: [0.1, 20]  [M_earth]
#     period: [73.506, 73.508]  [d]
#     ecc: [1e-05, 0.2]
#     inclination: [88, 90.0]  [deg]
#     argument: [0.0, 360]  [deg]
#     mean_anomaly: [0.0, 360]  [deg]
#     ascending_node: [90.0, 270.0]  [deg]
#   TTVs: True
#
# Total time of TTVs data: 996.625070414 [days]
# First planet (ID) in transit: Planet-b
# Reference epoch of the solutions: 21.0 [JD]
# Time span of TTVs simulations: 1004.89382252642
# Timestep of the simulations: None [days]

# %%
# Reference time
PS.T0JD = 0.0

PS.T0JD
# Out:
# 0.0

# %% [markdown]
# Now let's define the main parameters to run the MCMC. We will run the MCMC along 1000 iterations saving each 10 steps.

# %%
Ntemps = 16       # Number of temperatures
Nwalkers = 100    # Number of walkers per temperature
Tmax = None       # Maximum temperature. If None, then Parallel-Tempering chose an appropiate maximum temperature

itmax = 50000      # Maximum number of steps
conver_steps = 50 # Number of steps to save the chains

# %% [markdown]
# ## 3.1 Initializing walkers

# %% [markdown]
# To initialize the MCMC we should provide an initial array of the location of the walkers in the parameter space. To do so, Nauyaca provides 3 forms of easily initialize walkers through the 'initial_walkers' function in the 'utils' module. Additionally, you can provide your own walkers' initial position as long as they are inside the valid boundaries.
#
# IMPORTANT: Initial walkers should be provided in an array of shape (ntemps, nwalkers, ndim), where ndim is the number of dimensions (mass1, period1...)
#
# Let's generate these 3 ways of initial walkers and plot them using the 'plots' module

# %%
from nauyaca_local.utils import initial_walkers

# %% [markdown]
# **1) Uniform distribution**
#
# For all the planetary parameters, initialize walkers from an uniform distribution
# along the stablished boundaries for each planet. Using this option is unnecesary to run optimizers previously.

# %%
walkers_uniform = initial_walkers(PS, distribution="Uniform", ntemps=Ntemps, nwalkers=Nwalkers)
# Out:
# --> Selected distribution: Uniform

# %%
plots.plot_hist(PS, chains=walkers_uniform)

# %% [markdown]
# For the two other ways, let's load the results from the optimizers that we got in the previous tutorial.

# %%
import numpy as np

RESULTS_opt = np.genfromtxt(f'{PS.system_name}.opt').tolist()
len(RESULTS_opt)
# Out:
# 480

# %%
# Visualize the chi2 distribution
plt.hist(np.array(RESULTS_opt).T[0] )

thrs = 0.6

# Helps to visualize the choice of threshold
r2 = sorted(RESULTS_opt, key=lambda x: x[0])
plt.hist(np.array(r2).T[0][:int(len(RESULTS_opt)*thrs)])
# Out:
# (array([138.,  39.,  28.,  19.,  10.,   9.,   7.,  14.,   9.,  15.]),
#  array([  -83.17010789,  5768.69101747, 11620.55214282, 17472.41326818,
#         23324.27439353, 29176.13551889, 35027.99664425, 40879.8577696 ,
#         46731.71889496, 52583.58002031, 58435.44114567]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# **2) Gaussian distribution**
#
# Provide the results directly from the optimizers (through opt_data argument) and construct a gaussian with the mean and standard deviation of the solutions along each dimension. In opt_data, pass RESULTS_opt (from optimizers or from file). Argument 'treshold' selects a fraction of the best solutions and discard the rest. For example, treshold=.4 takes the best 40% of the solutions according to the $\chi^2$

# %%
walkers_gaussian = initial_walkers(PS, distribution="Gaussian", 
                                   ntemps=Ntemps, nwalkers=Nwalkers, 
                                   opt_data=RESULTS_opt, threshold=0.4)
# Out:
# --> Selected distribution: Gaussian
#     192 of 480 solutions taken

# %%
plots.plot_hist(PS, chains=walkers_gaussian)

# %% [markdown]
# **3) Picked distribution**
#
# Provide directly the results of the optimizers (throuhgt opt_data argument) and construct a discrete distribution by randomly selecting exact values of the optimizer solutions. In opt_data, pass RESULTS_opt (from optimizers) or results_opt (from file) treshold selects a fraction of the best solutions and discard the rest. For example, .8 takes the 80% of the solutions with the best $\chi^2$

# %%
walkers_picked = initial_walkers(PS, distribution="Picked", 
                                 ntemps=Ntemps, nwalkers=Nwalkers, 
                                 opt_data=RESULTS_opt, threshold=.6)
# Out:
# --> Selected distribution: Picked
#     288 of 480 solutions taken

# %%
plots.plot_hist(PS, chains=walkers_picked)

# %% [markdown]
# #### 4) Smart distribution

# %%
walkers_smart = initial_walkers(PS, distribution="Smart",
                    ntemps=Ntemps, nwalkers=Nwalkers,
                    opt_data=RESULTS_opt, threshold=0.6)
# Out:
# --> Selected distribution: Smart
#     288 of 480 solutions taken

# %%
# Temporal
bi, bf = np.array(PS.bounds).T 
walkers_s2 = np.zeros_like(walkers_smart) # []

for t in range(Ntemps):
    flat_params = walkers_smart[t] # una misma temperatura
    #wk_tmp = []
    
    for i_fp, fp  in enumerate(flat_params):
        #wk_tmp.append( (fp-bi)/(bf-bi)  )
        
        walkers_s2[t,i_fp,:]  = (fp-bi)/(bf-bi)
walkers_s2.shape
# Out:
# (16, 100, 13)

# %%
plots.plot_hist(PS, chains=walkers_smart)

# %%
plots.plot_hist(PS, chains=walkers_s2)

# %% [markdown]
# Note that if there are constant values in the planet's boundaries, then that parameter will be skipped and values will not appear in the initial walkers

# %% [markdown]
# ## 3.2 Running the MCMC

# %% [markdown]
# Let's run the MCMC using the initial walkers from the picked distribution generated above. Also provide the necessary keyword arguments

# %%
RESULTS_mcmc = MCMC.run_mcmc(
            PS,                             # Planetary System object
            pop0 = walkers_s2,        # Initial population of walkers 
            nwalkers = Nwalkers,            # Number of walkers
            ntemps = Ntemps,                # Number of temperatures
            Tmax = Tmax,                    # Maximum temperature
            betas = None,                   # Betas is an array of inverse temperatures
            Itmax = itmax,                  # Maximum nomber of iterations (steps)
            conver_steps = conver_steps,    # Save data each this number of steps
            cores = 7,                      # Number of cores to run in parallel
            suffix = '')                    # Suffix to add at the final hdf5 file
# Out:
#  =========== PARALLEL-TEMPERING MCMC ===========
#
# --> Starting date:  2020-07-23 04:06
# --> Reference epoch of the solutions:  0.0  [JD]
# --> Results will be saved at:  SystemX.hdf5
#
# --------- Iteration:  50
#  Mean tau: 0.998
#  Accepted swap fraction in Temp 0:  0.057
#  Mean acceptance fraction Temp 0:  0.013
#  Mean posterior:  -18779.42608
#  Mean likelihood:  -18779.42608
#  Better Chi2:  (0, 82) -26.168837
#  Current mean Chi2 dispersion:  0.0
#  Saving...
#  Elapsed time:  0.264 min
# --------- Iteration:  100
#  Mean tau: 1.99
#  Accepted swap fraction in Temp 0:  0.04
#  Mean acceptance fraction Temp 0:  0.013
#  Mean posterior:  -9982.343042
#  Mean likelihood:  -9982.343042
#  Better Chi2:  (0, 82) -26.168837
#  Current mean Chi2 dispersion:  4398.541519
#  Saving...
#  Elapsed time:  0.5354 min
# --------- Iteration:  150
#  Mean tau: 2.983
#  Accepted swap fraction in Temp 0:  0.033
#  Mean acceptance fraction Temp 0:  0.014
#  Mean posterior:  -6190.415636
#  Mean likelihood:  -6190.415636
#  Better Chi2:  (0, 82) -26.168837
#  Current mean Chi2 dispersion:  1895.963703
#  Saving...
#  Elapsed time:  0.8075 min
# --------- Iteration:  200
#  Mean tau: 3.976
#  Accepted swap fraction in Temp 0:  0.028
#  Mean acceptance fraction Temp 0:  0.015
#  Mean posterior:  -4275.960858
#  Mean likelihood:  -4275.960858
#  Better Chi2:  (0, 82) 36.904364
#  Current mean Chi2 dispersion:  2371.278328
#  Saving...
#  Elapsed time:  1.086 min
# --------- Iteration:  250
#  Mean tau: 4.969
#  Accepted swap fraction in Temp 0:  0.025
#  Mean acceptance fraction Temp 0:  0.016
#  Mean posterior:  -3193.49988
#  Mean likelihood:  -3193.49988
#  Better Chi2:  (0, 82) 49.216066
#  Current mean Chi2 dispersion:  1239.101956
#  Saving...
#  Elapsed time:  1.3802 min
# --------- Iteration:  300
#  Mean tau: 5.959
#  Accepted swap fraction in Temp 0:  0.023
#  Mean acceptance fraction Temp 0:  0.016
#  Mean posterior:  -2360.52232
#  Mean likelihood:  -2360.52232
#  Better Chi2:  (0, 82) 49.216066
#  Current mean Chi2 dispersion:  1432.855587
#  Saving...
#  Elapsed time:  1.6584 min
# --------- Iteration:  350
#  Mean tau: 6.95
#  Accepted swap fraction in Temp 0:  0.021
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  -1726.226323
#  Mean likelihood:  -1726.226323
#  Better Chi2:  (0, 82) 49.216066
#  Current mean Chi2 dispersion:  954.949196
#  Saving...
#  Elapsed time:  1.9431 min
# --------- Iteration:  400
#  Mean tau: 7.94
#  Accepted swap fraction in Temp 0:  0.019
#  Mean acceptance fraction Temp 0:  0.019
#  Mean posterior:  -1310.208419
#  Mean likelihood:  -1310.208419
#  Better Chi2:  (0, 82) 49.216066
#  Current mean Chi2 dispersion:  1062.253302
#  Saving...
#  Elapsed time:  2.2565 min
# --------- Iteration:  450
#  Mean tau: 8.931
#  Accepted swap fraction in Temp 0:  0.018
#  Mean acceptance fraction Temp 0:  0.021
#  Mean posterior:  -957.585732
#  Mean likelihood:  -957.585732
#  Better Chi2:  (0, 82) 49.216066
#  Current mean Chi2 dispersion:  793.845978
#  Saving...
#  Elapsed time:  2.5403 min
# --------- Iteration:  500
#  Mean tau: 9.921
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -833.342025
#  Mean likelihood:  -833.342025
#  Better Chi2:  (0, 82) 49.216066
#  Current mean Chi2 dispersion:  828.276173
#  Saving...
#  Elapsed time:  2.8395 min
# --------- Iteration:  550
#  Mean tau: 10.91
#  Accepted swap fraction in Temp 0:  0.015
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -724.56756
#  Mean likelihood:  -724.56756
#  Better Chi2:  (0, 82) 49.216066
#  Current mean Chi2 dispersion:  573.078352
#  Saving...
#  Elapsed time:  3.1281 min
# --------- Iteration:  600
#  Mean tau: 11.9
#  Accepted swap fraction in Temp 0:  0.014
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -631.445242
#  Mean likelihood:  -631.445242
#  Better Chi2:  (0, 82) 58.131456
#  Current mean Chi2 dispersion:  582.532315
#  Saving...
#  Elapsed time:  3.4279 min
# --------- Iteration:  650
#  Mean tau: 12.89
#  Accepted swap fraction in Temp 0:  0.013
#  Mean acceptance fraction Temp 0:  0.025
#  Mean posterior:  -526.879774
#  Mean likelihood:  -526.879774
#  Better Chi2:  (0, 82) 58.131456
#  Current mean Chi2 dispersion:  392.201299
#  Saving...
#  Elapsed time:  3.7238 min
# --------- Iteration:  700
#  Mean tau: 13.881
#  Accepted swap fraction in Temp 0:  0.012
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -447.351307
#  Mean likelihood:  -447.351307
#  Better Chi2:  (0, 82) 58.131456
#  Current mean Chi2 dispersion:  403.95906
#  Saving...
#  Elapsed time:  4.0217 min
# --------- Iteration:  750
#  Mean tau: 14.871
#  Accepted swap fraction in Temp 0:  0.012
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -394.07891
#  Mean likelihood:  -394.07891
#  Better Chi2:  (0, 82) 58.131456
#  Current mean Chi2 dispersion:  283.466016
#  Saving...
#  Elapsed time:  4.3174 min
# --------- Iteration:  800
#  Mean tau: 15.861
#  Accepted swap fraction in Temp 0:  0.011
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -344.545601
#  Mean likelihood:  -344.545601
#  Better Chi2:  (0, 82) 58.131456
#  Current mean Chi2 dispersion:  293.190877
#  Saving...
#  Elapsed time:  4.6139 min
# --------- Iteration:  850
#  Mean tau: 16.85
#  Accepted swap fraction in Temp 0:  0.011
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -305.247191
#  Mean likelihood:  -305.247191
#  Better Chi2:  (0, 82) 58.131456
#  Current mean Chi2 dispersion:  214.961481
#  Saving...
#  Elapsed time:  4.9097 min
# --------- Iteration:  900
#  Mean tau: 17.84
#  Accepted swap fraction in Temp 0:  0.01
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -273.044037
#  Mean likelihood:  -273.044037
#  Better Chi2:  (0, 82) 58.131456
#  Current mean Chi2 dispersion:  223.010182
#  Saving...
#  Elapsed time:  5.2026 min
# --------- Iteration:  950
#  Mean tau: 18.83
#  Accepted swap fraction in Temp 0:  0.01
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -246.688579
#  Mean likelihood:  -246.688579
#  Better Chi2:  (0, 82) 55.653193
#  Current mean Chi2 dispersion:  190.752962
#  Saving...
#  Elapsed time:  5.4961 min
# --------- Iteration:  1000
#  Mean tau: 19.82
#  Accepted swap fraction in Temp 0:  0.009
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -226.895539
#  Mean likelihood:  -226.895539
#  Better Chi2:  (0, 82) 55.653193
#  Current mean Chi2 dispersion:  195.122933
#  Saving...
#  Elapsed time:  5.7951 min
# --------- Iteration:  1050
#  Mean tau: 20.81
#  Accepted swap fraction in Temp 0:  0.009
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -213.951754
#  Mean likelihood:  -213.951754
#  Better Chi2:  (0, 7) 56.320797
#  Current mean Chi2 dispersion:  163.249275
#  Saving...
#  Elapsed time:  6.0951 min
# --------- Iteration:  1100
#  Mean tau: 21.8
#  Accepted swap fraction in Temp 0:  0.009
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -203.612326
#  Mean likelihood:  -203.612326
#  Better Chi2:  (0, 7) 56.320797
#  Current mean Chi2 dispersion:  164.924857
#  Saving...
#  Elapsed time:  6.3934 min
# --------- Iteration:  1150
#  Mean tau: 22.79
#  Accepted swap fraction in Temp 0:  0.008
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -196.917808
#  Mean likelihood:  -196.917808
#  Better Chi2:  (0, 7) 56.320797
#  Current mean Chi2 dispersion:  134.19077
#  Saving...
#  Elapsed time:  6.7 min
# --------- Iteration:  1200
#  Mean tau: 23.78
#  Accepted swap fraction in Temp 0:  0.008
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -192.095766
#  Mean likelihood:  -192.095766
#  Better Chi2:  (0, 7) 56.320797
#  Current mean Chi2 dispersion:  134.373719
#  Saving...
#  Elapsed time:  6.9997 min
# --------- Iteration:  1250
#  Mean tau: 24.771
#  Accepted swap fraction in Temp 0:  0.008
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -184.035246
#  Mean likelihood:  -184.035246
#  Better Chi2:  (0, 7) 56.320797
#  Current mean Chi2 dispersion:  105.160991
#  Saving...
#  Elapsed time:  7.316 min
# --------- Iteration:  1300
#  Mean tau: 25.761
#  Accepted swap fraction in Temp 0:  0.008
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -179.190282
#  Mean likelihood:  -179.190282
#  Better Chi2:  (0, 7) 56.320797
#  Current mean Chi2 dispersion:  105.199047
#  Saving...
#  Elapsed time:  7.641 min
# --------- Iteration:  1350
#  Mean tau: 26.752
#  Accepted swap fraction in Temp 0:  0.007
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -172.893732
#  Mean likelihood:  -172.893732
#  Better Chi2:  (0, 82) 55.653193
#  Current mean Chi2 dispersion:  83.341993
#  Saving...
#  Elapsed time:  8.0031 min
# --------- Iteration:  1400
#  Mean tau: 27.742
#  Accepted swap fraction in Temp 0:  0.007
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -162.703591
#  Mean likelihood:  -162.703591
#  Better Chi2:  (0, 82) 55.653193
#  Current mean Chi2 dispersion:  83.794782
#  Saving...
#  Elapsed time:  8.3222 min
# --------- Iteration:  1450
#  Mean tau: 28.732
#  Accepted swap fraction in Temp 0:  0.007
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -154.931884
#  Mean likelihood:  -154.931884
#  Better Chi2:  (0, 82) 55.653193
#  Current mean Chi2 dispersion:  68.044187
#  Saving...
#  Elapsed time:  8.6272 min
# --------- Iteration:  1500
#  Mean tau: 29.721
#  Accepted swap fraction in Temp 0:  0.007
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -151.579588
#  Mean likelihood:  -151.579588
#  Better Chi2:  (0, 82) 58.101682
#  Current mean Chi2 dispersion:  68.567363
#  Saving...
#  Elapsed time:  9.0175 min
# --------- Iteration:  1550
#  Mean tau: 30.711
#  Accepted swap fraction in Temp 0:  0.006
#  Mean acceptance fraction Temp 0:  0.03
#  Mean posterior:  -147.394671
#  Mean likelihood:  -147.394671
#  Better Chi2:  (0, 7) 57.075088
#  Current mean Chi2 dispersion:  55.300143
#  Saving...
#  Elapsed time:  9.2975 min
# --------- Iteration:  1600
#  Mean tau: 31.701
#  Accepted swap fraction in Temp 0:  0.006
#  Mean acceptance fraction Temp 0:  0.03
#  Mean posterior:  -143.765117
#  Mean likelihood:  -143.765117
#  Better Chi2:  (0, 7) 57.075088
#  Current mean Chi2 dispersion:  55.849306
#  Saving...
#  Elapsed time:  9.6047 min
# --------- Iteration:  1650
#  Mean tau: 32.691
#  Accepted swap fraction in Temp 0:  0.006
#  Mean acceptance fraction Temp 0:  0.03
#  Mean posterior:  -140.282592
#  Mean likelihood:  -140.282592
#  Better Chi2:  (0, 7) 57.075088
#  Current mean Chi2 dispersion:  45.783885
#  Saving...
#  Elapsed time:  9.8872 min
# --------- Iteration:  1700
#  Mean tau: 33.681
#  Accepted swap fraction in Temp 0:  0.006
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -136.32218
#  Mean likelihood:  -136.32218
#  Better Chi2:  (0, 7) 57.075088
#  Current mean Chi2 dispersion:  46.403409
#  Saving...
#  Elapsed time:  10.2141 min
# --------- Iteration:  1750
#  Mean tau: 34.671
#  Accepted swap fraction in Temp 0:  0.006
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -132.297835
#  Mean likelihood:  -132.297835
#  Better Chi2:  (0, 7) 57.075088
#  Current mean Chi2 dispersion:  38.992049
#  Saving...
#  Elapsed time:  10.5777 min
# --------- Iteration:  1800
#  Mean tau: 35.661
#  Accepted swap fraction in Temp 0:  0.006
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -130.462054
#  Mean likelihood:  -130.462054
#  Better Chi2:  (0, 7) 57.075088
#  Current mean Chi2 dispersion:  39.596453
#  Saving...
#  Elapsed time:  10.9315 min
# --------- Iteration:  1850
#  Mean tau: 36.652
#  Accepted swap fraction in Temp 0:  0.006
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -126.551321
#  Mean likelihood:  -126.551321
#  Better Chi2:  (0, 82) 58.260753
#  Current mean Chi2 dispersion:  34.322586
#  Saving...
#  Elapsed time:  11.2675 min
# --------- Iteration:  1900
#  Mean tau: 37.642
#  Accepted swap fraction in Temp 0:  0.006
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -124.620628
#  Mean likelihood:  -124.620628
#  Better Chi2:  (0, 82) 58.260753
#  Current mean Chi2 dispersion:  34.926028
#  Saving...
#  Elapsed time:  11.6051 min
# --------- Iteration:  1950
#  Mean tau: 38.632
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -123.035171
#  Mean likelihood:  -123.035171
#  Better Chi2:  (0, 82) 58.260753
#  Current mean Chi2 dispersion:  31.265733
#  Saving...
#  Elapsed time:  11.9698 min
# --------- Iteration:  2000
#  Mean tau: 39.623
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -118.958935
#  Mean likelihood:  -118.958935
#  Better Chi2:  (0, 82) 58.260753
#  Current mean Chi2 dispersion:  31.870105
#  Saving...
#  Elapsed time:  12.3324 min
# --------- Iteration:  2050
#  Mean tau: 40.614
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -117.328973
#  Mean likelihood:  -117.328973
#  Better Chi2:  (0, 7) 54.321306
#  Current mean Chi2 dispersion:  29.382524
#  Saving...
#  Elapsed time:  12.6605 min
# --------- Iteration:  2100
#  Mean tau: 41.605
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.029
#  Mean posterior:  -115.427931
#  Mean likelihood:  -115.427931
#  Better Chi2:  (0, 7) 54.321306
#  Current mean Chi2 dispersion:  29.861288
#  Saving...
#  Elapsed time:  13.0033 min
# --------- Iteration:  2150
#  Mean tau: 42.597
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -112.851222
#  Mean likelihood:  -112.851222
#  Better Chi2:  (0, 7) 54.321306
#  Current mean Chi2 dispersion:  27.856133
#  Saving...
#  Elapsed time:  13.3443 min
# --------- Iteration:  2200
#  Mean tau: 43.588
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -111.272067
#  Mean likelihood:  -111.272067
#  Better Chi2:  (0, 82) 57.381477
#  Current mean Chi2 dispersion:  28.282512
#  Saving...
#  Elapsed time:  13.7058 min
# --------- Iteration:  2250
#  Mean tau: 44.578
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -108.723886
#  Mean likelihood:  -108.723886
#  Better Chi2:  (0, 82) 57.381477
#  Current mean Chi2 dispersion:  26.577183
#  Saving...
#  Elapsed time:  14.0053 min
# --------- Iteration:  2300
#  Mean tau: 45.569
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -107.026854
#  Mean likelihood:  -107.026854
#  Better Chi2:  (0, 82) 57.381477
#  Current mean Chi2 dispersion:  26.980018
#  Saving...
#  Elapsed time:  14.3677 min
# --------- Iteration:  2350
#  Mean tau: 46.561
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -105.170277
#  Mean likelihood:  -105.170277
#  Better Chi2:  (0, 82) 57.381477
#  Current mean Chi2 dispersion:  25.271309
#  Saving...
#  Elapsed time:  14.7054 min
# --------- Iteration:  2400
#  Mean tau: 47.551
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -103.27022
#  Mean likelihood:  -103.27022
#  Better Chi2:  (0, 82) 57.381477
#  Current mean Chi2 dispersion:  25.650885
#  Saving...
#  Elapsed time:  15.037 min
# --------- Iteration:  2450
#  Mean tau: 48.542
#  Accepted swap fraction in Temp 0:  0.005
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -101.528688
#  Mean likelihood:  -101.528688
#  Better Chi2:  (0, 82) 56.838896
#  Current mean Chi2 dispersion:  23.814719
#  Saving...
#  Elapsed time:  15.3688 min
# --------- Iteration:  2500
#  Mean tau: 49.534
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -100.452687
#  Mean likelihood:  -100.452687
#  Better Chi2:  (0, 82) 56.838896
#  Current mean Chi2 dispersion:  24.150087
#  Saving...
#  Elapsed time:  15.6943 min
# --------- Iteration:  2550
#  Mean tau: 50.486
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.028
#  Mean posterior:  -99.407777
#  Mean likelihood:  -99.407777
#  Better Chi2:  (0, 7) 57.571359
#  Current mean Chi2 dispersion:  22.457939
#  Saving...
#  Elapsed time:  16.021 min
# --------- Iteration:  2600
#  Mean tau: 51.401
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -98.118741
#  Mean likelihood:  -98.118741
#  Better Chi2:  (0, 82) 56.838896
#  Current mean Chi2 dispersion:  22.748169
#  Saving...
#  Elapsed time:  16.3478 min
# --------- Iteration:  2650
#  Mean tau: 52.281
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -97.172904
#  Mean likelihood:  -97.172904
#  Better Chi2:  (0, 82) 56.838896
#  Current mean Chi2 dispersion:  20.965386
#  Saving...
#  Elapsed time:  16.6781 min
# --------- Iteration:  2700
#  Mean tau: 53.128
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -96.471986
#  Mean likelihood:  -96.471986
#  Better Chi2:  (0, 82) 56.291434
#  Current mean Chi2 dispersion:  21.204605
#  Saving...
#  Elapsed time:  17.0351 min
# --------- Iteration:  2750
#  Mean tau: 53.945
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -94.943842
#  Mean likelihood:  -94.943842
#  Better Chi2:  (0, 7) 56.814535
#  Current mean Chi2 dispersion:  19.501285
#  Saving...
#  Elapsed time:  17.3728 min
# --------- Iteration:  2800
#  Mean tau: 54.732
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -94.119357
#  Mean likelihood:  -94.119357
#  Better Chi2:  (0, 7) 56.814535
#  Current mean Chi2 dispersion:  19.738655
#  Saving...
#  Elapsed time:  17.6867 min
# --------- Iteration:  2850
#  Mean tau: 55.491
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -93.42749
#  Mean likelihood:  -93.42749
#  Better Chi2:  (0, 7) 56.814535
#  Current mean Chi2 dispersion:  18.478405
#  Saving...
#  Elapsed time:  18.0454 min
# --------- Iteration:  2900
#  Mean tau: 56.223
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -92.109896
#  Mean likelihood:  -92.109896
#  Better Chi2:  (0, 7) 56.756088
#  Current mean Chi2 dispersion:  18.700184
#  Saving...
#  Elapsed time:  18.3752 min
# --------- Iteration:  2950
#  Mean tau: 56.93
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -90.619772
#  Mean likelihood:  -90.619772
#  Better Chi2:  (0, 7) 55.74821
#  Current mean Chi2 dispersion:  17.773886
#  Saving...
#  Elapsed time:  18.6874 min
# --------- Iteration:  3000
#  Mean tau: 57.614
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -89.877403
#  Mean likelihood:  -89.877403
#  Better Chi2:  (0, 7) 55.74821
#  Current mean Chi2 dispersion:  17.98948
#  Saving...
#  Elapsed time:  19.0275 min
# --------- Iteration:  3050
#  Mean tau: 58.275
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.027
#  Mean posterior:  -89.401926
#  Mean likelihood:  -89.401926
#  Better Chi2:  (0, 7) 54.405789
#  Current mean Chi2 dispersion:  17.022208
#  Saving...
#  Elapsed time:  19.335 min
# --------- Iteration:  3100
#  Mean tau: 58.915
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -89.273826
#  Mean likelihood:  -89.273826
#  Better Chi2:  (0, 7) 57.598578
#  Current mean Chi2 dispersion:  17.177039
#  Saving...
#  Elapsed time:  19.6517 min
# --------- Iteration:  3150
#  Mean tau: 59.534
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -88.687234
#  Mean likelihood:  -88.687234
#  Better Chi2:  (0, 7) 57.598578
#  Current mean Chi2 dispersion:  16.233333
#  Saving...
#  Elapsed time:  20.0085 min
# --------- Iteration:  3200
#  Mean tau: 60.133
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -88.122397
#  Mean likelihood:  -88.122397
#  Better Chi2:  (0, 7) 57.598578
#  Current mean Chi2 dispersion:  16.36381
#  Saving...
#  Elapsed time:  20.3636 min
# --------- Iteration:  3250
#  Mean tau: 60.715
#  Accepted swap fraction in Temp 0:  0.004
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -87.928947
#  Mean likelihood:  -87.928947
#  Better Chi2:  (0, 7) 57.598578
#  Current mean Chi2 dispersion:  15.42919
#  Saving...
#  Elapsed time:  20.6848 min
# --------- Iteration:  3300
#  Mean tau: 61.278
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -87.639603
#  Mean likelihood:  -87.639603
#  Better Chi2:  (0, 7) 56.165177
#  Current mean Chi2 dispersion:  15.521391
#  Saving...
#  Elapsed time:  21.0233 min
# --------- Iteration:  3350
#  Mean tau: 61.824
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -86.908801
#  Mean likelihood:  -86.908801
#  Better Chi2:  (0, 7) 56.165177
#  Current mean Chi2 dispersion:  14.614279
#  Saving...
#  Elapsed time:  21.3578 min
# --------- Iteration:  3400
#  Mean tau: 62.354
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -86.898811
#  Mean likelihood:  -86.898811
#  Better Chi2:  (0, 7) 56.165177
#  Current mean Chi2 dispersion:  14.686418
#  Saving...
#  Elapsed time:  21.6766 min
# --------- Iteration:  3450
#  Mean tau: 62.868
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -86.330776
#  Mean likelihood:  -86.330776
#  Better Chi2:  (0, 7) 56.165177
#  Current mean Chi2 dispersion:  13.842476
#  Saving...
#  Elapsed time:  22.0103 min
# --------- Iteration:  3500
#  Mean tau: 63.367
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -85.082859
#  Mean likelihood:  -85.082859
#  Better Chi2:  (0, 7) 56.165177
#  Current mean Chi2 dispersion:  13.935188
#  Saving...
#  Elapsed time:  22.344 min
# --------- Iteration:  3550
#  Mean tau: 63.852
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -83.737498
#  Mean likelihood:  -83.737498
#  Better Chi2:  (0, 7) 56.165177
#  Current mean Chi2 dispersion:  13.241993
#  Saving...
#  Elapsed time:  22.6477 min
# --------- Iteration:  3600
#  Mean tau: 64.324
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.026
#  Mean posterior:  -83.69345
#  Mean likelihood:  -83.69345
#  Better Chi2:  (0, 7) 57.306507
#  Current mean Chi2 dispersion:  13.338506
#  Saving...
#  Elapsed time:  22.997 min
# --------- Iteration:  3650
#  Mean tau: 64.781
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.025
#  Mean posterior:  -83.232012
#  Mean likelihood:  -83.232012
#  Better Chi2:  (0, 7) 57.306507
#  Current mean Chi2 dispersion:  12.592668
#  Saving...
#  Elapsed time:  23.3547 min
# --------- Iteration:  3700
#  Mean tau: 65.226
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.025
#  Mean posterior:  -82.889744
#  Mean likelihood:  -82.889744
#  Better Chi2:  (0, 7) 54.129882
#  Current mean Chi2 dispersion:  12.678845
#  Saving...
#  Elapsed time:  23.6737 min
# --------- Iteration:  3750
#  Mean tau: 65.659
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.025
#  Mean posterior:  -82.40112
#  Mean likelihood:  -82.40112
#  Better Chi2:  (0, 7) 54.129882
#  Current mean Chi2 dispersion:  12.035903
#  Saving...
#  Elapsed time:  24.0297 min
# --------- Iteration:  3800
#  Mean tau: 66.079
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.025
#  Mean posterior:  -81.962593
#  Mean likelihood:  -81.962593
#  Better Chi2:  (0, 7) 57.32232
#  Current mean Chi2 dispersion:  12.117789
#  Saving...
#  Elapsed time:  24.3474 min
# --------- Iteration:  3850
#  Mean tau: 66.488
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.025
#  Mean posterior:  -81.656499
#  Mean likelihood:  -81.656499
#  Better Chi2:  (0, 7) 57.32232
#  Current mean Chi2 dispersion:  11.461893
#  Saving...
#  Elapsed time:  24.6761 min
# --------- Iteration:  3900
#  Mean tau: 66.886
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.025
#  Mean posterior:  -81.668655
#  Mean likelihood:  -81.668655
#  Better Chi2:  (0, 7) 55.210032
#  Current mean Chi2 dispersion:  11.523883
#  Saving...
#  Elapsed time:  25.0331 min
# --------- Iteration:  3950
#  Mean tau: 67.273
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.025
#  Mean posterior:  -81.29216
#  Mean likelihood:  -81.29216
#  Better Chi2:  (0, 7) 55.53883
#  Current mean Chi2 dispersion:  10.826821
#  Saving...
#  Elapsed time:  25.3213 min
# --------- Iteration:  4000
#  Mean tau: 67.65
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.025
#  Mean posterior:  -81.056139
#  Mean likelihood:  -81.056139
#  Better Chi2:  (0, 7) 55.546618
#  Current mean Chi2 dispersion:  10.883829
#  Saving...
#  Elapsed time:  25.678 min
# --------- Iteration:  4050
#  Mean tau: 68.019
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.025
#  Mean posterior:  -80.134891
#  Mean likelihood:  -80.134891
#  Better Chi2:  (0, 82) 57.231271
#  Current mean Chi2 dispersion:  10.333711
#  Saving...
#  Elapsed time:  26.0035 min
# --------- Iteration:  4100
#  Mean tau: 68.379
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -80.109704
#  Mean likelihood:  -80.109704
#  Better Chi2:  (0, 7) 56.127023
#  Current mean Chi2 dispersion:  10.394782
#  Saving...
#  Elapsed time:  26.3298 min
# --------- Iteration:  4150
#  Mean tau: 68.73
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -79.404495
#  Mean likelihood:  -79.404495
#  Better Chi2:  (0, 82) 56.462826
#  Current mean Chi2 dispersion:  9.840316
#  Saving...
#  Elapsed time:  26.6838 min
# --------- Iteration:  4200
#  Mean tau: 69.073
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -79.554498
#  Mean likelihood:  -79.554498
#  Better Chi2:  (0, 7) 56.127023
#  Current mean Chi2 dispersion:  9.896064
#  Saving...
#  Elapsed time:  26.997 min
# --------- Iteration:  4250
#  Mean tau: 69.407
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -79.150366
#  Mean likelihood:  -79.150366
#  Better Chi2:  (0, 7) 56.127023
#  Current mean Chi2 dispersion:  9.344367
#  Saving...
#  Elapsed time:  27.3513 min
# --------- Iteration:  4300
#  Mean tau: 69.734
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -77.908819
#  Mean likelihood:  -77.908819
#  Better Chi2:  (0, 82) 54.969934
#  Current mean Chi2 dispersion:  9.42851
#  Saving...
#  Elapsed time:  27.6789 min
# --------- Iteration:  4350
#  Mean tau: 70.054
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -77.834954
#  Mean likelihood:  -77.834954
#  Better Chi2:  (0, 82) 53.256251
#  Current mean Chi2 dispersion:  8.956467
#  Saving...
#  Elapsed time:  28.0114 min
# --------- Iteration:  4400
#  Mean tau: 70.366
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -77.335311
#  Mean likelihood:  -77.335311
#  Better Chi2:  (0, 82) 53.256251
#  Current mean Chi2 dispersion:  9.035881
#  Saving...
#  Elapsed time:  28.3335 min
# --------- Iteration:  4450
#  Mean tau: 70.672
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -76.974381
#  Mean likelihood:  -76.974381
#  Better Chi2:  (0, 82) 53.256251
#  Current mean Chi2 dispersion:  8.578802
#  Saving...
#  Elapsed time:  28.644 min
# --------- Iteration:  4500
#  Mean tau: 70.971
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -75.959818
#  Mean likelihood:  -75.959818
#  Better Chi2:  (0, 82) 53.256251
#  Current mean Chi2 dispersion:  8.678657
#  Saving...
#  Elapsed time:  28.9998 min
# --------- Iteration:  4550
#  Mean tau: 71.264
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -75.721178
#  Mean likelihood:  -75.721178
#  Better Chi2:  (0, 7) 55.555742
#  Current mean Chi2 dispersion:  8.307588
#  Saving...
#  Elapsed time:  29.3034 min
# --------- Iteration:  4600
#  Mean tau: 71.55
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -74.786811
#  Mean likelihood:  -74.786811
#  Better Chi2:  (0, 7) 55.555742
#  Current mean Chi2 dispersion:  8.420094
#  Saving...
#  Elapsed time:  29.6544 min
# --------- Iteration:  4650
#  Mean tau: 71.831
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -73.621794
#  Mean likelihood:  -73.621794
#  Better Chi2:  (0, 7) 55.555742
#  Current mean Chi2 dispersion:  8.121169
#  Saving...
#  Elapsed time:  29.968 min
# --------- Iteration:  4700
#  Mean tau: 72.105
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -72.755845
#  Mean likelihood:  -72.755845
#  Better Chi2:  (0, 7) 55.555742
#  Current mean Chi2 dispersion:  8.272091
#  Saving...
#  Elapsed time:  30.31 min
# --------- Iteration:  4750
#  Mean tau: 72.374
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -72.253887
#  Mean likelihood:  -72.253887
#  Better Chi2:  (0, 7) 55.555742
#  Current mean Chi2 dispersion:  8.032299
#  Saving...
#  Elapsed time:  30.6276 min
# --------- Iteration:  4800
#  Mean tau: 72.636
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -71.876396
#  Mean likelihood:  -71.876396
#  Better Chi2:  (0, 7) 55.555742
#  Current mean Chi2 dispersion:  8.180574
#  Saving...
#  Elapsed time:  30.97 min
# --------- Iteration:  4850
#  Mean tau: 72.894
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -71.792837
#  Mean likelihood:  -71.792837
#  Better Chi2:  (0, 82) 56.230063
#  Current mean Chi2 dispersion:  7.97278
#  Saving...
#  Elapsed time:  31.2643 min
# --------- Iteration:  4900
#  Mean tau: 73.147
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -71.751147
#  Mean likelihood:  -71.751147
#  Better Chi2:  (0, 82) 56.230063
#  Current mean Chi2 dispersion:  8.094975
#  Saving...
#  Elapsed time:  31.6114 min
# --------- Iteration:  4950
#  Mean tau: 73.395
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -71.352346
#  Mean likelihood:  -71.352346
#  Better Chi2:  (0, 82) 56.230063
#  Current mean Chi2 dispersion:  7.91391
#  Saving...
#  Elapsed time:  31.9073 min
# --------- Iteration:  5000
#  Mean tau: 73.638
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.024
#  Mean posterior:  -70.175238
#  Mean likelihood:  -70.175238
#  Better Chi2:  (0, 82) 56.230063
#  Current mean Chi2 dispersion:  8.058393
#  Saving...
#  Elapsed time:  32.2526 min
# --------- Iteration:  5050
#  Mean tau: 73.876
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -70.209165
#  Mean likelihood:  -70.209165
#  Better Chi2:  (0, 82) 56.230063
#  Current mean Chi2 dispersion:  7.898139
#  Saving...
#  Elapsed time:  32.5467 min
# --------- Iteration:  5100
#  Mean tau: 74.11
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -70.238014
#  Mean likelihood:  -70.238014
#  Better Chi2:  (0, 82) 56.230063
#  Current mean Chi2 dispersion:  8.012151
#  Saving...
#  Elapsed time:  32.8677 min
# --------- Iteration:  5150
#  Mean tau: 74.339
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -70.064548
#  Mean likelihood:  -70.064548
#  Better Chi2:  (0, 82) 56.230063
#  Current mean Chi2 dispersion:  7.842521
#  Saving...
#  Elapsed time:  33.1961 min
# --------- Iteration:  5200
#  Mean tau: 74.564
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -69.472144
#  Mean likelihood:  -69.472144
#  Better Chi2:  (0, 7) 56.046573
#  Current mean Chi2 dispersion:  7.955067
#  Saving...
#  Elapsed time:  33.5046 min
# --------- Iteration:  5250
#  Mean tau: 74.785
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -68.543036
#  Mean likelihood:  -68.543036
#  Better Chi2:  (0, 7) 56.046573
#  Current mean Chi2 dispersion:  7.82945
#  Saving...
#  Elapsed time:  33.808 min
# --------- Iteration:  5300
#  Mean tau: 75.001
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -68.024153
#  Mean likelihood:  -68.024153
#  Better Chi2:  (0, 7) 56.046573
#  Current mean Chi2 dispersion:  7.959685
#  Saving...
#  Elapsed time:  34.1329 min
# --------- Iteration:  5350
#  Mean tau: 75.214
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -67.746843
#  Mean likelihood:  -67.746843
#  Better Chi2:  (0, 7) 56.046573
#  Current mean Chi2 dispersion:  7.842267
#  Saving...
#  Elapsed time:  34.4186 min
# --------- Iteration:  5400
#  Mean tau: 75.423
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -67.867778
#  Mean likelihood:  -67.867778
#  Better Chi2:  (0, 7) 56.046573
#  Current mean Chi2 dispersion:  7.951399
#  Saving...
#  Elapsed time:  34.7271 min
# --------- Iteration:  5450
#  Mean tau: 75.628
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -67.111166
#  Mean likelihood:  -67.111166
#  Better Chi2:  (0, 82) 55.345166
#  Current mean Chi2 dispersion:  7.829419
#  Saving...
#  Elapsed time:  35.072 min
# --------- Iteration:  5500
#  Mean tau: 75.83
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -67.185415
#  Mean likelihood:  -67.185415
#  Better Chi2:  (0, 82) 57.476767
#  Current mean Chi2 dispersion:  7.934826
#  Saving...
#  Elapsed time:  35.3773 min
# --------- Iteration:  5550
#  Mean tau: 76.028
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -66.910743
#  Mean likelihood:  -66.910743
#  Better Chi2:  (0, 82) 57.476767
#  Current mean Chi2 dispersion:  7.828138
#  Saving...
#  Elapsed time:  35.7225 min
# --------- Iteration:  5600
#  Mean tau: 76.223
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -66.333449
#  Mean likelihood:  -66.333449
#  Better Chi2:  (0, 82) 57.476767
#  Current mean Chi2 dispersion:  7.935291
#  Saving...
#  Elapsed time:  36.0082 min
# --------- Iteration:  5650
#  Mean tau: 76.415
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -65.567672
#  Mean likelihood:  -65.567672
#  Better Chi2:  (0, 82) 57.476767
#  Current mean Chi2 dispersion:  7.851597
#  Saving...
#  Elapsed time:  36.3515 min
# --------- Iteration:  5700
#  Mean tau: 76.604
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -65.225023
#  Mean likelihood:  -65.225023
#  Better Chi2:  (0, 82) 57.476767
#  Current mean Chi2 dispersion:  7.966802
#  Saving...
#  Elapsed time:  36.6956 min
# --------- Iteration:  5750
#  Mean tau: 76.789
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -65.508274
#  Mean likelihood:  -65.508274
#  Better Chi2:  (0, 82) 57.476767
#  Current mean Chi2 dispersion:  7.865902
#  Saving...
#  Elapsed time:  36.9797 min
# --------- Iteration:  5800
#  Mean tau: 76.971
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -64.447389
#  Mean likelihood:  -64.447389
#  Better Chi2:  (0, 82) 57.167146
#  Current mean Chi2 dispersion:  7.980727
#  Saving...
#  Elapsed time:  37.2825 min
# --------- Iteration:  5850
#  Mean tau: 77.15
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -63.738244
#  Mean likelihood:  -63.738244
#  Better Chi2:  (0, 82) 57.167146
#  Current mean Chi2 dispersion:  7.931222
#  Saving...
#  Elapsed time:  37.5932 min
# --------- Iteration:  5900
#  Mean tau: 77.325
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -63.553844
#  Mean likelihood:  -63.553844
#  Better Chi2:  (0, 82) 56.863558
#  Current mean Chi2 dispersion:  8.047334
#  Saving...
#  Elapsed time:  37.9396 min
# --------- Iteration:  5950
#  Mean tau: 77.498
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.023
#  Mean posterior:  -62.186907
#  Mean likelihood:  -62.186907
#  Better Chi2:  (0, 82) 56.863558
#  Current mean Chi2 dispersion:  8.047478
#  Saving...
#  Elapsed time:  38.2828 min
# --------- Iteration:  6000
#  Mean tau: 77.668
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -60.964163
#  Mean likelihood:  -60.964163
#  Better Chi2:  (0, 7) 54.581461
#  Current mean Chi2 dispersion:  8.211454
#  Saving...
#  Elapsed time:  38.5813 min
# --------- Iteration:  6050
#  Mean tau: 77.835
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -60.388936
#  Mean likelihood:  -60.388936
#  Better Chi2:  (0, 82) 53.439258
#  Current mean Chi2 dispersion:  8.24346
#  Saving...
#  Elapsed time:  38.8956 min
# --------- Iteration:  6100
#  Mean tau: 78.0
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -59.391546
#  Mean likelihood:  -59.391546
#  Better Chi2:  (0, 7) 55.472107
#  Current mean Chi2 dispersion:  8.422809
#  Saving...
#  Elapsed time:  39.1951 min
# --------- Iteration:  6150
#  Mean tau: 78.161
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -58.977554
#  Mean likelihood:  -58.977554
#  Better Chi2:  (0, 7) 55.472107
#  Current mean Chi2 dispersion:  8.465945
#  Saving...
#  Elapsed time:  39.5157 min
# --------- Iteration:  6200
#  Mean tau: 78.32
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -57.068088
#  Mean likelihood:  -57.068088
#  Better Chi2:  (0, 7) 55.472107
#  Current mean Chi2 dispersion:  8.682372
#  Saving...
#  Elapsed time:  39.842 min
# --------- Iteration:  6250
#  Mean tau: 78.477
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -56.23051
#  Mean likelihood:  -56.23051
#  Better Chi2:  (0, 82) 55.809174
#  Current mean Chi2 dispersion:  8.766094
#  Saving...
#  Elapsed time:  40.1827 min
# --------- Iteration:  6300
#  Mean tau: 78.63
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -55.937764
#  Mean likelihood:  -55.937764
#  Better Chi2:  (0, 7) 56.314415
#  Current mean Chi2 dispersion:  8.977559
#  Saving...
#  Elapsed time:  40.5024 min
# --------- Iteration:  6350
#  Mean tau: 78.782
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -56.055598
#  Mean likelihood:  -56.055598
#  Better Chi2:  (0, 7) 56.314415
#  Current mean Chi2 dispersion:  9.032807
#  Saving...
#  Elapsed time:  40.7992 min
# --------- Iteration:  6400
#  Mean tau: 78.931
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -55.188168
#  Mean likelihood:  -55.188168
#  Better Chi2:  (0, 7) 56.314415
#  Current mean Chi2 dispersion:  9.229958
#  Saving...
#  Elapsed time:  41.1188 min
# --------- Iteration:  6450
#  Mean tau: 79.078
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -55.068398
#  Mean likelihood:  -55.068398
#  Better Chi2:  (0, 7) 56.314415
#  Current mean Chi2 dispersion:  9.28309
#  Saving...
#  Elapsed time:  41.4277 min
# --------- Iteration:  6500
#  Mean tau: 79.223
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -54.411968
#  Mean likelihood:  -54.411968
#  Better Chi2:  (0, 7) 56.314415
#  Current mean Chi2 dispersion:  9.468329
#  Saving...
#  Elapsed time:  41.7335 min
# --------- Iteration:  6550
#  Mean tau: 79.365
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -54.560671
#  Mean likelihood:  -54.560671
#  Better Chi2:  (0, 7) 56.314415
#  Current mean Chi2 dispersion:  9.497095
#  Saving...
#  Elapsed time:  42.0422 min
# --------- Iteration:  6600
#  Mean tau: 79.505
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -54.195512
#  Mean likelihood:  -54.195512
#  Better Chi2:  (0, 82) 57.010884
#  Current mean Chi2 dispersion:  9.6575
#  Saving...
#  Elapsed time:  42.3624 min
# --------- Iteration:  6650
#  Mean tau: 79.643
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -54.026866
#  Mean likelihood:  -54.026866
#  Better Chi2:  (0, 82) 56.017498
#  Current mean Chi2 dispersion:  9.667299
#  Saving...
#  Elapsed time:  42.6864 min
# --------- Iteration:  6700
#  Mean tau: 79.779
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -53.777632
#  Mean likelihood:  -53.777632
#  Better Chi2:  (0, 7) 57.213408
#  Current mean Chi2 dispersion:  9.811555
#  Saving...
#  Elapsed time:  43.0002 min
# --------- Iteration:  6750
#  Mean tau: 79.913
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -53.467672
#  Mean likelihood:  -53.467672
#  Better Chi2:  (0, 7) 57.213408
#  Current mean Chi2 dispersion:  9.815919
#  Saving...
#  Elapsed time:  43.3132 min
# --------- Iteration:  6800
#  Mean tau: 80.045
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -53.194315
#  Mean likelihood:  -53.194315
#  Better Chi2:  (0, 7) 57.213408
#  Current mean Chi2 dispersion:  9.95007
#  Saving...
#  Elapsed time:  43.6569 min
# --------- Iteration:  6850
#  Mean tau: 80.175
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -52.623497
#  Mean likelihood:  -52.623497
#  Better Chi2:  (0, 7) 57.248628
#  Current mean Chi2 dispersion:  9.938877
#  Saving...
#  Elapsed time:  44.0015 min
# --------- Iteration:  6900
#  Mean tau: 80.303
#  Accepted swap fraction in Temp 0:  0.002
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -52.123131
#  Mean likelihood:  -52.123131
#  Better Chi2:  (0, 7) 57.248628
#  Current mean Chi2 dispersion:  10.075682
#  Saving...
#  Elapsed time:  44.2951 min
# --------- Iteration:  6950
#  Mean tau: 80.429
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -51.966699
#  Mean likelihood:  -51.966699
#  Better Chi2:  (0, 7) 57.248628
#  Current mean Chi2 dispersion:  10.05858
#  Saving...
#  Elapsed time:  44.6084 min
# --------- Iteration:  7000
#  Mean tau: 80.554
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -51.460341
#  Mean likelihood:  -51.460341
#  Better Chi2:  (0, 7) 57.248628
#  Current mean Chi2 dispersion:  10.188561
#  Saving...
#  Elapsed time:  44.9266 min
# --------- Iteration:  7050
#  Mean tau: 80.676
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -51.523595
#  Mean likelihood:  -51.523595
#  Better Chi2:  (0, 7) 57.248628
#  Current mean Chi2 dispersion:  10.177991
#  Saving...
#  Elapsed time:  45.2414 min
# --------- Iteration:  7100
#  Mean tau: 80.796
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -51.647958
#  Mean likelihood:  -51.647958
#  Better Chi2:  (0, 7) 57.248628
#  Current mean Chi2 dispersion:  10.283152
#  Saving...
#  Elapsed time:  45.5584 min
# --------- Iteration:  7150
#  Mean tau: 80.915
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -50.832259
#  Mean likelihood:  -50.832259
#  Better Chi2:  (0, 7) 57.899408
#  Current mean Chi2 dispersion:  10.287635
#  Saving...
#  Elapsed time:  45.9007 min
# --------- Iteration:  7200
#  Mean tau: 81.033
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -50.365584
#  Mean likelihood:  -50.365584
#  Better Chi2:  (0, 7) 57.540823
#  Current mean Chi2 dispersion:  10.401693
#  Saving...
#  Elapsed time:  46.1918 min
# --------- Iteration:  7250
#  Mean tau: 81.148
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -49.75185
#  Mean likelihood:  -49.75185
#  Better Chi2:  (0, 7) 57.464159
#  Current mean Chi2 dispersion:  10.400446
#  Saving...
#  Elapsed time:  46.5331 min
# --------- Iteration:  7300
#  Mean tau: 81.262
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -49.181153
#  Mean likelihood:  -49.181153
#  Better Chi2:  (0, 7) 57.464159
#  Current mean Chi2 dispersion:  10.520867
#  Saving...
#  Elapsed time:  46.8681 min
# --------- Iteration:  7350
#  Mean tau: 81.374
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -49.58134
#  Mean likelihood:  -49.58134
#  Better Chi2:  (0, 7) 57.464159
#  Current mean Chi2 dispersion:  10.503336
#  Saving...
#  Elapsed time:  47.1763 min
# --------- Iteration:  7400
#  Mean tau: 81.484
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -48.808742
#  Mean likelihood:  -48.808742
#  Better Chi2:  (0, 7) 57.464159
#  Current mean Chi2 dispersion:  10.612991
#  Saving...
#  Elapsed time:  47.4844 min
# --------- Iteration:  7450
#  Mean tau: 81.592
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -48.521527
#  Mean likelihood:  -48.521527
#  Better Chi2:  (0, 7) 57.464159
#  Current mean Chi2 dispersion:  10.596271
#  Saving...
#  Elapsed time:  47.7914 min
# --------- Iteration:  7500
#  Mean tau: 81.7
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -48.585218
#  Mean likelihood:  -48.585218
#  Better Chi2:  (0, 82) 53.202806
#  Current mean Chi2 dispersion:  10.693014
#  Saving...
#  Elapsed time:  48.0975 min
# --------- Iteration:  7550
#  Mean tau: 81.806
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -48.187391
#  Mean likelihood:  -48.187391
#  Better Chi2:  (0, 82) 53.202806
#  Current mean Chi2 dispersion:  10.665743
#  Saving...
#  Elapsed time:  48.4102 min
# --------- Iteration:  7600
#  Mean tau: 81.91
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -48.164819
#  Mean likelihood:  -48.164819
#  Better Chi2:  (0, 82) 57.66755
#  Current mean Chi2 dispersion:  10.754936
#  Saving...
#  Elapsed time:  48.7531 min
# --------- Iteration:  7650
#  Mean tau: 82.013
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.022
#  Mean posterior:  -47.70411
#  Mean likelihood:  -47.70411
#  Better Chi2:  (0, 82) 56.393024
#  Current mean Chi2 dispersion:  10.719935
#  Saving...
#  Elapsed time:  49.0666 min
# --------- Iteration:  7700
#  Mean tau: 82.115
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.021
#  Mean posterior:  -47.272824
#  Mean likelihood:  -47.272824
#  Better Chi2:  (0, 30) 55.032262
#  Current mean Chi2 dispersion:  10.811409
#  Saving...
#  Elapsed time:  49.3762 min
# --------- Iteration:  7750
#  Mean tau: 82.216
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.021
#  Mean posterior:  -46.683236
#  Mean likelihood:  -46.683236
#  Better Chi2:  (0, 82) 57.270963
#  Current mean Chi2 dispersion:  10.776544
#  Saving...
#  Elapsed time:  49.6933 min
# --------- Iteration:  7800
#  Mean tau: 82.315
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.021
#  Mean posterior:  -46.419109
#  Mean likelihood:  -46.419109
#  Better Chi2:  (0, 82) 57.270963
#  Current mean Chi2 dispersion:  10.869411
#  Saving...
#  Elapsed time:  50.0157 min
# --------- Iteration:  7850
#  Mean tau: 82.412
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.021
#  Mean posterior:  -46.243556
#  Mean likelihood:  -46.243556
#  Better Chi2:  (0, 82) 57.270963
#  Current mean Chi2 dispersion:  10.816261
#  Saving...
#  Elapsed time:  50.3177 min
# --------- Iteration:  7900
#  Mean tau: 82.509
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.021
#  Mean posterior:  -45.740631
#  Mean likelihood:  -45.740631
#  Better Chi2:  (0, 82) 57.270963
#  Current mean Chi2 dispersion:  10.907528
#  Saving...
#  Elapsed time:  50.6177 min
# --------- Iteration:  7950
#  Mean tau: 82.604
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.021
#  Mean posterior:  -44.541626
#  Mean likelihood:  -44.541626
#  Better Chi2:  (0, 30) 54.31432
#  Current mean Chi2 dispersion:  10.86919
#  Saving...
#  Elapsed time:  50.9104 min
# --------- Iteration:  8000
#  Mean tau: 82.697
#  Accepted swap fraction in Temp 0:  0.003
# ...
#  Current mean Chi2 dispersion:  11.517607
#  Saving...
#  Elapsed time:  289.1763 min
# --------- Iteration:  47450
#  Mean tau: 52.331
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.046354
#  Mean likelihood:  44.046354
#  Better Chi2:  (0, 54) 104.478001
#  Current mean Chi2 dispersion:  11.496701
#  Saving...
#  Elapsed time:  289.4706 min
# --------- Iteration:  47500
#  Mean tau: 51.496
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  43.979899
#  Mean likelihood:  43.979899
#  Better Chi2:  (0, 54) 104.756408
#  Current mean Chi2 dispersion:  11.510141
#  Saving...
#  Elapsed time:  289.7549 min
# --------- Iteration:  47550
#  Mean tau: 50.629
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.153723
#  Mean likelihood:  44.153723
#  Better Chi2:  (0, 42) 105.285058
#  Current mean Chi2 dispersion:  11.488131
#  Saving...
#  Elapsed time:  290.0755 min
# --------- Iteration:  47600
#  Mean tau: 49.768
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.63059
#  Mean likelihood:  44.63059
#  Better Chi2:  (0, 42) 106.59868
#  Current mean Chi2 dispersion:  11.503217
#  Saving...
#  Elapsed time:  290.4011 min
# --------- Iteration:  47650
#  Mean tau: 48.912
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.499733
#  Mean likelihood:  44.499733
#  Better Chi2:  (0, 42) 106.59868
#  Current mean Chi2 dispersion:  11.482337
#  Saving...
#  Elapsed time:  290.7027 min
# --------- Iteration:  47700
#  Mean tau: 48.061
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.791047
#  Mean likelihood:  44.791047
#  Better Chi2:  (0, 42) 106.65145
#  Current mean Chi2 dispersion:  11.497538
#  Saving...
#  Elapsed time:  290.9695 min
# --------- Iteration:  47750
#  Mean tau: 47.214
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.492931
#  Mean likelihood:  44.492931
#  Better Chi2:  (0, 42) 107.886705
#  Current mean Chi2 dispersion:  11.476267
#  Saving...
#  Elapsed time:  291.2595 min
# --------- Iteration:  47800
#  Mean tau: 46.374
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.569512
#  Mean likelihood:  44.569512
#  Better Chi2:  (0, 42) 107.962882
#  Current mean Chi2 dispersion:  11.490399
#  Saving...
#  Elapsed time:  291.5604 min
# --------- Iteration:  47850
#  Mean tau: 45.541
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.659358
#  Mean likelihood:  44.659358
#  Better Chi2:  (0, 42) 106.470603
#  Current mean Chi2 dispersion:  11.468166
#  Saving...
#  Elapsed time:  291.8847 min
# --------- Iteration:  47900
#  Mean tau: 44.713
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.781037
#  Mean likelihood:  44.781037
#  Better Chi2:  (0, 42) 106.761739
#  Current mean Chi2 dispersion:  11.48258
#  Saving...
#  Elapsed time:  292.161 min
# --------- Iteration:  47950
#  Mean tau: 43.891
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.326703
#  Mean likelihood:  44.326703
#  Better Chi2:  (0, 42) 105.343892
#  Current mean Chi2 dispersion:  11.458902
#  Saving...
#  Elapsed time:  292.4719 min
# --------- Iteration:  48000
#  Mean tau: 43.078
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.752139
#  Mean likelihood:  44.752139
#  Better Chi2:  (0, 17) 106.919846
#  Current mean Chi2 dispersion:  11.472866
#  Saving...
#  Elapsed time:  292.7869 min
# --------- Iteration:  48050
#  Mean tau: 42.272
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.764662
#  Mean likelihood:  44.764662
#  Better Chi2:  (0, 17) 106.888606
#  Current mean Chi2 dispersion:  11.450034
#  Saving...
#  Elapsed time:  293.0449 min
# --------- Iteration:  48100
#  Mean tau: 41.473
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  44.755803
#  Mean likelihood:  44.755803
#  Better Chi2:  (0, 40) 106.53866
#  Current mean Chi2 dispersion:  11.46365
#  Saving...
#  Elapsed time:  293.3619 min
# --------- Iteration:  48150
#  Mean tau: 40.684
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.39823
#  Mean likelihood:  45.39823
#  Better Chi2:  (0, 17) 107.452983
#  Current mean Chi2 dispersion:  11.44253
#  Saving...
#  Elapsed time:  293.6396 min
# --------- Iteration:  48200
#  Mean tau: 39.902
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.159439
#  Mean likelihood:  45.159439
#  Better Chi2:  (0, 17) 107.206128
#  Current mean Chi2 dispersion:  11.457012
#  Saving...
#  Elapsed time:  293.9433 min
# --------- Iteration:  48250
#  Mean tau: 39.13
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.204933
#  Mean likelihood:  45.204933
#  Better Chi2:  (0, 17) 106.122119
#  Current mean Chi2 dispersion:  11.435603
#  Saving...
#  Elapsed time:  294.2257 min
# --------- Iteration:  48300
#  Mean tau: 38.368
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.279142
#  Mean likelihood:  45.279142
#  Better Chi2:  (0, 17) 107.144001
#  Current mean Chi2 dispersion:  11.450082
#  Saving...
#  Elapsed time:  294.5138 min
# --------- Iteration:  48350
#  Mean tau: 37.615
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.620759
#  Mean likelihood:  45.620759
#  Better Chi2:  (0, 17) 107.162718
#  Current mean Chi2 dispersion:  11.429861
#  Saving...
#  Elapsed time:  294.8195 min
# --------- Iteration:  48400
#  Mean tau: 36.876
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.227509
#  Mean likelihood:  45.227509
#  Better Chi2:  (0, 54) 107.337609
#  Current mean Chi2 dispersion:  11.443809
#  Saving...
#  Elapsed time:  295.1197 min
# --------- Iteration:  48450
#  Mean tau: 36.149
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.457338
#  Mean likelihood:  45.457338
#  Better Chi2:  (0, 42) 107.392736
#  Current mean Chi2 dispersion:  11.422485
#  Saving...
#  Elapsed time:  295.392 min
# --------- Iteration:  48500
#  Mean tau: 35.433
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.655878
#  Mean likelihood:  45.655878
#  Better Chi2:  (0, 54) 107.324462
#  Current mean Chi2 dispersion:  11.437382
#  Saving...
#  Elapsed time:  295.708 min
# --------- Iteration:  48550
#  Mean tau: 34.731
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.658163
#  Mean likelihood:  45.658163
#  Better Chi2:  (0, 54) 107.20063
#  Current mean Chi2 dispersion:  11.415749
#  Saving...
#  Elapsed time:  296.0166 min
# --------- Iteration:  48600
#  Mean tau: 34.044
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.323964
#  Mean likelihood:  45.323964
#  Better Chi2:  (0, 54) 107.20063
#  Current mean Chi2 dispersion:  11.429266
#  Saving...
#  Elapsed time:  296.2965 min
# --------- Iteration:  48650
#  Mean tau: 33.372
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.6983
#  Mean likelihood:  45.6983
#  Better Chi2:  (0, 54) 107.20063
#  Current mean Chi2 dispersion:  11.408074
#  Saving...
#  Elapsed time:  296.6212 min
# --------- Iteration:  48700
#  Mean tau: 32.718
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.63588
#  Mean likelihood:  45.63588
#  Better Chi2:  (0, 54) 107.237371
#  Current mean Chi2 dispersion:  11.422179
#  Saving...
#  Elapsed time:  296.9106 min
# --------- Iteration:  48750
#  Mean tau: 32.082
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.851319
#  Mean likelihood:  45.851319
#  Better Chi2:  (0, 17) 107.621871
#  Current mean Chi2 dispersion:  11.401598
#  Saving...
#  Elapsed time:  297.1878 min
# --------- Iteration:  48800
#  Mean tau: 31.468
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.781202
#  Mean likelihood:  45.781202
#  Better Chi2:  (0, 40) 107.176171
#  Current mean Chi2 dispersion:  11.415782
#  Saving...
#  Elapsed time:  297.4842 min
# --------- Iteration:  48850
#  Mean tau: 30.875
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.807604
#  Mean likelihood:  45.807604
#  Better Chi2:  (0, 40) 106.608635
#  Current mean Chi2 dispersion:  11.395125
#  Saving...
#  Elapsed time:  297.7622 min
# --------- Iteration:  48900
#  Mean tau: 30.306
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.683476
#  Mean likelihood:  45.683476
#  Better Chi2:  (0, 40) 106.608635
#  Current mean Chi2 dispersion:  11.408657
#  Saving...
#  Elapsed time:  298.0692 min
# --------- Iteration:  48950
#  Mean tau: 29.763
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.797189
#  Mean likelihood:  45.797189
#  Better Chi2:  (0, 40) 106.608635
#  Current mean Chi2 dispersion:  11.386572
#  Saving...
#  Elapsed time:  298.3461 min
# --------- Iteration:  49000
#  Mean tau: 29.249
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.465893
#  Mean likelihood:  45.465893
#  Better Chi2:  (0, 64) 106.744485
#  Current mean Chi2 dispersion:  11.399117
#  Saving...
#  Elapsed time:  298.6736 min
# --------- Iteration:  49050
#  Mean tau: 28.769
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.639932
#  Mean likelihood:  45.639932
#  Better Chi2:  (0, 40) 106.972884
#  Current mean Chi2 dispersion:  11.376236
#  Saving...
#  Elapsed time:  298.9519 min
# --------- Iteration:  49100
#  Mean tau: 28.325
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.876606
#  Mean likelihood:  45.876606
#  Better Chi2:  (0, 40) 106.972884
#  Current mean Chi2 dispersion:  11.389665
#  Saving...
#  Elapsed time:  299.2489 min
# --------- Iteration:  49150
#  Mean tau: 27.92
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.89652
#  Mean likelihood:  45.89652
#  Better Chi2:  (0, 40) 106.948081
#  Current mean Chi2 dispersion:  11.368599
#  Saving...
#  Elapsed time:  299.5351 min
# --------- Iteration:  49200
#  Mean tau: 27.561
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.607401
#  Mean likelihood:  45.607401
#  Better Chi2:  (0, 40) 107.688541
#  Current mean Chi2 dispersion:  11.380898
#  Saving...
#  Elapsed time:  299.8258 min
# --------- Iteration:  49250
#  Mean tau: 27.253
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.866851
#  Mean likelihood:  45.866851
#  Better Chi2:  (0, 42) 107.14044
#  Current mean Chi2 dispersion:  11.360278
#  Saving...
#  Elapsed time:  300.1329 min
# --------- Iteration:  49300
#  Mean tau: 27.004
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.877625
#  Mean likelihood:  45.877625
#  Better Chi2:  (0, 40) 107.156766
#  Current mean Chi2 dispersion:  11.373038
#  Saving...
#  Elapsed time:  300.4381 min
# --------- Iteration:  49350
#  Mean tau: 26.822
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  45.956065
#  Mean likelihood:  45.956065
#  Better Chi2:  (0, 40) 107.156766
#  Current mean Chi2 dispersion:  11.352168
#  Saving...
#  Elapsed time:  300.7276 min
# --------- Iteration:  49400
#  Mean tau: 26.719
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  46.118853
#  Mean likelihood:  46.118853
#  Better Chi2:  (0, 42) 106.211823
#  Current mean Chi2 dispersion:  11.365307
#  Saving...
#  Elapsed time:  301.027 min
# --------- Iteration:  49450
#  Mean tau: 26.708
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  46.242805
#  Mean likelihood:  46.242805
#  Better Chi2:  (0, 22) 106.58192
#  Current mean Chi2 dispersion:  11.344758
#  Saving...
#  Elapsed time:  301.3397 min
# --------- Iteration:  49500
#  Mean tau: 26.807
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  46.043577
#  Mean likelihood:  46.043577
#  Better Chi2:  (0, 22) 107.114938
#  Current mean Chi2 dispersion:  11.357342
#  Saving...
#  Elapsed time:  301.6366 min
# --------- Iteration:  49550
#  Mean tau: 27.038
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  46.328155
#  Mean likelihood:  46.328155
#  Better Chi2:  (0, 17) 106.750838
#  Current mean Chi2 dispersion:  11.33817
#  Saving...
#  Elapsed time:  301.9195 min
# --------- Iteration:  49600
#  Mean tau: 27.432
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  46.343182
#  Mean likelihood:  46.343182
#  Better Chi2:  (0, 22) 107.222947
#  Current mean Chi2 dispersion:  11.3513
#  Saving...
#  Elapsed time:  302.1967 min
# --------- Iteration:  49650
#  Mean tau: 28.031
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  46.606392
#  Mean likelihood:  46.606392
#  Better Chi2:  (0, 22) 107.012514
#  Current mean Chi2 dispersion:  11.332948
#  Saving...
#  Elapsed time:  302.5231 min
# --------- Iteration:  49700
#  Mean tau: 28.893
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  46.59634
#  Mean likelihood:  46.59634
#  Better Chi2:  (0, 22) 107.012514
#  Current mean Chi2 dispersion:  11.346485
#  Saving...
#  Elapsed time:  302.7961 min
# --------- Iteration:  49750
#  Mean tau: 30.108
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  46.80987
#  Mean likelihood:  46.80987
#  Better Chi2:  (0, 22) 107.061434
#  Current mean Chi2 dispersion:  11.329031
#  Saving...
#  Elapsed time:  303.1075 min
# --------- Iteration:  49800
#  Mean tau: 31.818
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  46.67778
#  Mean likelihood:  46.67778
#  Better Chi2:  (0, 22) 107.061434
#  Current mean Chi2 dispersion:  11.342463
#  Saving...
#  Elapsed time:  303.3677 min
# --------- Iteration:  49850
#  Mean tau: 34.273
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  46.81307
#  Mean likelihood:  46.81307
#  Better Chi2:  (0, 40) 106.922792
#  Current mean Chi2 dispersion:  11.324341
#  Saving...
#  Elapsed time:  303.6931 min
# --------- Iteration:  49900
#  Mean tau: 37.982
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  47.123452
#  Mean likelihood:  47.123452
#  Better Chi2:  (0, 22) 107.222451
#  Current mean Chi2 dispersion:  11.338757
#  Saving...
#  Elapsed time:  303.9755 min
# --------- Iteration:  49950
#  Mean tau: 44.304
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  47.267844
#  Mean likelihood:  47.267844
#  Better Chi2:  (0, 40) 108.306379
#  Current mean Chi2 dispersion:  11.32098
#  Saving...
#  Elapsed time:  304.2969 min
# --------- Iteration:  50000
#  Mean tau: 63.283
#  Accepted swap fraction in Temp 0:  0.003
#  Mean acceptance fraction Temp 0:  0.018
#  Mean posterior:  47.363868
#  Mean likelihood:  47.363868
#  Better Chi2:  (0, 40) 108.306379
#  Current mean Chi2 dispersion:  11.335763
#  Saving...
#  Elapsed time:  304.5788 min
#
# --> Maximum number of iterations reached in MCMC
# --> Best solutions from the SystemX.hdf5 will be written at: SystemX.best
# --> Reference epoch of the solutions:  0.0  [JD]
# --> Iterations performed:  50000
# --> Elapsed time in MCMC: 304.585 minutes

# %%
--------- Iteration:  50000
 Mean tau: 63.283
 Accepted swap fraction in Temp 0:  0.003
 Mean acceptance fraction Temp 0:  0.018
 Mean posterior:  47.363868
 Mean likelihood:  47.363868
 Better Chi2:  (0, 40) 108.306379
 Current mean Chi2 dispersion:  11.335763
 Saving...
 Elapsed time:  304.5788 min

# %% [markdown]
# After the MCMC ends, let's consult the attributes in the RESULTS_mcmc variable:

# %%
# Save the attributes as a dictionary
results_dictionary = RESULTS_mcmc.__dict__ 

# Available attributes of the MCMC
results_dictionary.keys()
# Out:
# dict_keys(['_random', '_likeprior', 'a', 'nwalkers', 'dim', 'adaptation_time', 'adaptation_lag', '_betas', 'pool', '_chain', '_logposterior', '_loglikelihood', '_beta_history', '_time', '_p0', '_logposterior0', '_loglikelihood0', 'nswap', 'nswap_accepted', 'nprop', 'nprop_accepted'])

# %% [markdown]
# Let's print many results from the attributes above:

# %%
# The chains 
results_dictionary['_chain'] # shape: (ntemps, nwalkers, steps, ndim)
# Out:
# array([[[[8.62654168e-01, 9.97669178e-01, 5.47343882e-01, ...,
#           8.39244215e-01, 3.93733829e-01, 5.42521431e-01],
#          [8.59774779e-01, 9.96950928e-01, 5.47363277e-01, ...,
#           8.38364213e-01, 3.94700250e-01, 5.41521370e-01],
#          [8.49782810e-01, 9.96103148e-01, 5.40587163e-01, ...,
#           8.38457689e-01, 3.94843365e-01, 5.42808834e-01],
#          ...,
#          [4.52076806e-01, 9.94421467e-01, 7.40341687e-01, ...,
#           4.35344283e-01, 8.29503192e-01, 6.43219681e-01],
#          [4.52076806e-01, 9.94421467e-01, 7.40341687e-01, ...,
#           4.35344283e-01, 8.29503192e-01, 6.43219681e-01],
#          [4.52076806e-01, 9.94421467e-01, 7.40341687e-01, ...,
#           4.35344283e-01, 8.29503192e-01, 6.43219681e-01]],
#
#         [[4.08509725e-01, 9.97841328e-01, 7.92486262e-01, ...,
#           4.26705519e-01, 8.34689795e-01, 6.55611942e-01],
#          [4.08879894e-01, 9.97587039e-01, 7.86282722e-01, ...,
#           4.30925012e-01, 8.30671867e-01, 6.51037962e-01],
#          [4.08879894e-01, 9.97587039e-01, 7.86282722e-01, ...,
#           4.30925012e-01, 8.30671867e-01, 6.51037962e-01],
#          ...,
#          [4.53272722e-01, 9.94367232e-01, 7.41825972e-01, ...,
#           4.32806122e-01, 8.31776755e-01, 6.41693671e-01],
#          [4.53272722e-01, 9.94367232e-01, 7.41825972e-01, ...,
#           4.32806122e-01, 8.31776755e-01, 6.41693671e-01],
#          [4.53272722e-01, 9.94367232e-01, 7.41825972e-01, ...,
#           4.32806122e-01, 8.31776755e-01, 6.41693671e-01]],
#
#         [[2.89690318e-01, 9.28253558e-01, 9.53915736e-01, ...,
#           6.48980092e-01, 6.32318352e-01, 1.40912904e-01],
#          [2.89690318e-01, 9.28253558e-01, 9.53915736e-01, ...,
#           6.48980092e-01, 6.32318352e-01, 1.40912904e-01],
#          [2.89690318e-01, 9.28253558e-01, 9.53915736e-01, ...,
#           6.48980092e-01, 6.32318352e-01, 1.40912904e-01],
#          ...,
#          [4.25346940e-01, 9.76812749e-01, 5.02234737e-01, ...,
#           6.84654394e-01, 5.87954297e-01, 3.61940863e-01],
#          [4.25346940e-01, 9.76812749e-01, 5.02234737e-01, ...,
#           6.84654394e-01, 5.87954297e-01, 3.61940863e-01],
#          [4.25346940e-01, 9.76812749e-01, 5.02234737e-01, ...,
#           6.84654394e-01, 5.87954297e-01, 3.61940863e-01]],
#
#         ...,
#
#         [[2.79617260e-02, 9.96371551e-01, 9.85535125e-01, ...,
#           4.72919488e-01, 7.90184032e-01, 5.00991803e-01],
#          [6.05240528e-01, 9.96448980e-01, 5.05495559e-01, ...,
#           6.45725604e-01, 6.17169749e-01, 6.22646098e-01],
#          [6.05240528e-01, 9.96448980e-01, 5.05495559e-01, ...,
#           6.45725604e-01, 6.17169749e-01, 6.22646098e-01],
#          ...,
#          [5.05546635e-01, 9.94938170e-01, 3.27606034e-01, ...,
#           6.96436666e-01, 5.73293948e-01, 5.29568919e-01],
#          [5.05546635e-01, 9.94938170e-01, 3.27606034e-01, ...,
#           6.96436666e-01, 5.73293948e-01, 5.29568919e-01],
#          [5.05546635e-01, 9.94938170e-01, 3.27606034e-01, ...,
#           6.96436666e-01, 5.73293948e-01, 5.29568919e-01]],
#
#         [[8.50352202e-01, 9.94268261e-01, 2.36217245e-01, ...,
#           2.54551731e-01, 9.99172372e-01, 4.85373442e-01],
#          [8.50352202e-01, 9.94268261e-01, 2.36217245e-01, ...,
#           2.54551731e-01, 9.99172372e-01, 4.85373442e-01],
#          [8.50352202e-01, 9.94268261e-01, 2.36217245e-01, ...,
#           2.54551731e-01, 9.99172372e-01, 4.85373442e-01],
#          ...,
#          [4.07811030e-01, 9.83431439e-01, 5.93502165e-01, ...,
#           6.72491879e-01, 5.97174020e-01, 4.81583073e-01],
#          [4.07811030e-01, 9.83431439e-01, 5.93502165e-01, ...,
#           6.72491879e-01, 5.97174020e-01, 4.81583073e-01],
#          [4.07110139e-01, 9.83532323e-01, 5.93868719e-01, ...,
#           6.72127416e-01, 5.97628199e-01, 4.80870857e-01]],
#
#         [[9.87392279e-01, 9.98129937e-01, 7.99156556e-02, ...,
#           5.82047685e-01, 6.78732276e-01, 9.98746694e-01],
#          [7.27678934e-03, 9.98225321e-01, 2.35093801e-02, ...,
#           8.40869673e-01, 4.10869145e-01, 4.80992829e-01],
#          [9.56115037e-01, 9.52317254e-01, 4.74118162e-02, ...,
#           3.31046919e-01, 9.45229486e-01, 4.81030169e-01],
#          ...,
#          [4.53809503e-01, 9.95079501e-01, 6.49997047e-01, ...,
#           4.28110113e-01, 8.41284614e-01, 4.95178917e-01],
#          [4.53809503e-01, 9.95079501e-01, 6.49997047e-01, ...,
#           4.28110113e-01, 8.41284614e-01, 4.95178917e-01],
#          [4.53809503e-01, 9.95079501e-01, 6.49997047e-01, ...,
#           4.28110113e-01, 8.41284614e-01, 4.95178917e-01]]],
#
#
#        [[[1.55647310e-03, 9.80923585e-01, 1.92279003e-01, ...,
#           4.65474153e-01, 7.89892551e-01, 4.53842218e-01],
#          [5.66071481e-01, 9.95250287e-01, 6.20636343e-01, ...,
#           1.01414054e-01, 1.42178714e-01, 5.30808430e-01],
#          [5.66071481e-01, 9.95250287e-01, 6.20636343e-01, ...,
#           1.01414054e-01, 1.42178714e-01, 5.30808430e-01],
#          ...,
#          [4.99632357e-01, 6.94386814e-01, 6.85445393e-01, ...,
#           1.35152813e-01, 1.04339473e-01, 4.52957348e-01],
#          [4.99632357e-01, 6.94386814e-01, 6.85445393e-01, ...,
#           1.35152813e-01, 1.04339473e-01, 4.52957348e-01],
#          [4.99632357e-01, 6.94386814e-01, 6.85445393e-01, ...,
#           1.35152813e-01, 1.04339473e-01, 4.52957348e-01]],
#
#         [[9.78366931e-01, 9.92129700e-01, 5.63111512e-03, ...,
#           6.00617231e-01, 6.86939189e-01, 6.69513468e-01],
#          [2.31794061e-01, 9.93621248e-01, 9.93661372e-01, ...,
#           1.41025170e-01, 9.45397630e-02, 5.01271589e-01],
#          [6.82161107e-02, 9.78053204e-01, 9.98833967e-01, ...,
#           7.38919968e-01, 5.18612537e-01, 3.81350578e-01],
#          ...,
#          [5.88603615e-01, 9.92576996e-01, 6.08829843e-01, ...,
#           4.15788378e-01, 8.55052579e-01, 4.79121591e-01],
#          [5.88603615e-01, 9.92576996e-01, 6.08829843e-01, ...,
#           4.15788378e-01, 8.55052579e-01, 4.79121591e-01],
#          [5.88603615e-01, 9.92576996e-01, 6.08829843e-01, ...,
#           4.15788378e-01, 8.55052579e-01, 4.79121591e-01]],
#
#         [[9.73019571e-01, 9.99869117e-01, 1.29521777e-02, ...,
#           6.41639581e-01, 6.46861123e-01, 2.77988910e-01],
#          [9.73285965e-01, 9.99483556e-01, 1.25874576e-02, ...,
#           6.39595933e-01, 6.48857729e-01, 2.97493850e-01],
#          [4.02686872e-01, 9.97802006e-01, 6.40650343e-01, ...,
#           9.23140454e-01, 3.12551880e-01, 7.84996735e-01],
#          ...,
#          [4.44726247e-01, 8.94825878e-01, 6.29119227e-01, ...,
#           3.93904989e-02, 2.11503830e-01, 5.38458088e-01],
#          [4.44726247e-01, 8.94825878e-01, 6.29119227e-01, ...,
#           3.93904989e-02, 2.11503830e-01, 5.38458088e-01],
#          [4.42109136e-01, 8.98762950e-01, 6.29536188e-01, ...,
#           3.82855994e-02, 2.13073218e-01, 5.41207087e-01]],
#
#         ...,
#
#         [[3.63827945e-03, 9.97837162e-01, 8.02716111e-01, ...,
#           4.45596102e-01, 8.13245090e-01, 7.42178977e-02],
#          [3.63827945e-03, 9.97837162e-01, 8.02716111e-01, ...,
#           4.45596102e-01, 8.13245090e-01, 7.42178977e-02],
#          [3.63827945e-03, 9.97837162e-01, 8.02716111e-01, ...,
#           4.45596102e-01, 8.13245090e-01, 7.42178977e-02],
#          ...,
#          [4.10656649e-01, 9.74084256e-01, 8.01946371e-01, ...,
#           6.34858725e-01, 6.34704785e-01, 4.32802984e-01],
#          [4.10656649e-01, 9.74084256e-01, 8.01946371e-01, ...,
#           6.34858725e-01, 6.34704785e-01, 4.32802984e-01],
#          [4.10656649e-01, 9.74084256e-01, 8.01946371e-01, ...,
#           6.34858725e-01, 6.34704785e-01, 4.32802984e-01]],
#
#         [[4.61244397e-03, 9.99499697e-01, 6.57499648e-01, ...,
#           8.56756690e-01, 3.97762338e-01, 5.72871189e-03],
#          [2.72607714e-01, 9.99673372e-01, 8.97065106e-01, ...,
#           6.22996343e-04, 2.14559216e-01, 5.70180878e-01],
#          [2.72607714e-01, 9.99673372e-01, 8.97065106e-01, ...,
#           6.22996343e-04, 2.14559216e-01, 5.70180878e-01],
#          ...,
#          [4.45596444e-01, 9.15621929e-01, 5.17799230e-01, ...,
#           6.27309718e-01, 6.31087575e-01, 5.05714302e-01],
#          [4.45596444e-01, 9.15621929e-01, 5.17799230e-01, ...,
#           6.27309718e-01, 6.31087575e-01, 5.05714302e-01],
#          [4.47313733e-01, 9.15650839e-01, 5.17737130e-01, ...,
#           6.27012836e-01, 6.31503443e-01, 5.06093043e-01]],
#
#         [[9.94849423e-02, 9.93446480e-01, 8.51793859e-01, ...,
#           3.42170643e-01, 9.24304539e-01, 2.79526873e-03],
#          [9.29747176e-01, 9.86375686e-01, 2.19124955e-01, ...,
#           8.14196100e-01, 4.27115581e-01, 2.68375599e-02],
#          [9.29747176e-01, 9.86375686e-01, 2.19124955e-01, ...,
#           8.14196100e-01, 4.27115581e-01, 2.68375599e-02],
#          ...,
#          [3.98548082e-01, 8.84525537e-01, 5.18030955e-01, ...,
#           6.09776474e-01, 6.45741486e-01, 4.80532196e-01],
#          [3.98548082e-01, 8.84525537e-01, 5.18030955e-01, ...,
#           6.09776474e-01, 6.45741486e-01, 4.80532196e-01],
#          [3.98548082e-01, 8.84525537e-01, 5.18030955e-01, ...,
#           6.09776474e-01, 6.45741486e-01, 4.80532196e-01]]],
#
#
#        [[[3.40879256e-03, 9.94419080e-01, 9.66244270e-01, ...,
#           8.70101897e-01, 3.66453830e-01, 6.28602944e-02],
#          [8.81021767e-01, 9.96690259e-01, 4.31033819e-01, ...,
#           5.88135192e-01, 6.82890784e-01, 4.09063199e-01],
#          [2.35527025e-03, 9.89620579e-01, 6.01678648e-01, ...,
#           9.33189317e-02, 1.37709327e-01, 9.71481003e-01],
#          ...,
#          [3.40658107e-01, 9.45821515e-01, 7.93757277e-01, ...,
#           8.91876663e-01, 3.31490230e-01, 5.87176392e-01],
#          [3.40658107e-01, 9.45821515e-01, 7.93757277e-01, ...,
#           8.91876663e-01, 3.31490230e-01, 5.87176392e-01],
#          [3.40658107e-01, 9.45821515e-01, 7.93757277e-01, ...,
#           8.91876663e-01, 3.31490230e-01, 5.87176392e-01]],
#
#         [[9.99908171e-01, 9.92592743e-01, 7.10880277e-01, ...,
#           3.75582244e-01, 8.91606513e-01, 9.97411003e-01],
#          [9.42469979e-01, 9.53987354e-01, 9.23525460e-06, ...,
#           3.27758268e-01, 9.47989118e-01, 5.02032560e-01],
#          [1.05832860e-03, 9.93896692e-01, 8.10825822e-01, ...,
#           4.47451022e-01, 8.11425730e-01, 1.07710096e-03],
#          ...,
#          [5.30273639e-01, 6.01283157e-01, 7.86518974e-01, ...,
#           1.32382292e-01, 1.12815524e-01, 3.94155840e-01],
#          [5.30273639e-01, 6.01283157e-01, 7.86518974e-01, ...,
#           1.32382292e-01, 1.12815524e-01, 3.94155840e-01],
#          [5.30273639e-01, 6.01283157e-01, 7.86518974e-01, ...,
#           1.32382292e-01, 1.12815524e-01, 3.94155840e-01]],
#
#         [[3.91240177e-04, 5.41739760e-01, 1.81223369e-03, ...,
#           6.77260148e-01, 5.85402751e-01, 5.28738866e-01],
#          [3.91240177e-04, 5.41739760e-01, 1.81223369e-03, ...,
#           6.77260148e-01, 5.85402751e-01, 5.28738866e-01],
#          [4.07167007e-03, 9.95540035e-01, 8.62886999e-01, ...,
#           1.86792247e-01, 6.12797856e-02, 4.54051405e-03],
#          ...,
#          [4.37549758e-01, 6.41588829e-01, 7.82681146e-01, ...,
#           1.61197523e-01, 8.22847367e-02, 4.49909011e-01],
#          [4.37549758e-01, 6.41588829e-01, 7.82681146e-01, ...,
#           1.61197523e-01, 8.22847367e-02, 4.49909011e-01],
#          [4.29661768e-01, 6.36874342e-01, 7.98404858e-01, ...,
#           1.64984537e-01, 7.87019641e-02, 4.42049847e-01]],
#
#         ...,
#
#         [[2.96011710e-01, 9.92689991e-01, 4.99880966e-01, ...,
#           1.14552932e-01, 1.09154250e-01, 4.72256732e-01],
#          [2.96011710e-01, 9.92689991e-01, 4.99880966e-01, ...,
#           1.14552932e-01, 1.09154250e-01, 4.72256732e-01],
#          [4.44883096e-01, 9.94641919e-01, 8.92447401e-01, ...,
#           6.80037816e-01, 5.86440083e-01, 4.92793238e-01],
#          ...,
#          [6.16918989e-01, 9.66103931e-01, 3.91296606e-01, ...,
#           7.78492215e-01, 4.65486438e-01, 4.15674266e-01],
#          [6.16531590e-01, 9.66456146e-01, 3.93220572e-01, ...,
#           7.78445140e-01, 4.65538625e-01, 4.16303472e-01],
#          [6.16531590e-01, 9.66456146e-01, 3.93220572e-01, ...,
#           7.78445140e-01, 4.65538625e-01, 4.16303472e-01]],
#
#         [[6.97974406e-01, 9.94692554e-01, 3.14564251e-01, ...,
#           4.62238017e-01, 8.18749473e-01, 9.61718113e-01],
#          [9.44087653e-01, 9.51858684e-01, 1.84563322e-03, ...,
#           3.30152482e-01, 9.45090725e-01, 5.00803785e-01],
#          [9.95401443e-01, 9.97130295e-01, 2.46696353e-01, ...,
#           3.17399906e-01, 9.55661233e-01, 9.97419088e-01],
#          ...,
#          [2.26924190e-01, 7.52749800e-01, 7.89780334e-01, ...,
#           5.10919852e-02, 2.01253354e-01, 4.81921960e-01],
#          [2.36012612e-01, 7.34987523e-01, 8.00544647e-01, ...,
#           5.23512731e-02, 1.99870713e-01, 4.77915860e-01],
#          [2.63519296e-01, 7.41331361e-01, 7.89357975e-01, ...,
#           5.60998609e-02, 1.95918308e-01, 4.78315571e-01]],
#
#         [[4.52722605e-01, 9.96325317e-01, 7.08344000e-01, ...,
#           3.46949388e-01, 9.22524375e-01, 4.38357434e-02],
#          [8.01264961e-01, 9.98240108e-01, 5.83702593e-01, ...,
#           4.25936368e-01, 8.67216990e-01, 9.99318943e-01],
#          [9.95260188e-01, 9.93036617e-01, 5.83424843e-01, ...,
#           5.84068034e-01, 7.08060630e-01, 2.52972287e-03],
#          ...,
#          [5.11019374e-01, 9.95324583e-01, 7.47626492e-01, ...,
#           4.40920933e-01, 8.29294891e-01, 4.33434937e-01],
#          [5.11019374e-01, 9.95324583e-01, 7.47626492e-01, ...,
#           4.40920933e-01, 8.29294891e-01, 4.33434937e-01],
#          [5.11019374e-01, 9.95324583e-01, 7.47626492e-01, ...,
#           4.40920933e-01, 8.29294891e-01, 4.33434937e-01]]],
#
#
#        ...,
#
#
#        [[[9.22435765e-01, 9.95991790e-01, 3.44138728e-01, ...,
#           7.83724818e-01, 4.59346584e-01, 4.94324763e-01],
#          [3.15488310e-01, 9.99796714e-01, 6.34652017e-01, ...,
#           4.04521753e-01, 8.59300540e-01, 9.99989974e-01],
#          [2.58311816e-01, 9.95534171e-01, 5.71483626e-01, ...,
#           2.11430504e-01, 1.40305021e-01, 3.91526269e-01],
#          ...,
#          [4.67825578e-01, 9.99986463e-01, 7.02178009e-01, ...,
#           4.13357199e-01, 8.50104314e-01, 4.82612679e-01],
#          [6.28432041e-02, 9.93172615e-01, 7.74928506e-01, ...,
#           3.32113111e-01, 9.46986500e-01, 4.24828824e-01],
#          [6.73104907e-01, 9.94344200e-01, 2.08798305e-01, ...,
#           2.84621182e-01, 9.77893854e-01, 4.79631684e-01]],
#
#         [[6.84005155e-01, 9.71014837e-01, 3.99569651e-01, ...,
#           7.49328022e-01, 5.03776666e-01, 7.72449894e-01],
#          [4.94038910e-01, 9.97246572e-01, 2.18155314e-01, ...,
#           6.11442807e-01, 6.65542340e-01, 6.42123450e-01],
#          [6.93981512e-01, 5.77461922e-01, 1.56753232e-01, ...,
#           6.31969520e-01, 6.13921452e-01, 8.26963385e-01],
#          ...,
#          [8.64106398e-01, 9.24882269e-01, 5.32389196e-01, ...,
#           5.95221537e-01, 6.87350818e-01, 8.73929063e-01],
#          [6.27742822e-04, 7.89447718e-01, 2.66824144e-03, ...,
#           6.67812427e-01, 5.95772729e-01, 5.29851575e-01],
#          [5.40764931e-01, 8.78417661e-01, 4.72683177e-02, ...,
#           9.71407274e-01, 2.48672942e-01, 4.47838125e-01]],
#
#         [[2.59708630e-02, 2.43754757e-02, 9.87418984e-01, ...,
#           2.04828016e-01, 4.94164524e-02, 2.23954839e-01],
#          [5.12522759e-03, 9.98872037e-01, 6.72660456e-01, ...,
#           2.58570244e-01, 9.68939310e-01, 5.80822284e-03],
#          [7.56955781e-01, 8.99789370e-01, 4.11654395e-01, ...,
#           2.55641422e-01, 1.61639010e-01, 5.67032797e-01],
#          ...,
#          [2.64799665e-01, 9.57812839e-01, 6.14937134e-01, ...,
#           2.01040243e-02, 1.95797123e-01, 5.52851814e-01],
#          [9.84292923e-02, 1.33000958e-01, 8.93483541e-02, ...,
#           7.79589457e-01, 4.70301960e-01, 6.99643983e-01],
#          [1.30403437e-01, 9.88097150e-01, 8.89335722e-01, ...,
#           1.76559972e-01, 6.79689338e-02, 1.69427653e-01]],
#
#         ...,
#
#         [[5.97157319e-01, 9.98926996e-01, 6.50597853e-01, ...,
#           5.12323157e-01, 7.68129962e-01, 6.11395072e-01],
#          [1.65907255e-02, 9.99665633e-01, 4.64240490e-01, ...,
#           8.22279493e-01, 4.13235783e-01, 9.71161933e-01],
#          [5.00479169e-01, 9.98445955e-01, 3.94156779e-01, ...,
#           6.44856311e-01, 6.32111826e-01, 4.79366559e-01],
#          ...,
#          [8.18234849e-02, 9.87478757e-01, 8.21670966e-01, ...,
#           8.96247727e-01, 3.43716412e-01, 1.85200770e-01],
#          [1.98358487e-01, 9.79435617e-01, 6.10107482e-01, ...,
#           3.98849103e-02, 1.72682975e-01, 4.51308762e-01],
#          [3.30685983e-01, 8.90600005e-01, 5.65396708e-01, ...,
#           6.12671613e-01, 6.55334172e-01, 7.86282854e-01]],
#
#         [[2.29392343e-01, 9.98708825e-01, 4.90587620e-01, ...,
#           4.59302680e-01, 8.84592943e-02, 2.91111482e-01],
#          [8.29373756e-01, 9.24441538e-01, 2.56856453e-01, ...,
#           3.67585469e-01, 9.07735847e-01, 9.97869345e-01],
#          [3.00409732e-02, 9.99028777e-01, 7.82100039e-01, ...,
#           8.70925750e-01, 3.69120652e-01, 7.43815151e-01],
#          ...,
#          [1.15118988e-01, 9.98875184e-01, 6.34851520e-01, ...,
#           1.72595320e-01, 6.91711301e-02, 5.75786123e-01],
#          [3.18890515e-01, 9.40763795e-01, 9.76005987e-01, ...,
#           6.70244838e-02, 1.58584516e-01, 2.62115051e-01],
#          [1.99223344e-01, 9.84898459e-01, 3.85817656e-01, ...,
#           1.05148719e-01, 1.23498746e-01, 4.43816325e-01]],
#
#         [[1.87950811e-02, 9.91105701e-01, 4.76946404e-02, ...,
#           4.88914306e-01, 1.29888983e-01, 3.76624516e-01],
#          [3.39785489e-02, 9.99501275e-01, 6.93430813e-01, ...,
#           6.89939405e-01, 5.67395096e-01, 2.61825655e-01],
#          [3.24727636e-02, 9.99584753e-01, 4.61913647e-01, ...,
#           8.20123267e-01, 4.15046674e-01, 9.68812656e-01],
#          ...,
#          [6.73461030e-01, 9.96712318e-01, 5.74564418e-01, ...,
#           3.17842681e-01, 9.57432823e-01, 9.98160478e-01],
#          [3.17656441e-01, 9.96910071e-01, 8.27185412e-01, ...,
#           2.17579490e-01, 3.27441672e-02, 6.16941612e-01],
#          [4.86070352e-01, 8.93027416e-01, 4.73363522e-01, ...,
#           5.61338451e-01, 7.25948963e-01, 4.55591520e-01]]],
#
#
#        [[[2.72646190e-01, 8.15690269e-02, 2.55730987e-01, ...,
#           8.63766515e-01, 3.39808910e-01, 4.95095347e-01],
#          [2.00385812e-01, 9.96407595e-01, 9.66263450e-01, ...,
#           2.98819661e-01, 9.50062739e-01, 5.03222507e-01],
#          [4.10803946e-01, 9.95883328e-01, 3.07305531e-01, ...,
#           4.53942918e-01, 5.26389862e-01, 5.45477506e-01],
#          ...,
#          [7.56440222e-01, 9.88467551e-01, 1.11879780e-01, ...,
#           3.41262731e-01, 9.36340946e-01, 2.37849698e-01],
#          [2.42390971e-01, 9.60921327e-01, 8.35381925e-01, ...,
#           1.84195090e-02, 1.94133721e-01, 2.66107088e-01],
#          [2.77335137e-01, 9.00716045e-01, 6.78796244e-01, ...,
#           1.18345129e-01, 9.96028932e-02, 3.02800864e-01]],
#
#         [[2.68356957e-04, 9.94159940e-01, 7.15220465e-01, ...,
#           1.40272178e-01, 8.80711181e-02, 4.98136954e-01],
#          [4.85687140e-01, 9.59788041e-01, 9.35318524e-01, ...,
#           9.18899027e-01, 3.52211574e-01, 4.53196830e-01],
#          [1.04539193e-01, 6.81128819e-01, 2.16336991e-01, ...,
#           4.78784685e-01, 1.70466366e-01, 7.91230915e-01],
#          ...,
#          [4.70715515e-01, 9.61064675e-01, 6.52483671e-01, ...,
#           1.59673675e-01, 8.23324341e-02, 5.59043135e-01],
#          [3.64712639e-01, 9.27581874e-01, 6.18363588e-01, ...,
#           2.10608043e-02, 2.33354743e-01, 5.50036506e-01],
#          [5.47560687e-01, 9.82677088e-01, 4.29543647e-01, ...,
#           2.74211478e-01, 9.86211940e-01, 4.06357848e-01]],
#
#         [[3.02440125e-01, 9.97864110e-01, 6.47347101e-01, ...,
#           3.93535292e-01, 8.65075564e-01, 9.96432858e-01],
#          [2.52502959e-03, 9.92380655e-01, 9.51650819e-01, ...,
#           8.80282112e-01, 3.53578409e-01, 6.10952549e-02],
#          [8.01663093e-01, 9.75259839e-01, 2.35369683e-01, ...,
#           6.91172203e-01, 5.29723588e-01, 8.52834555e-01],
#          ...,
#          [5.95630358e-01, 9.36716358e-01, 6.17835032e-01, ...,
#           8.61947241e-01, 3.84077315e-01, 5.66459344e-01],
#          [5.52441063e-01, 9.84963545e-01, 6.50499087e-01, ...,
#           3.60713776e-03, 2.25062158e-01, 6.34900974e-01],
#          [7.56440222e-01, 9.88467551e-01, 1.11879780e-01, ...,
#           3.41262731e-01, 9.36340946e-01, 2.37849698e-01]],
#
#         ...,
#
#         [[4.20700452e-02, 7.39844914e-01, 3.03892420e-01, ...,
#           4.93422123e-01, 2.30593693e-01, 6.82907552e-01],
#          [5.58820299e-01, 9.90600980e-01, 4.61769544e-01, ...,
#           4.25604207e-01, 8.32152870e-01, 5.17313618e-01],
#          [4.99384576e-01, 9.94927442e-01, 4.14471701e-01, ...,
#           6.62368919e-01, 6.11032073e-01, 4.76538023e-01],
#          ...,
#          [1.11555918e-02, 9.51626399e-01, 3.17777389e-03, ...,
#           5.96755138e-02, 1.41838863e-01, 4.73299882e-01],
#          [2.88472746e-01, 9.19556397e-01, 2.39505868e-01, ...,
#           1.73197186e-01, 5.81977237e-02, 3.03730461e-01],
#          [4.42444838e-01, 9.99398174e-01, 6.66351231e-01, ...,
#           3.48128261e-01, 9.24090322e-01, 1.10563123e-01]],
#
#         [[2.30596373e-04, 9.99124529e-01, 8.15974471e-01, ...,
#           7.55015326e-01, 5.00153520e-01, 9.98421357e-01],
#          [7.37186147e-01, 9.96180876e-01, 9.44041482e-01, ...,
#           6.20664443e-01, 6.03212472e-01, 6.38851039e-01],
#          [6.66605309e-01, 3.53398038e-01, 7.80235971e-01, ...,
#           7.70076297e-01, 4.55400032e-01, 9.71650287e-01],
#          ...,
#          [3.47466222e-01, 9.40646454e-01, 8.91843944e-01, ...,
#           5.64330336e-01, 7.29913304e-01, 1.38450070e-01],
#          [3.41639955e-01, 9.40779053e-01, 9.01392251e-01, ...,
#           5.63226781e-01, 7.31433271e-01, 1.28166924e-01],
#          [7.49455925e-01, 9.94583380e-01, 3.14054977e-01, ...,
#           4.74700493e-02, 1.75259569e-01, 9.67975709e-01]],
#
#         [[8.13097922e-01, 9.90900863e-01, 3.38590259e-01, ...,
#           3.04670719e-01, 9.57245485e-01, 9.91108079e-01],
#          [3.59527602e-01, 9.91926496e-01, 9.81465460e-01, ...,
#           5.51374263e-01, 4.65664059e-01, 5.26333397e-01],
#          [3.11542874e-02, 6.19337092e-01, 6.47567385e-02, ...,
#           6.26522527e-01, 4.91426132e-01, 7.26631678e-01],
#          ...,
#          [1.61459092e-01, 8.61382499e-01, 6.41199579e-01, ...,
#           6.98546661e-01, 5.65344877e-01, 6.39473415e-01],
#          [1.80320818e-01, 9.36238341e-01, 1.46246367e-01, ...,
#           4.45295010e-01, 8.12156912e-01, 4.82695255e-01],
#          [4.71357174e-02, 9.75599672e-01, 7.59692848e-01, ...,
#           1.40309908e-01, 9.05142230e-02, 4.60513955e-01]]],
#
#
#        [[[8.92645759e-01, 9.98085397e-01, 4.88373608e-01, ...,
#           5.70804781e-01, 6.31812474e-01, 2.87731845e-01],
#          [4.87064906e-01, 9.00302846e-01, 6.83002583e-01, ...,
#           4.18585841e-01, 5.04860074e-01, 5.28773509e-01],
#          [7.87891571e-01, 9.45675217e-01, 5.09931124e-01, ...,
#           2.73969502e-01, 4.32987400e-01, 6.50351555e-01],
#          ...,
#          [2.68075722e-01, 6.03843987e-01, 5.35450415e-01, ...,
#           1.20841202e-02, 2.25660517e-01, 8.77866742e-01],
#          [2.23517640e-01, 9.80565000e-01, 7.32969559e-01, ...,
#           5.28561271e-02, 1.88995245e-01, 4.41896716e-01],
#          [5.21117457e-02, 9.86051319e-01, 6.81884320e-01, ...,
#           1.13244982e-01, 1.18618041e-01, 4.05808530e-01]],
#
#         [[3.20379382e-01, 9.98123471e-01, 6.32909295e-01, ...,
#           3.98656471e-01, 8.59485375e-01, 9.99394899e-01],
#          [2.27719556e-01, 9.96983694e-01, 7.59453525e-01, ...,
#           5.96694438e-01, 6.65677561e-01, 8.17634469e-01],
#          [4.88585338e-01, 9.97265245e-01, 2.70917611e-01, ...,
#           3.60651785e-01, 7.71068232e-01, 5.71473030e-01],
#          ...,
#          [4.48463591e-01, 8.08054485e-01, 5.81785327e-01, ...,
#           3.61671474e-02, 1.87001550e-01, 2.47942540e-01],
#          [4.48463591e-01, 8.08054485e-01, 5.81785327e-01, ...,
#           3.61671474e-02, 1.87001550e-01, 2.47942540e-01],
#          [4.53261547e-01, 7.98385736e-01, 5.65693671e-01, ...,
#           2.54063904e-02, 1.96199842e-01, 2.35462969e-01]],
#
#         [[9.73812322e-01, 9.97337550e-01, 4.66990326e-02, ...,
#           3.55339454e-01, 4.68885375e-01, 8.97643193e-01],
#          [8.94664751e-01, 9.87631795e-01, 1.68750053e-01, ...,
#           3.35227311e-01, 4.11709636e-01, 8.00528931e-01],
#          [8.94664751e-01, 9.87631795e-01, 1.68750053e-01, ...,
#           3.35227311e-01, 4.11709636e-01, 8.00528931e-01],
#          ...,
#          [2.36633476e-01, 9.26173711e-01, 2.58828328e-01, ...,
#           2.47248029e-01, 7.06829769e-03, 8.71154498e-02],
#          [9.48571797e-01, 4.69334147e-01, 1.51907985e-02, ...,
#           9.72000022e-02, 1.24100930e-01, 5.13791934e-01],
#          [7.12514412e-01, 9.05569436e-01, 5.16963305e-01, ...,
#           5.05432874e-01, 7.80721896e-01, 5.27927237e-01]],
#
#         ...,
#
#         [[5.23530635e-01, 9.56256245e-01, 1.21028245e-01, ...,
#           2.66059547e-01, 4.88241875e-01, 4.83541940e-01],
#          [7.14788092e-01, 9.91136564e-01, 5.09306118e-01, ...,
#           2.31944610e-01, 4.79539076e-01, 5.79209569e-01],
#          [7.16043844e-01, 9.91288951e-01, 5.07806076e-01, ...,
#           2.31837653e-01, 4.79353400e-01, 5.79483033e-01],
#          ...,
#          [4.10121814e-01, 9.98605078e-01, 4.55196887e-01, ...,
#           4.23125904e-01, 8.39413426e-01, 7.26898673e-01],
#          [9.46843306e-01, 4.23662298e-01, 1.02672800e-02, ...,
#           8.99477904e-02, 1.28097986e-01, 5.13627817e-01],
#          [5.54150810e-01, 9.82706982e-01, 4.05347887e-01, ...,
#           9.48962292e-02, 1.28706620e-01, 6.88907915e-01]],
#
#         [[3.14554937e-01, 9.75987485e-01, 5.27901300e-01, ...,
#           4.13017720e-01, 6.24398107e-01, 5.52133134e-01],
#          [7.19191147e-01, 9.94863466e-01, 3.32890838e-01, ...,
#           3.93670791e-01, 2.35975203e-01, 6.23321557e-01],
#          [6.53176687e-01, 9.29555493e-01, 4.09634992e-01, ...,
#           3.56867939e-01, 3.15010907e-01, 6.39818483e-01],
#          ...,
#          [4.46842581e-02, 9.41905428e-01, 1.88310648e-02, ...,
#           9.56720514e-02, 1.19231146e-01, 4.46020848e-01],
#          [4.46842581e-02, 9.41905428e-01, 1.88310648e-02, ...,
#           9.56720514e-02, 1.19231146e-01, 4.46020848e-01],
#          [4.46842581e-02, 9.41905428e-01, 1.88310648e-02, ...,
#           9.56720514e-02, 1.19231146e-01, 4.46020848e-01]],
#
#         [[5.50932816e-04, 9.97759231e-01, 2.20638163e-03, ...,
#           8.40714954e-01, 4.08063670e-01, 4.89979852e-01],
#          [5.50932816e-04, 9.97759231e-01, 2.20638163e-03, ...,
#           8.40714954e-01, 4.08063670e-01, 4.89979852e-01],
#          [5.50932816e-04, 9.97759231e-01, 2.20638163e-03, ...,
#           8.40714954e-01, 4.08063670e-01, 4.89979852e-01],
#          ...,
#          [4.36614990e-02, 7.97503375e-01, 2.72597638e-01, ...,
#           3.80159312e-01, 7.51901638e-01, 3.97053406e-03],
#          [4.36614990e-02, 7.97503375e-01, 2.72597638e-01, ...,
#           3.80159312e-01, 7.51901638e-01, 3.97053406e-03],
#          [4.36614990e-02, 7.97503375e-01, 2.72597638e-01, ...,
#           3.80159312e-01, 7.51901638e-01, 3.97053406e-03]]]])

# %%
# The loglikelihood
results_dictionary['_loglikelihood'] # shape: (ntemps, nwalkers, steps)
# Out:
# array([[[-8.14744462e+04, -5.06261423e+04, -2.39247544e+04, ...,
#          -1.75947939e+02, -1.75947939e+02, -1.75947939e+02],
#         [-2.09912542e+04, -1.77645441e+04, -1.77645441e+04, ...,
#          -1.76965279e+02, -1.76965279e+02, -1.76965279e+02],
#         [-3.07987023e+04, -3.07987023e+04, -3.07987023e+04, ...,
#          -1.28940255e+03, -1.28940255e+03, -1.28940255e+03],
#         ...,
#         [-9.61151349e+04, -4.15523183e+04, -4.15523183e+04, ...,
#          -1.93295230e+03, -1.93295230e+03, -1.93295230e+03],
#         [-3.68452545e+04, -3.68452545e+04, -3.68452545e+04, ...,
#          -6.79583182e+02, -6.79583182e+02, -6.64997388e+02],
#         [-1.28838400e+05, -1.04131864e+05, -1.97768358e+04, ...,
#          -1.31653930e+03, -1.31653930e+03, -1.31653930e+03]],
#
#        [[-1.78598620e+05, -1.21138801e+05, -1.21138801e+05, ...,
#          -3.19331376e+03, -3.19331376e+03, -3.19331376e+03],
#         [-1.50118061e+05, -1.20666596e+05, -9.19578707e+04, ...,
#          -3.20830899e+03, -3.20830899e+03, -3.20830899e+03],
#         [-1.57068961e+05, -1.55298621e+05, -1.16769340e+05, ...,
#          -2.14242176e+03, -2.14242176e+03, -2.06192439e+03],
#         ...,
#         [-1.06463841e+05, -1.06463841e+05, -1.06463841e+05, ...,
#          -2.08980662e+03, -2.08980662e+03, -2.08980662e+03],
#         [-1.51088667e+05, -1.02778127e+05, -1.02778127e+05, ...,
#          -2.19276927e+03, -2.19276927e+03, -2.18557934e+03],
#         [-1.46807758e+05, -1.09339773e+05, -1.09339773e+05, ...,
#          -2.86054144e+03, -2.86054144e+03, -2.86054144e+03]],
#
#        [[-2.66792224e+05, -2.46833695e+05, -1.89980386e+05, ...,
#          -4.72396042e+03, -4.72396042e+03, -4.72396042e+03],
#         [-2.51961212e+05, -1.99331434e+05, -1.50034425e+05, ...,
#          -7.12668512e+03, -7.12668512e+03, -7.12668512e+03],
#         [-2.39181546e+05, -2.39181546e+05, -1.85221177e+05, ...,
#          -5.23586661e+03, -5.23586661e+03, -4.75859894e+03],
#         ...,
#         [-2.14989793e+05, -2.14989793e+05, -9.15405089e+04, ...,
#          -4.88819814e+03, -4.86918320e+03, -4.86918320e+03],
#         [-2.14875812e+05, -1.67960621e+05, -1.18160162e+05, ...,
#          -5.09004238e+03, -4.37916522e+03, -4.20412151e+03],
#         [-1.22922044e+05, -1.14336431e+05, -1.44508348e+05, ...,
#          -5.45745734e+03, -5.45745734e+03, -5.45745734e+03]],
#
#        ...,
#
#        [[-8.36231196e+09, -1.00000000e+10, -1.02142683e+09, ...,
#          -1.23728390e+05, -1.26557067e+05, -1.43711554e+05],
#         [-1.00003510e+10, -1.00000000e+10, -1.00000000e+10, ...,
#          -1.11359172e+05, -1.26244579e+05, -1.23988175e+05],
#         [-2.02677186e+07, -1.00000000e+10, -2.61205266e+09, ...,
#          -1.37359854e+05, -1.24028829e+05, -1.14733772e+05],
#         ...,
#         [-1.00124545e+10, -1.00000000e+10, -1.00000000e+10, ...,
#          -1.15245656e+05, -1.07533172e+05, -1.24183145e+05],
#         [-1.00000000e+10, -1.00000000e+10, -1.00000000e+10, ...,
#          -1.20689240e+05, -1.29684590e+05, -1.24498759e+05],
#         [-9.16934378e+09, -1.00000166e+10, -1.00000000e+10, ...,
#          -1.22265795e+05, -1.38611481e+05, -1.27688759e+05]],
#
#        [[-1.00000000e+10, -1.00000000e+10, -1.00000000e+10, ...,
#          -1.40169586e+05, -1.60092012e+05, -1.90194228e+05],
#         [-3.17857604e+06, -1.00000756e+10, -1.00000000e+10, ...,
#          -1.65357274e+05, -1.66585442e+05, -1.52522253e+05],
#         [-1.00000000e+10, -1.00000000e+10, -1.00000000e+10, ...,
#          -1.22711550e+05, -1.40631994e+05, -1.40169586e+05],
#         ...,
#         [-1.00000000e+10, -1.00000000e+10, -1.00000000e+10, ...,
#          -2.10211319e+05, -1.52920615e+05, -1.31887844e+05],
#         [-1.00000875e+10, -1.00000000e+10, -1.00000000e+10, ...,
#          -1.34753829e+05, -1.31806289e+05, -1.35062451e+05],
#         [-1.00000000e+10, -1.00000000e+10, -1.00000000e+10, ...,
#          -1.24075230e+05, -1.88437983e+05, -1.45995682e+05]],
#
#        [[-6.91741273e+10, -3.49776206e+10, -1.88445659e+10, ...,
#          -1.35690659e+05, -1.80338297e+05, -1.52747988e+05],
#         [-1.00000000e+10, -1.00000926e+10, -1.00001936e+10, ...,
#          -2.68188674e+05, -2.68188674e+05, -2.72554917e+05],
#         [-2.58655950e+10, -1.91947845e+10, -1.91947845e+10, ...,
#          -1.80422389e+05, -1.68591589e+05, -2.16457790e+05],
#         ...,
#         [-1.99816431e+10, -1.89911288e+10, -1.88869923e+10, ...,
#          -1.53830818e+05, -1.72329094e+05, -1.97547020e+05],
#         [-4.63339579e+10, -1.49755783e+10, -1.13873794e+10, ...,
#          -4.06492547e+06, -4.06492547e+06, -4.06492547e+06],
#         [-1.00005248e+10, -1.00005248e+10, -1.00005248e+10, ...,
#          -1.00000000e+10, -1.00000000e+10, -1.00000000e+10]]])

# %%
# Number of accepted swaps in each temperature
results_dictionary['nswap_accepted'] # shape: (ntemps,)
# Out:
# array([  1321.,   4081.,   5461.,   9107.,  18754.,  35945.,  59236.,
#         84812., 110463., 134817., 156332., 174850., 193400., 211287.,
#        228858., 245709., 262217., 279595., 295037., 306683., 314306.,
#        318036., 318730., 317675., 315386., 311742., 307787., 303764.,
#        299295., 148480.])

# %% [markdown]
# An easy way of looking into the posteriors is generating histograms of the results using the 'plots' module. Lets make a burning of the first 50% of the chains at temperature T=0.

# %%
T = 0   # Target temperature

# %%
plots.plot_hist(PS, hdf5_file='SystemX.hdf5', burning=0.8) #chains=results_dictionary['_chain'][T]

# %%
from IPython.display import display, clear_output
from nauyaca_local import utils
RESULTS = utils.get_mcmc_results(f'SystemX.hdf5')['CHAINS']


def plotear(x,y,steps,t,c):
    ax.scatter(RESULTS[t][:,steps,x], RESULTS[t][:,steps,y], alpha=0.3, label=f'{t}',c=c)
    plt.scatter(np.median(RESULTS[t][:,steps,x]),
                np.median(RESULTS[t][:,steps,y]), marker='s',c=c, edgecolors='k')
    return
for steps in range(int(itmax/conver_steps)):
    x, y = 10,11
    fig, ax = plt.subplots( figsize=(10,8))
    
    plotear(x,y,steps,13,'k')
    plotear(x,y,steps,7,'g')
    plotear(x,y,steps,0,'r')
        
    plt.legend()
    plt.title(f"Iter: {steps*conver_steps}")
    plt.xlim(0,1)
    plt.ylim(0,1)
    
    #plt.axvline(68)
    #plt.axhline(15)
    
    display(fig)
    plt.close(fig)
    clear_output(wait=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-e7c27880f384> in <module>
#      25     #plt.axhline(15)
#      26
# ---> 27     display(fig)
#      28     plt.close(fig)
#      29     clear_output(wait=1)
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </home/eliab/anaconda2/envs/Py37/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2643             renderer.stop_rasterizing()
#    2644
# -> 2645         mimage._draw_list_compositing_images(renderer, self, artists)
#    2646
#    2647         renderer.close_group('axes')
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/legend.py in draw(self, renderer)
#     666                 shadow.draw(renderer)
#     667
# --> 668             self.legendPatch.draw(renderer)
#     669
#     670         self._legend_box.draw(renderer)
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/patches.py in draw(self, renderer)
#     569         # Patch has traditionally ignored the dashoffset.
#     570         with cbook._setattr_cm(self, _dashoffset=0), \
# --> 571                 self._bind_draw_path_function(renderer) as draw_path:
#     572             path = self.get_path()
#     573             transform = self.get_transform()
#
# ~/anaconda2/envs/Py37/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda2/envs/Py37/lib/python3.7/site-packages/matplotlib/patches.py in _bind_draw_path_function(self, renderer)
#     526         gc.set_joinstyle(self._joinstyle)
#     527
# --> 528         gc.set_antialiased(self._antialiased)
#     529         self._set_gc_clip(gc)
#     530         gc.set_url(self._url)
#
# KeyboardInterrupt:

# %% [markdown]
# If you are interested in visualizing the chains movement just make a plot as

# %%
plots.plot_chains(PS, hdf5_file='SystemX.hdf5', temperature=0, plot_means=True) #chains=results_dictionary['_chain'][T]

# %% [markdown]
# And now a corner plot to visualize possible correlations between variables

# %%
plots.plot_corner(PS, chains=results_dictionary['_chain'][T], burning=0.5)

# %% [markdown]
# ### 3.2.1 The .hdf5 file

# %% [markdown]
# It is also possible to acces the main attributes of the MCMC sampler that are saved in the .hdf5 file. but first, let's print a summary of the posteriors which correspond to the median and 16th and 84th percentile as lower and upper errors

# %%
from nauyaca_local.utils import mcmc_summary

# burning argument is a fraction of the chains to discard in the burning phase. Let's remove first 50%
# verbose prints the summary
posteriors = mcmc_summary("SystemX.hdf5", burning=0.5, verbose=True)   

print('\n---RESULTS:')
posteriors
# Out:
# -->Planetary System:  SystemX
#    Stellar mass:  0.91
#    Stellar radius:  1.18
#    Number of planets:  2
# --------------------------
# -->MCMC parameters
#    Ntemps:  16
#    Nwalkers per temperature:  100
#    Number of iterations:  50000
#    Thining:  50
# --------------------------
#       RESULTS
# -->Results in File:   SystemX.hdf5
# -->Reference epoch of the solutions:  0  [JD]
# -->Best solution in MCMC
#    Best chi2 solution:  108.30638
#    0.4744   0.8902   0.4894   0.2416   0.9037   0.6786   180.0
#    0.9873   0.8023   0.3647   0.5009   0.214   0.0345   0.4517
# --------------------------
# -->MCMC medians and 1-sigma errors
#              mass1      0.4 ^{+0.05}_{-0.04}
#            period1      0.9286 ^{+0.0579}_{-0.0868}
#               ecc1      0.629 ^{+0.128}_{-0.124}
#       inclination1      0.65 ^{+0.33}_{-0.33}
#          argument1      0.9 ^{+0.01}_{-0.01}
#      mean_anomaly1      0.68 ^{+0.01}_{-0.02}
#              mass2      0.94 ^{+0.06}_{-0.09}
#            period2      0.61 ^{+0.27}_{-0.25}
#               ecc2      0.29 ^{+0.08}_{-0.18}
#       inclination2      0.82 ^{+0.1}_{-0.22}
#          argument2      0.18 ^{+0.23}_{-0.1}
#      mean_anomaly2      0.16 ^{+0.69}_{-0.1}
#    ascending_node2      0.44 ^{+0.08}_{-0.05}
#
# ---RESULTS:
# {'mass1': [0.39603550183673214],
#  'mass1_e': [0.04183773767234383],
#  'mass1_E': [0.0475183762583391],
#  'period1': [0.9286418847326872],
#  'period1_e': [0.08675324245185312],
#  'period1_E': [0.057915638804613145],
#  'ecc1': [0.6287053256079944],
#  'ecc1_e': [0.1243376277459205],
#  'ecc1_E': [0.12803215888642883],
#  'inclination1': [0.6499596212240606],
#  'inclination1_e': [0.3338125840090974],
#  'inclination1_E': [0.32590929347372377],
#  'argument1': [0.897159299362674],
#  'argument1_e': [0.011919804585832638],
#  'argument1_E': [0.01345024920761595],
#  'mean_anomaly1': [0.6783037114476522],
#  'mean_anomaly1_e': [0.021318983741766218],
#  'mean_anomaly1_E': [0.012032861275375062],
#  'mass2': [0.9381178900836873],
#  'mass2_e': [0.09314267979090052],
#  'mass2_E': [0.05604971940905912],
#  'period2': [0.6056440224863529],
#  'period2_e': [0.24709906680825555],
#  'period2_E': [0.26980230356598656],
#  'ecc2': [0.2930857284166232],
#  'ecc2_e': [0.17527005359780157],
#  'ecc2_E': [0.08179580899935496],
#  'inclination2': [0.8181511679329432],
#  'inclination2_e': [0.22177288104125426],
#  'inclination2_E': [0.10370819215909999],
#  'argument2': [0.1771462436317966],
#  'argument2_e': [0.0988934526130476],
#  'argument2_E': [0.22994921336360258],
#  'mean_anomaly2': [0.1588243850341965],
#  'mean_anomaly2_e': [0.0951678805333122],
#  'mean_anomaly2_E': [0.6911890592873108],
#  'ascending_node2': [0.4442077240649081],
#  'ascending_node2_e': [0.048447921328946764],
#  'ascending_node2_E': [0.07713542842842508]}

# %% [markdown]
# Now, let's make available all the results saved in the .hdf5 file in a dictionary:

# %%
results_hdf5 =  nau.utils.get_mcmc_results('SystemX.hdf5')

print(results_hdf5.keys() )  # Attributes saved in the .hdf5 file
# Out:
# dict_keys(['ACC_FRAC0', 'AUTOCORR', 'BESTCHI2', 'BESTSOLS', 'BETAS', 'BOUNDS', 'CHAINS', 'COL_NAMES', 'CONVER_STEPS', 'CORES', 'INDEX', 'ITER_LAST', 'ITMAX', 'MEANCHI2', 'MSTAR', 'NAME', 'NPLA', 'NTEMPS', 'NWALKERS', 'POP0', 'REF_EPOCH', 'RSTAR', 'TAU_PROM0'])

# %% [markdown]
# These keys correspond to the main features of the MCMC saved in the .hdf5 file. This file is portable and is useful to restart an MCMC in other time or in another computer.
#
# Not all the attributes in results_dictionary are stored in the .hdf5 file but just those necessary to analize the MCMC performance and many properties of the planetary system. For example the 'CHAINS' key is the same as the attribute in results_dictionary['_chain'].
#
# From the .hdf5 file it is also possible to monitor the MCMC behaviour using the prefabricated image

# %%
plots.plot_monitor('SystemX.hdf5')

# %%
plots.plot_monitor('SystemX.hdf5')

# %% [markdown]
# ### 3.2.2 The .best file

# %% [markdown]
# At the end of the iterations, best solutions are extracted automatically (corresponding to the solutions of 'better posterior' per step) and saved in a .best file. It's ordered by log-likelihood from higher to lower. If for any reason the mcmc run does not finish correctly or is interrupted, you can always extract the best solutions along the saved iterations by typing:

# %%
best_solutions = nau.utils.extract_best_solutions('SystemX.hdf5')
# Out:
# --> Best solutions from the SystemX.hdf5 will be written at: SystemX.best

# %% [markdown]
# Let's select the bet 5 solutions

# %%
# The best 5 results. Tuples are (loglikelihood, (solution))
best_n = best_solutions[0:1]
best_n
# Out:
# [(108.30637904423656,
#   array([4.74421831e-01, 8.90246597e-01, 4.89427329e-01, 2.41637466e-01,
#          9.03679716e-01, 6.78556036e-01, 1.80000000e+02, 9.87309434e-01,
#          8.02254474e-01, 3.64701182e-01, 5.00930545e-01, 2.14019649e-01,
#          3.45445574e-02, 4.51747968e-01]))]

# %% [markdown]
# ## 3.3 Visualizing the TTVs

# %% [markdown]
# Let's plot the best 5 solutions found by the MCMC and stored in previous created variable 'best_n'

# %%
PS.constant_params
# Out:
# {6: 180.0}

# %%
from nauyaca_local.plots import plot_TTVs

n = [solution[1] for solution in best_n]
print(n)

#
n = [4.74421831e-01, 8.90246597e-01, 4.89427329e-01, 2.41637466e-01,
         9.03679716e-01, 6.78556036e-01,  9.87309434e-01,
         8.02254474e-01, 3.64701182e-01, 5.00930545e-01, 2.14019649e-01,
         3.45445574e-02, 4.51747968e-01]

bi, bf = np.array(PS.bounds).T # hypercube
flat_params2 =  bi + n*(bf - bi)  

sol1 = list(flat_params2)             # hypercube cambie a 2
for k, v in sorted(PS.constant_params.items(), key=lambda j:j[0]):
    sol1.insert(k, v)
print(sol1)
#

plot_TTVs(PS,[sol1], show_obs=True)
# Out:
# [array([4.74421831e-01, 8.90246597e-01, 4.89427329e-01, 2.41637466e-01,
#        9.03679716e-01, 6.78556036e-01, 1.80000000e+02, 9.87309434e-01,
#        8.02254474e-01, 3.64701182e-01, 5.00930545e-01, 2.14019649e-01,
#        3.45445574e-02, 4.51747968e-01])]
# [9.5409944369, 33.617780493194005, 0.09789057152671, 88.483274932, 325.32469776, 244.28017296000002, 180.0, 19.7474577366, 73.50760450894799, 0.07294658938818, 89.00186109, 77.04707364000001, 12.436040664, 171.31463424]
