# %% [markdown]
# # 4.- Running the MCMC

# %% [markdown]
# Nauyaca uses a Parallel-Tempering sampling algorithm ($\texttt{ptemcee}$; Vousden et al., 2015) to explore the parameter space at different walker temperatures. While walkers at 'hotter' temperatures can explore the parameter space more freely, the walkers at lower temperatures explore in detail small regions with high probability. There is an exchange between walkers at different temperatures, allowing the walkers do not get stuck in local high probability regions. The posteriors are drawn from the walkers at temperature 0 (the coldest).
#
# Let's import Nauyaca and other useful libraries for analysis

# %%
import nauyaca as nau

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# As before, let's load the Planetary System object

# %%
PS = nau.PlanetarySystem.load_json('SystemX.json')
print(PS)
# Out:
# --> Parameter -ecc- of planet -Planet-b- set to lower physical limit: 1e-06
# --> Parameter -ecc- of planet -Planet-c- set to lower physical limit: 1e-06
#
#  =========== Planetary System Summary ===========
# --> Parameter -ecc- of planet -Planet-b- set to lower physical limit: 1e-06
# --> Parameter -ecc- of planet -Planet-c- set to lower physical limit: 1e-06
#
# System: SystemX
# Mstar: 0.9132 Msun |  Rstar: 0.8632 Rsun
# Number of planets: 2
# Planet information:
# ------
# Planet1: Planet-b
#   Boundaries:
#     mass: (1, 20.0)  [M_earth]
#     period: (5.35, 5.36)  [d]
#     ecc: (1e-06, 0.2)
#     inclination: (85, 95)  [deg]
#     argument: (0.0, 360)  [deg]
#     mean_anomaly: (0.0, 360)  [deg]
#     ascending_node: (88.36, 88.36)  [deg]
#   TTVs: True
# ------
# Planet2: Planet-c
#   Boundaries:
#     mass: (1, 50)  [M_earth]
#     period: (11.83, 11.84)  [d]
#     ecc: (1e-06, 0.2)
#     inclination: (85, 95)  [deg]
#     argument: (0.0, 360)  [deg]
#     mean_anomaly: (0.0, 360)  [deg]
#     ascending_node: (0.0, 180.0)  [deg]
#   TTVs: True
#
# Simulation attributes:
# Reference epoch of the solutions (T0JD): 0.0 [JD]
# Total time of TTVs data (Ftime): 200 [days]
# Timestep of the simulations (dt): 0.15 [days]

# %% [markdown]
# ## 4.1 Initializing walkers

# %% [markdown]
# Before running the MCMC, we need to decide which the initial prior will be. The prior is all that information that you can provide as initial guess for the exploration. We refer to $walker$ as those data that represent a point in the parameter space. Initial walkers constitute a group of data points in the space of $\mathrm{N_{dim}}$ dimensions that are initially supplied to the MCMC.
#
# For our current problem, the number of dimensions to explore is:

# %%
PS.ndim
# Out:
# 13

# %% [markdown]
# Thus, each walker will be an array of $\mathrm{N_{dim}}$ dimensions.
#
# Let's define the main parameters to run the MCMC. We will run the MCMC along 3000 iterations saving each 50 steps.

# %%
Ntemps = 8        # Number of temperatures
Nwalkers = 100    # Number of walkers per temperature
Tmax = 50        # Maximum temperature. If None, then Parallel-Tempering chose an appropiate maximum temperature

Itmax = 3000      # Maximum number of steps
Intra_steps = 50 # Number of steps to save the chains

# %% [markdown]
# Nauyaca provides 4 forms of easily initialize walkers through the 'initial_walkers' function in the 'utils' module. Additionally, you can provide your own walkers' initial position as long as they are inside the valid boundaries.
#
# **IMPORTANT:** Initial walkers should be provided in an array of shape (Ntemps, Nwalkers, Ndim)
#
# Let's generate these 4 ways of initial walkers and plot them using the 'Plots' module

# %%
nauplot = nau.Plots(PS)

# %% [markdown]
# ###  4.1.1 Uniform distribution
#
# For all the planetary parameters, initialize walkers from an uniform distribution
# along the established boundaries for each planet. Using this option is unnecesary to run optimizers previously. We call it from the 'utils' module

# %%
walkers_uniform = nau.utils.init_walkers(PS, 
                                distribution="Uniform", 
                                ntemps=Ntemps, 
                                nwalkers=Nwalkers)
# Out:
# --> Selected distribution: Uniform

# %%
# Show the initial uniform population 
nauplot.plot_hist(chains=walkers_uniform)

# %% [markdown]
# **Note:** If there are constant values in the planet's boundaries, then that parameter will be skipped and values will not appear in the initial walkers. Here, panels without information corresponds to planet parameters that remain as fixed. In this case, the constant parameter(s) and its value correspond to:

# %%
for constant in PS.constant_params.keys():
    param = PS.params_names_all.split()[constant]
    value = PS.constant_params[constant]
    print(f"{param}: {value}")
# Out:
# ascending_node1: 88.36

# %% [markdown]
# ### 4.1.2 Gaussian distribution
#
# In order to use this function, you need to provide the information comming from the optimizers saved in the **_cube.opt** file. Let's load the results from the optimizers that we got in the previous tutorial:

# %%
RESULTS_opt = np.genfromtxt(f'{PS.system_name}_cube.opt')

# %% [markdown]
# Provide the results directly from the optimizers (through opt_data argument) and construct a gaussian with the mean and standard deviation of the solutions along each dimension. In opt_data, pass RESULTS_opt (from optimizers or from file). Argument 'fbest' selects a fraction of the best solutions and discard the rest. For example, fbest=.3 takes the best 30% of the solutions, according to their $\chi^2$

# %%
walkers_gaussian = nau.utils.init_walkers(PS, 
                                   distribution = "Gaussian",
                                   opt_data = RESULTS_opt, 
                                   fbest = 0.3,
                                   ntemps = Ntemps, 
                                   nwalkers = Nwalkers)
# Out:
# --> Selected distribution: Gaussian
#     24 of 80 solutions taken

# %% [markdown]
# **Note:** the walkers_gaussian variable contains the walkers information normalized between 0 and 1. Try printing that variable to corroborate. That's a map between the physical boundaries and the hypercube with which Nauyaca internally works. However, we can visualize the physical results when passing that variable to the Plots module:

# %%
nauplot.plot_hist(chains=walkers_gaussian)

# %% [markdown]
# That will be the initial distribution of walkers

# %% [markdown]
# ### 4.1.3 Picked distribution
#
# Provide the results of the optimizers (through opt_data argument) to construct a discrete distribution by randomly selecting values around the optimizer solutions. In opt_data, pass RESULTS_opt (from optimizers) or results_opt (from file) fbest selects a fraction of the best solutions and discard the rest. For example, .3 takes the 30% of the solutions with the best $\chi^2$

# %%
walkers_picked = nau.utils.init_walkers(PS, 
                                 distribution = "Picked", 
                                 opt_data = RESULTS_opt, 
                                 fbest = .3,
                                 ntemps = Ntemps, 
                                 nwalkers = Nwalkers)
# Out:
# --> Selected distribution: Picked
#     24 of 80 solutions taken

# %%
nauplot.plot_hist(chains=walkers_picked)

# %% [markdown]
# ### 4.1.4 Ladder distribution

# %% [markdown]
# Provide the results of the optimizers (through opt_data argument).
# This method separate the solutions from optimizers in chunks corresponding to the number of temperatures. Then, each temperature draw their own walkers by following the rule:
# First temperature draw walkers from the first chunk (which includes the solution with the topmost solution). Second temperature draw walkers from first and second chunks. Third temperature draw walkers from first, second and third chunks. The same rule follows for the rest of the temperatures.
#
# In opt_data, pass RESULTS_opt (from optimizers) or results_opt (from file). fbest selects a fraction of the best solutions and discard the rest. For example, .3 takes the 30% of the solutions with the best $\chi^2$

# %%
walkers_ladder = nau.utils.init_walkers(PS, 
                                distribution = "Ladder",
                                opt_data = RESULTS_opt, 
                                fbest = 0.3,
                                ntemps = Ntemps, 
                                nwalkers = Nwalkers)
# Out:
# --> Selected distribution: Ladder
#     24 of 80 solutions taken

# %%
nauplot.plot_hist(chains=walkers_ladder)

# %% [markdown]
# ## 4.2 Running the MCMC

# %% [markdown]
# Let's run the MCMC using the initial walkers from the Ladder distribution generated above. Also provide the necessary keyword arguments. Many of them were defined at the beggining of section 3.1

# %%
nauMCMC = nau.MCMC(
            PS,                             # Planetary System object
            p0 = walkers_ladder,            # Initial population of walkers 
            tmax = Tmax,                    # Maximum temperature
            itmax = Itmax,                  # Maximum nomber of iterations (steps)
            intra_steps = Intra_steps,      # Save data each this number of steps
            cores = 8,                      # Number of cores to run in parallel
            suffix='')

# %%
RESULTS_mcmc = nauMCMC.run()
# Out:
#  =========== PARALLEL-TEMPERING MCMC ===========
#
# --> Starting date:  2021-02-09 01:03
# --> Reference epoch of the solutions:  0.0  [JD]
# --> Results will be saved at:  ./SystemX.hdf5
# --> MCMC parameters:
#       -ntemps: 8
#       -nwalkers: 100
#       -itmax: 3000
#       -intra_steps: 50
#
# --------- Iteration:  50
#  Mean tau: 0.308
#  Accepted swap fraction in Temp 0:  0.05
#  Mean acceptance fraction Temp 0:  0.13
#  Mean likelihood:  -15513.886954
#  Maximum likelihood:  (0, 32) 206.744198
#  Current mean likelihood dispersion:  0.0
#  Saving time: 0.04835 sec
#  Elapsed time:  0.2879 min
# --------- Iteration:  100
#  Mean tau: 0.591
#  Accepted swap fraction in Temp 0:  0.028
#  Mean acceptance fraction Temp 0:  0.132
#  Mean likelihood:  -14.443238
#  Maximum likelihood:  (0, 23) 293.685857
#  Current mean likelihood dispersion:  7749.721858
#  Saving time: 0.01226 sec
#  Elapsed time:  0.5757 min
# --------- Iteration:  150
#  Mean tau: 0.85
#  Accepted swap fraction in Temp 0:  0.02
#  Mean acceptance fraction Temp 0:  0.118
#  Mean likelihood:  229.421013
#  Maximum likelihood:  (0, 80) 297.20385
#  Current mean likelihood dispersion:  121.932125
#  Saving time: 0.01599 sec
#  Elapsed time:  0.869 min
# --------- Iteration:  200
#  Mean tau: 1.082
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.11
#  Mean likelihood:  282.775151
#  Maximum likelihood:  (0, 16) 302.529764
#  Current mean likelihood dispersion:  129.381094
#  Saving time: 0.01517 sec
#  Elapsed time:  1.1895 min
# --------- Iteration:  250
#  Mean tau: 1.286
#  Accepted swap fraction in Temp 0:  0.014
#  Mean acceptance fraction Temp 0:  0.105
#  Mean likelihood:  292.572223
#  Maximum likelihood:  (0, 5) 306.315478
#  Current mean likelihood dispersion:  27.750319
#  Saving time: 0.01370 sec
#  Elapsed time:  1.5006 min
# --------- Iteration:  300
#  Mean tau: 1.461
#  Accepted swap fraction in Temp 0:  0.015
#  Mean acceptance fraction Temp 0:  0.099
#  Mean likelihood:  294.424138
#  Maximum likelihood:  (0, 73) 308.709951
#  Current mean likelihood dispersion:  26.569786
#  Saving time: 0.01424 sec
#  Elapsed time:  1.8332 min
# --------- Iteration:  350
#  Mean tau: 1.604
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.094
#  Mean likelihood:  296.375861
#  Maximum likelihood:  (0, 83) 311.217726
#  Current mean likelihood dispersion:  5.234306
#  Saving time: 0.01754 sec
#  Elapsed time:  2.1529 min
# --------- Iteration:  400
#  Mean tau: 1.715
#  Accepted swap fraction in Temp 0:  0.021
#  Mean acceptance fraction Temp 0:  0.089
#  Mean likelihood:  301.676708
#  Maximum likelihood:  (0, 10) 326.056088
#  Current mean likelihood dispersion:  6.194277
#  Saving time: 0.01567 sec
#  Elapsed time:  2.4854 min
# --------- Iteration:  450
#  Mean tau: 1.792
#  Accepted swap fraction in Temp 0:  0.023
#  Mean acceptance fraction Temp 0:  0.086
#  Mean likelihood:  306.941904
#  Maximum likelihood:  (0, 29) 327.097444
#  Current mean likelihood dispersion:  5.245351
#  Saving time: 0.01917 sec
#  Elapsed time:  2.8256 min
# --------- Iteration:  500
#  Mean tau: 1.834
#  Accepted swap fraction in Temp 0:  0.023
#  Mean acceptance fraction Temp 0:  0.083
#  Mean likelihood:  311.348061
#  Maximum likelihood:  (0, 1) 334.370299
#  Current mean likelihood dispersion:  6.798509
#  Saving time: 0.01922 sec
#  Elapsed time:  3.1658 min
# --------- Iteration:  550
#  Mean tau: 1.836
#  Accepted swap fraction in Temp 0:  0.023
#  Mean acceptance fraction Temp 0:  0.081
#  Mean likelihood:  317.2484
#  Maximum likelihood:  (0, 16) 335.808522
#  Current mean likelihood dispersion:  8.069536
#  Saving time: 0.02647 sec
#  Elapsed time:  3.5568 min
# --------- Iteration:  600
#  Mean tau: 1.839
#  Accepted swap fraction in Temp 0:  0.022
#  Mean acceptance fraction Temp 0:  0.079
#  Mean likelihood:  320.137623
#  Maximum likelihood:  (0, 92) 339.471441
#  Current mean likelihood dispersion:  9.225705
#  Saving time: 0.02497 sec
#  Elapsed time:  3.9921 min
# --------- Iteration:  650
#  Mean tau: 1.841
#  Accepted swap fraction in Temp 0:  0.021
#  Mean acceptance fraction Temp 0:  0.077
#  Mean likelihood:  325.270824
#  Maximum likelihood:  (0, 87) 342.661002
#  Current mean likelihood dispersion:  9.584232
#  Saving time: 0.02162 sec
#  Elapsed time:  4.5111 min
# --------- Iteration:  700
#  Mean tau: 1.844
#  Accepted swap fraction in Temp 0:  0.02
#  Mean acceptance fraction Temp 0:  0.076
#  Mean likelihood:  329.171162
#  Maximum likelihood:  (0, 87) 343.889914
#  Current mean likelihood dispersion:  10.740742
#  Saving time: 0.02837 sec
#  Elapsed time:  4.9107 min
# --------- Iteration:  750
#  Mean tau: 1.847
#  Accepted swap fraction in Temp 0:  0.02
#  Mean acceptance fraction Temp 0:  0.075
#  Mean likelihood:  332.495907
#  Maximum likelihood:  (0, 97) 343.335726
#  Current mean likelihood dispersion:  10.160552
#  Saving time: 0.03303 sec
#  Elapsed time:  5.3184 min
# --------- Iteration:  800
#  Mean tau: 1.85
#  Accepted swap fraction in Temp 0:  0.019
#  Mean acceptance fraction Temp 0:  0.075
#  Mean likelihood:  333.541923
#  Maximum likelihood:  (0, 98) 344.990053
#  Current mean likelihood dispersion:  10.747632
#  Saving time: 0.01521 sec
#  Elapsed time:  5.8012 min
# --------- Iteration:  850
#  Mean tau: 1.852
#  Accepted swap fraction in Temp 0:  0.018
#  Mean acceptance fraction Temp 0:  0.074
#  Mean likelihood:  334.858797
#  Maximum likelihood:  (0, 57) 345.522567
#  Current mean likelihood dispersion:  9.535249
#  Saving time: 0.02140 sec
#  Elapsed time:  6.2546 min
# --------- Iteration:  900
#  Mean tau: 1.854
#  Accepted swap fraction in Temp 0:  0.018
#  Mean acceptance fraction Temp 0:  0.073
#  Mean likelihood:  335.794018
#  Maximum likelihood:  (0, 8) 345.960491
#  Current mean likelihood dispersion:  9.775037
#  Saving time: 0.01982 sec
#  Elapsed time:  6.7619 min
# --------- Iteration:  950
#  Mean tau: 1.857
#  Accepted swap fraction in Temp 0:  0.018
#  Mean acceptance fraction Temp 0:  0.072
#  Mean likelihood:  337.177032
#  Maximum likelihood:  (0, 55) 349.193845
#  Current mean likelihood dispersion:  8.399886
#  Saving time: 0.01892 sec
#  Elapsed time:  7.1904 min
# --------- Iteration:  1000
#  Mean tau: 1.859
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.07
#  Mean likelihood:  338.65977
#  Maximum likelihood:  (0, 19) 351.82132
#  Current mean likelihood dispersion:  8.605973
#  Saving time: 0.02404 sec
#  Elapsed time:  7.6262 min
# --------- Iteration:  1050
#  Mean tau: 1.862
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.069
#  Mean likelihood:  338.860339
#  Maximum likelihood:  (0, 97) 352.27562
#  Current mean likelihood dispersion:  7.058227
#  Saving time: 0.01974 sec
#  Elapsed time:  8.0621 min
# --------- Iteration:  1100
#  Mean tau: 1.865
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.068
#  Mean likelihood:  339.791423
#  Maximum likelihood:  (0, 35) 352.232448
#  Current mean likelihood dispersion:  7.162653
#  Saving time: 0.02012 sec
#  Elapsed time:  8.4894 min
# --------- Iteration:  1150
#  Mean tau: 1.868
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.067
#  Mean likelihood:  341.039977
#  Maximum likelihood:  (0, 52) 352.137447
#  Current mean likelihood dispersion:  6.031316
#  Saving time: 0.02535 sec
#  Elapsed time:  8.9571 min
# --------- Iteration:  1200
#  Mean tau: 1.871
#  Accepted swap fraction in Temp 0:  0.016
#  Mean acceptance fraction Temp 0:  0.067
#  Mean likelihood:  341.981186
#  Maximum likelihood:  (0, 97) 352.470935
#  Current mean likelihood dispersion:  6.18189
#  Saving time: 0.02611 sec
#  Elapsed time:  9.4841 min
# --------- Iteration:  1250
#  Mean tau: 1.874
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.066
#  Mean likelihood:  342.738924
#  Maximum likelihood:  (0, 97) 353.466751
#  Current mean likelihood dispersion:  4.946946
#  Saving time: 0.02270 sec
#  Elapsed time:  9.8856 min
# --------- Iteration:  1300
#  Mean tau: 1.878
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.065
#  Mean likelihood:  343.048779
#  Maximum likelihood:  (0, 84) 354.172764
#  Current mean likelihood dispersion:  5.077499
#  Saving time: 0.02473 sec
#  Elapsed time:  10.2689 min
# --------- Iteration:  1350
#  Mean tau: 1.881
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.064
#  Mean likelihood:  342.72931
#  Maximum likelihood:  (0, 97) 353.882729
#  Current mean likelihood dispersion:  4.168913
#  Saving time: 0.02634 sec
#  Elapsed time:  10.663 min
# --------- Iteration:  1400
#  Mean tau: 1.885
#  Accepted swap fraction in Temp 0:  0.017
#  Mean acceptance fraction Temp 0:  0.063
#  Mean likelihood:  344.007802
#  Maximum likelihood:  (0, 26) 359.979752
#  Current mean likelihood dispersion:  4.298019
#  Saving time: 0.02794 sec
#  Elapsed time:  11.0572 min
# --------- Iteration:  1450
#  Mean tau: 1.888
#  Accepted swap fraction in Temp 0:  0.018
#  Mean acceptance fraction Temp 0:  0.062
#  Mean likelihood:  343.946536
#  Maximum likelihood:  (0, 26) 366.40745
#  Current mean likelihood dispersion:  3.726814
#  Saving time: 0.02655 sec
#  Elapsed time:  11.4562 min
# --------- Iteration:  1500
#  Mean tau: 1.892
#  Accepted swap fraction in Temp 0:  0.019
#  Mean acceptance fraction Temp 0:  0.062
#  Mean likelihood:  344.536626
#  Maximum likelihood:  (0, 26) 371.486654
#  Current mean likelihood dispersion:  3.818411
#  Saving time: 0.02528 sec
#  Elapsed time:  11.8529 min
# --------- Iteration:  1550
#  Mean tau: 1.896
#  Accepted swap fraction in Temp 0:  0.02
#  Mean acceptance fraction Temp 0:  0.061
#  Mean likelihood:  345.594002
#  Maximum likelihood:  (0, 26) 371.486654
#  Current mean likelihood dispersion:  3.582844
#  Saving time: 0.01452 sec
#  Elapsed time:  12.3131 min
# --------- Iteration:  1600
#  Mean tau: 1.9
#  Accepted swap fraction in Temp 0:  0.02
#  Mean acceptance fraction Temp 0:  0.06
#  Mean likelihood:  345.748795
#  Maximum likelihood:  (0, 26) 369.946156
#  Current mean likelihood dispersion:  3.68725
#  Saving time: 0.01511 sec
#  Elapsed time:  12.7046 min
# --------- Iteration:  1650
#  Mean tau: 1.905
#  Accepted swap fraction in Temp 0:  0.021
#  Mean acceptance fraction Temp 0:  0.059
#  Mean likelihood:  347.074107
#  Maximum likelihood:  (0, 26) 370.552596
#  Current mean likelihood dispersion:  3.483718
#  Saving time: 0.01594 sec
#  Elapsed time:  13.101 min
# --------- Iteration:  1700
#  Mean tau: 1.909
#  Accepted swap fraction in Temp 0:  0.022
#  Mean acceptance fraction Temp 0:  0.058
#  Mean likelihood:  347.400663
#  Maximum likelihood:  (0, 26) 370.552596
#  Current mean likelihood dispersion:  3.635062
#  Saving time: 0.01655 sec
#  Elapsed time:  13.482 min
# --------- Iteration:  1750
#  Mean tau: 1.914
#  Accepted swap fraction in Temp 0:  0.022
#  Mean acceptance fraction Temp 0:  0.058
#  Mean likelihood:  347.970748
#  Maximum likelihood:  (0, 26) 370.552596
#  Current mean likelihood dispersion:  3.451426
#  Saving time: 0.01695 sec
#  Elapsed time:  13.8581 min
# --------- Iteration:  1800
#  Mean tau: 1.919
#  Accepted swap fraction in Temp 0:  0.023
#  Mean acceptance fraction Temp 0:  0.057
#  Mean likelihood:  349.769881
#  Maximum likelihood:  (0, 7) 373.26332
#  Current mean likelihood dispersion:  3.714463
#  Saving time: 0.02097 sec
#  Elapsed time:  14.233 min
# --------- Iteration:  1850
#  Mean tau: 1.925
#  Accepted swap fraction in Temp 0:  0.023
#  Mean acceptance fraction Temp 0:  0.056
#  Mean likelihood:  350.177379
#  Maximum likelihood:  (0, 26) 374.831903
#  Current mean likelihood dispersion:  3.623974
#  Saving time: 0.01867 sec
#  Elapsed time:  14.6147 min
# --------- Iteration:  1900
#  Mean tau: 1.931
#  Accepted swap fraction in Temp 0:  0.023
#  Mean acceptance fraction Temp 0:  0.056
#  Mean likelihood:  351.226343
#  Maximum likelihood:  (0, 26) 375.628968
#  Current mean likelihood dispersion:  3.885125
#  Saving time: 0.02053 sec
#  Elapsed time:  14.9874 min
# --------- Iteration:  1950
#  Mean tau: 1.937
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.055
#  Mean likelihood:  351.751518
#  Maximum likelihood:  (0, 26) 375.628968
#  Current mean likelihood dispersion:  3.871208
#  Saving time: 0.02202 sec
#  Elapsed time:  15.3634 min
# --------- Iteration:  2000
#  Mean tau: 1.943
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.055
#  Mean likelihood:  353.199962
#  Maximum likelihood:  (0, 7) 375.673078
#  Current mean likelihood dispersion:  4.170709
#  Saving time: 0.01871 sec
#  Elapsed time:  15.7371 min
# --------- Iteration:  2050
#  Mean tau: 1.95
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.054
#  Mean likelihood:  354.014931
#  Maximum likelihood:  (0, 26) 375.125603
#  Current mean likelihood dispersion:  4.287235
#  Saving time: 0.01980 sec
#  Elapsed time:  16.1099 min
# --------- Iteration:  2100
#  Mean tau: 1.957
#  Accepted swap fraction in Temp 0:  0.025
#  Mean acceptance fraction Temp 0:  0.053
#  Mean likelihood:  354.676377
#  Maximum likelihood:  (0, 51) 374.197983
#  Current mean likelihood dispersion:  4.559535
#  Saving time: 0.02086 sec
#  Elapsed time:  16.5202 min
# --------- Iteration:  2150
#  Mean tau: 1.966
#  Accepted swap fraction in Temp 0:  0.025
#  Mean acceptance fraction Temp 0:  0.053
#  Mean likelihood:  354.587581
#  Maximum likelihood:  (0, 10) 373.723176
#  Current mean likelihood dispersion:  4.550817
#  Saving time: 0.02239 sec
#  Elapsed time:  16.9071 min
# --------- Iteration:  2200
#  Mean tau: 1.975
#  Accepted swap fraction in Temp 0:  0.025
#  Mean acceptance fraction Temp 0:  0.052
#  Mean likelihood:  355.96605
#  Maximum likelihood:  (0, 11) 374.803218
#  Current mean likelihood dispersion:  4.801189
#  Saving time: 0.02582 sec
#  Elapsed time:  17.3177 min
# --------- Iteration:  2250
#  Mean tau: 1.985
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.052
#  Mean likelihood:  357.360682
#  Maximum likelihood:  (0, 10) 376.47626
#  Current mean likelihood dispersion:  4.907142
#  Saving time: 0.02383 sec
#  Elapsed time:  17.7107 min
# --------- Iteration:  2300
#  Mean tau: 1.996
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.052
#  Mean likelihood:  357.882098
#  Maximum likelihood:  (0, 10) 376.577885
#  Current mean likelihood dispersion:  5.172495
#  Saving time: 0.01406 sec
#  Elapsed time:  18.128 min
# --------- Iteration:  2350
#  Mean tau: 2.009
#  Accepted swap fraction in Temp 0:  0.025
#  Mean acceptance fraction Temp 0:  0.051
#  Mean likelihood:  358.814097
#  Maximum likelihood:  (0, 10) 377.665462
#  Current mean likelihood dispersion:  5.295896
#  Saving time: 0.01578 sec
#  Elapsed time:  18.4879 min
# --------- Iteration:  2400
#  Mean tau: 2.023
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.051
#  Mean likelihood:  358.827929
#  Maximum likelihood:  (0, 10) 376.630092
#  Current mean likelihood dispersion:  5.506329
#  Saving time: 0.01572 sec
#  Elapsed time:  18.9378 min
# --------- Iteration:  2450
#  Mean tau: 2.039
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.05
#  Mean likelihood:  359.167328
#  Maximum likelihood:  (0, 24) 376.277578
#  Current mean likelihood dispersion:  5.55966
#  Saving time: 0.02574 sec
#  Elapsed time:  19.3877 min
# --------- Iteration:  2500
#  Mean tau: 2.058
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.05
#  Mean likelihood:  359.468104
#  Maximum likelihood:  (0, 53) 378.259936
#  Current mean likelihood dispersion:  5.718638
#  Saving time: 0.02163 sec
#  Elapsed time:  19.857 min
# --------- Iteration:  2550
#  Mean tau: 2.035
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.05
#  Mean likelihood:  360.37296
#  Maximum likelihood:  (0, 24) 376.161238
#  Current mean likelihood dispersion:  5.763851
#  Saving time: 0.02166 sec
#  Elapsed time:  20.3826 min
# --------- Iteration:  2600
#  Mean tau: 1.973
#  Accepted swap fraction in Temp 0:  0.025
#  Mean acceptance fraction Temp 0:  0.049
#  Mean likelihood:  361.452025
#  Maximum likelihood:  (0, 25) 380.213519
#  Current mean likelihood dispersion:  5.959461
#  Saving time: 0.02328 sec
#  Elapsed time:  20.9045 min
# --------- Iteration:  2650
#  Mean tau: 1.874
#  Accepted swap fraction in Temp 0:  0.025
#  Mean acceptance fraction Temp 0:  0.049
#  Mean likelihood:  362.031342
#  Maximum likelihood:  (0, 25) 380.0553
#  Current mean likelihood dispersion:  5.995695
#  Saving time: 0.02584 sec
#  Elapsed time:  21.3137 min
# --------- Iteration:  2700
#  Mean tau: 1.74
#  Accepted swap fraction in Temp 0:  0.025
#  Mean acceptance fraction Temp 0:  0.049
#  Mean likelihood:  363.033597
#  Maximum likelihood:  (0, 53) 378.149516
#  Current mean likelihood dispersion:  6.198817
#  Saving time: 0.03089 sec
#  Elapsed time:  21.7841 min
# --------- Iteration:  2750
#  Mean tau: 1.573
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.049
#  Mean likelihood:  363.371853
#  Maximum likelihood:  (0, 39) 376.625152
#  Current mean likelihood dispersion:  6.166051
#  Saving time: 0.02066 sec
#  Elapsed time:  22.2128 min
# --------- Iteration:  2800
#  Mean tau: 1.376
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.048
#  Mean likelihood:  364.224608
#  Maximum likelihood:  (0, 25) 378.032026
#  Current mean likelihood dispersion:  6.356196
#  Saving time: 0.02189 sec
#  Elapsed time:  22.6359 min
# --------- Iteration:  2850
#  Mean tau: 1.153
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.048
#  Mean likelihood:  364.767838
#  Maximum likelihood:  (0, 24) 379.907931
#  Current mean likelihood dispersion:  6.35313
#  Saving time: 0.02203 sec
#  Elapsed time:  23.0779 min
# --------- Iteration:  2900
#  Mean tau: 0.913
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.048
#  Mean likelihood:  365.792625
#  Maximum likelihood:  (0, 24) 380.456379
#  Current mean likelihood dispersion:  6.552076
#  Saving time: 0.03091 sec
#  Elapsed time:  23.5953 min
# --------- Iteration:  2950
#  Mean tau: 0.686
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.048
#  Mean likelihood:  366.344466
#  Maximum likelihood:  (0, 53) 380.199494
#  Current mean likelihood dispersion:  6.509998
#  Saving time: 0.03118 sec
#  Elapsed time:  24.0348 min
# --------- Iteration:  3000
#  Mean tau: 0.918
#  Accepted swap fraction in Temp 0:  0.024
#  Mean acceptance fraction Temp 0:  0.047
#  Mean likelihood:  366.895381
#  Maximum likelihood:  (0, 53) 380.173763
#  Current mean likelihood dispersion:  6.692991
#  Saving time: 0.02930 sec
#  Elapsed time:  24.5478 min
#
# --> Maximum number of iterations reached in MCMC
# --> Best solutions from the ./SystemX.hdf5 will be written at: ./SystemX.best
# --> Reference epoch of the solutions:  0.0  [JD]
# --> Iterations performed:  3000
# --> Elapsed time in MCMC: 24.5484 minutes

# %% [markdown]
# After the mcmc run ends, it returns the sampler object from $\texttt{ptemcee}$, with the following attributes:

# %%
RESULTS_mcmc.__dict__.keys()
# Out:
# dict_keys(['_random', '_likeprior', 'a', 'nwalkers', 'dim', 'adaptation_time', 'adaptation_lag', '_betas', 'pool', '_chain', '_logposterior', '_loglikelihood', '_beta_history', '_time', '_p0', '_logposterior0', '_loglikelihood0', 'nswap', 'nswap_accepted', 'nprop', 'nprop_accepted'])

# %% [markdown]
# We will deeply inspect these attributes in the following tutorial.

# %% [markdown]
# Okey, at this point there are two files that have been saved with the following extesions:
#
# * **.hdf5:** It contains the main results from the MCMC run. It will be useful for posterior analysis. It also can be provided to the Plots module to plot default figures from Nauyaca. This file is portable and is useful to restart an MCMC in other time or in another computer.
#
# * **.best:** It is a file containing the best solution (normalized) of each saved iteration. It correspond to the solution with the 'Maximum likelihood' indicated in the outputs.

# %% [markdown]
# ## 4.3 Results (fast version)

# %% [markdown]
# For the following analysis, let's make a burnin of the first 25% of the chains. Also remember that results are taken from temperature 0.

# %%
burn = 0.25  # Fractional lenght of the initial chains to be discarted

# %% [markdown]
# **MCMC Summary**
#
# An easy way to summarize the current MCMC run is through the mcmc_summary method in utils, passing the name of the .hdf5 file.

# %%
posteriors = nau.utils.mcmc_summary(PS, hdf5_file=f'{PS.system_name}.hdf5', burnin=burn)
# Out:
# --> Planetary System:  SystemX
#     Stellar mass:  0.9132
#     Stellar radius:  0.8632
#     Number of planets:  2
# --> Planets:
#        Planet1: Planet-b
#        Planet2: Planet-c
#
# --------------------------
# --> MCMC parameters
#     Ntemps:  8
#     Nwalkers per temperature:  100
#     Number of iterations:  3000
#     Thining:  50
#     Burnin:  0.25
#     Chain shape:  (100, 46, 13)
# --------------------------
#       RESULTS
# --> Results in File:   SystemX.hdf5
# --> Reference epoch of the solutions:  0  [JD]
# --> Best solution in MCMC
#     Logl:  380.45638
#           mass period ecc inclination argument mean_anomaly ascending_node
# Planet1: 5.3404   5.3553   0.1742   90.8035   311.4558   353.4077   88.36
# Planet2: 22.735   11.8329   0.0702   89.2394   217.9614   54.1509   108.3325
# --------------------------
# --> MCMC medians and 1-sigma errors
#              mass1      5.84 ^{+0.2}_{-0.38}
#            period1      5.3554 ^{+0.0}_{-0.0001}
#               ecc1      0.182 ^{+0.005}_{-0.006}
#       inclination1      89.67 ^{+0.51}_{-0.53}
#          argument1      312.94 ^{+1.39}_{-1.88}
#      mean_anomaly1      350.77 ^{+2.9}_{-2.06}
#              mass2      23.32 ^{+0.84}_{-0.98}
#            period2      11.83 ^{+0.0}_{-0.0}
#               ecc2       0.06 ^{+0.0}_{-0.0}
#       inclination2      90.18 ^{+0.32}_{-0.27}
#          argument2      229.21 ^{+4.88}_{-7.31}
#      mean_anomaly2      41.25 ^{+8.36}_{-5.29}
#    ascending_node2      110.38 ^{+2.36}_{-2.36}

# %% [markdown]
# That function prints a summary of the MCMC run where we can see the best solution found along the entire run and the medians of the posteriors with 1-$\sigma$ erros, corresponding to percentiles 16 and 84. Furthermore, it returns a dictionary with the flatten chains of each planetary parameter:

# %%
posteriors
# Out:
# {'mass1': array([5.90170211, 5.90476092, 5.82696804, ..., 5.47092934, 5.47092934,
#         5.47329454]),
#  'period1': array([5.35540545, 5.35539735, 5.35539626, ..., 5.35528304, 5.35528304,
#         5.35528216]),
#  'ecc1': array([0.19074787, 0.19014844, 0.18897232, ..., 0.17291657, 0.17291657,
#         0.17292826]),
#  'inclination1': array([89.95321787, 89.85101014, 89.71784691, ..., 90.06152942,
#         90.06152942, 90.06119356]),
#  'argument1': array([314.4463756 , 314.15694189, 314.09362994, ..., 310.8637328 ,
#         310.8637328 , 310.83875908]),
#  'mean_anomaly1': array([348.07148859, 348.49536411, 348.67950097, ..., 354.28213803,
#         354.28213803, 354.31268199]),
#  'mass2': array([25.17243442, 25.04691061, 24.21344025, ..., 22.34918618,
#         22.34918618, 22.33961057]),
#  'period2': array([11.83303475, 11.83303886, 11.83303221, ..., 11.83298399,
#         11.83298399, 11.83298538]),
#  'ecc2': array([0.05832215, 0.05859293, 0.06129925, ..., 0.06947093, 0.06947093,
#         0.06946881]),
#  'inclination2': array([90.08247079, 90.14028651, 90.12010799, ..., 89.88973509,
#         89.88973509, 89.88688192]),
#  'argument2': array([237.9247997 , 237.27004965, 235.06252185, ..., 218.39954797,
#         218.39954797, 218.40700663]),
#  'mean_anomaly2': array([31.3259204 , 32.06486448, 34.68534703, ..., 53.60861221,
#         53.60861221, 53.60027404]),
#  'ascending_node2': array([114.13183485, 113.83650539, 114.03132327, ..., 106.85321419,
#         106.85321419, 106.81264804])}

# %% [markdown]
# Now, it's easier to analyze individual parameters.
#
# Let's plot for example, the posterior of the 'mass1' and calculate the mean:

# %%
plt.hist(posteriors['mass1']);

mean = np.mean(posteriors['mass1'])
print(f"Mean: {mean}")
# Out:
# Mean: 5.774119731641769

# %% [markdown]
# All the results saved in the .hdf5 file can be accessed through the method 'get_mcmc_results'. First, let's print which keys are available by passin the hdf5 file and the which_keys set to True

# %%
nau.utils.get_mcmc_results(f'{PS.system_name}.hdf5', which_keys=True)
# Out:
# Available keywords:
#  ['ACC_FRAC0', 'AUTOCORR', 'BESTLOGL', 'BESTSOLS', 'BETAS', 'BOUNDS', 'BOUNDSP', 'CHAINS', 'COL_NAMES', 'CORES', 'INDEX', 'INTRA_STEPS', 'ITER_LAST', 'ITMAX', 'MEANLOGL', 'MSTAR', 'NAME', 'NDIM', 'NPLA', 'NTEMPS', 'NWALKERS', 'REF_EPOCH', 'RSTAR', 'p0']

# %% [markdown]
# These keys correspond to the main features of the MCMC saved in the .hdf5 file.
#
#
# Now, let's use the same function to extract ALL the results in the hdf5 file, which will return in a dictionary:

# %%
results_hdf5 =  nau.utils.get_mcmc_results(f'{PS.system_name}.hdf5')
results_hdf5
# Out:
# {'ACC_FRAC0': array([[0.0496    , 0.0724    , 0.1064    , 0.1227    , 0.1229    ,
#          0.1121    , 0.0939    , 0.0816    ],
#         [0.0276    , 0.04225   , 0.06525   , 0.08005   , 0.08355   ,
#          0.0778    , 0.0661    , 0.0572    ],
#         [0.01993333, 0.02996667, 0.0483    , 0.06473333, 0.0711    ,
#          0.06566667, 0.05366667, 0.04533333],
#         [0.0166    , 0.023425  , 0.03815   , 0.054325  , 0.061725  ,
#          0.057275  , 0.045875  , 0.03805   ],
#         [0.0142    , 0.01944   , 0.03182   , 0.04612   , 0.05388   ,
#          0.05158   , 0.04088   , 0.03308   ],
#         [0.01496667, 0.01853333, 0.02756667, 0.03986667, 0.04736667,
#          0.04545   , 0.0357    , 0.02853333],
#         [0.01651429, 0.0187    , 0.02511429, 0.03525714, 0.04224286,
#          0.04077143, 0.03184286, 0.02545714],
#         [0.020825  , 0.0207375 , 0.0231625 , 0.0312625 , 0.03825   ,
#          0.0373125 , 0.0293875 , 0.0238    ],
#         [0.02253333, 0.02204444, 0.0222    , 0.02813333, 0.03474444,
#          0.03411111, 0.02713333, 0.02211111],
#         [0.023     , 0.02331   , 0.02209   , 0.02571   , 0.03205   ,
#          0.03144   , 0.02499   , 0.02034   ],
#         [0.02269091, 0.02519091, 0.02319091, 0.02360909, 0.02967273,
#          0.029     , 0.023     , 0.01881818],
#         [0.02181667, 0.02624167, 0.02405833, 0.02205833, 0.02778333,
#          0.02698333, 0.02130833, 0.01755   ],
#         [0.02118462, 0.02723077, 0.02470769, 0.02071538, 0.02605385,
#          0.025     , 0.0198    , 0.01641538],
#         [0.02044286, 0.02777857, 0.02513571, 0.0196    , 0.02447857,
#          0.02327143, 0.01851429, 0.0154    ],
#         [0.01965333, 0.02798667, 0.02535333, 0.01858667, 0.02307333,
#          0.02194667, 0.01756667, 0.0146    ],
#         [0.018975  , 0.0278    , 0.025125  , 0.01755   , 0.0219    ,
#          0.0208625 , 0.0165875 , 0.013775  ],
#         [0.01836471, 0.02742353, 0.0247    , 0.01664118, 0.02078824,
#          0.01981765, 0.01581765, 0.01321176],
#         [0.01792222, 0.0272    , 0.02449444, 0.01621111, 0.02002222,
#          0.01882778, 0.01504444, 0.01256667],
#         [0.01763158, 0.02700526, 0.02424737, 0.01568421, 0.01924737,
#          0.01799474, 0.01435789, 0.01196842],
#         [0.01716   , 0.02657   , 0.02383   , 0.01508   , 0.018485  ,
#          0.017325  , 0.01379   , 0.01142   ],
#         [0.01662857, 0.02609048, 0.02341905, 0.01468095, 0.01788571,
#          0.01667143, 0.01330952, 0.01097143],
#         [0.01679091, 0.02597727, 0.023     , 0.01414091, 0.01721364,
#          0.01609091, 0.01289091, 0.01058182],
#         [0.0167913 , 0.02564348, 0.02250435, 0.0136087 , 0.0165    ,
#          0.01546957, 0.01246087, 0.01027826],
#         [0.01639167, 0.02536667, 0.02224167, 0.0131    , 0.01588333,
#          0.01490417, 0.012025  , 0.00995   ],
#         [0.01656   , 0.025296  , 0.022016  , 0.012736  , 0.015324  ,
#          0.014396  , 0.011604  , 0.009592  ],
#         [0.01688462, 0.02543462, 0.02188077, 0.01238846, 0.01491923,
#          0.01398846, 0.01118077, 0.00922308],
#         [0.01701481, 0.02544815, 0.02175926, 0.01216296, 0.01458889,
#          0.01358889, 0.0107963 , 0.0089037 ],
#         [0.01747857, 0.02556071, 0.02153214, 0.01195   , 0.01430357,
#          0.01318571, 0.01041429, 0.00858571],
#         [0.01792414, 0.02555172, 0.02132069, 0.01182414, 0.01402414,
#          0.01284483, 0.01008276, 0.00833793],
#         [0.01878   , 0.02586333, 0.02118333, 0.01166333, 0.01368667,
#          0.01245   , 0.00977333, 0.00811333],
#         [0.01970968, 0.02619355, 0.02116774, 0.01163871, 0.01334194,
#          0.01208387, 0.00949355, 0.00788387],
#         [0.02031875, 0.02624063, 0.0210375 , 0.0116125 , 0.01299687,
#          0.0117375 , 0.00922813, 0.0076625 ],
#         [0.02095758, 0.02631515, 0.02087879, 0.01161515, 0.01274848,
#          0.01144848, 0.00900606, 0.00746667],
#         [0.02154706, 0.02636765, 0.02075588, 0.01164706, 0.01248824,
#          0.01114118, 0.00877353, 0.00727059],
#         [0.02218286, 0.02653429, 0.02076286, 0.01173429, 0.01226571,
#          0.01085143, 0.00854   , 0.00708   ],
#         [0.02256111, 0.02664722, 0.02101111, 0.01192222, 0.01198056,
#          0.01056667, 0.00831111, 0.00689444],
#         [0.02298378, 0.02664595, 0.02124324, 0.01225946, 0.01174054,
#          0.01033514, 0.00812432, 0.00671892],
#         [0.02329474, 0.02664737, 0.02139737, 0.01245   , 0.01152105,
#          0.01015789, 0.00796053, 0.00654211],
#         [0.0235641 , 0.02672051, 0.02170513, 0.01268974, 0.01127179,
#          0.00994872, 0.00782308, 0.00644615],
#         [0.02404   , 0.0269025 , 0.021875  , 0.0127775 , 0.0110225 ,
#          0.0097475 , 0.007675  , 0.00633   ],
#         [0.02430244, 0.0268561 , 0.02196341, 0.01292439, 0.01077561,
#          0.00953659, 0.00752439, 0.00619512],
#         [0.02460952, 0.02682619, 0.02209524, 0.0131381 , 0.01057381,
#          0.00935   , 0.00739048, 0.0061    ],
#         [0.02470233, 0.02672791, 0.02224884, 0.01333721, 0.01037442,
#          0.00915349, 0.00723023, 0.00597209],
#         [0.02462727, 0.02658409, 0.02243636, 0.01352045, 0.01016136,
#          0.00897045, 0.00709091, 0.00585455],
#         [0.02446222, 0.02637556, 0.02253556, 0.01364889, 0.00999556,
#          0.00882222, 0.00694667, 0.00572444],
#         [0.02441739, 0.02622174, 0.0227413 , 0.01388478, 0.00982174,
#          0.00867826, 0.00681304, 0.0056    ],
#         [0.02454894, 0.02631489, 0.02301702, 0.01403617, 0.00970851,
#          0.00859787, 0.00668936, 0.00548085],
#         [0.02449583, 0.02625208, 0.02335208, 0.01433125, 0.00962292,
#          0.00851667, 0.00656667, 0.00537917],
#         [0.02447347, 0.02619184, 0.0235    , 0.01443878, 0.00958163,
#          0.00848571, 0.00643469, 0.00527347],
#         [0.024448  , 0.026188  , 0.023634  , 0.014472  , 0.009616  ,
#          0.008536  , 0.006318  , 0.005192  ],
#         [0.02445882, 0.02622157, 0.02381765, 0.01454118, 0.00973922,
#          0.00867255, 0.0062    , 0.00510196],
#         [0.02461154, 0.02632115, 0.02396731, 0.01458269, 0.00980192,
#          0.00875769, 0.00609231, 0.00501154],
#         [0.0246    , 0.02628679, 0.02406226, 0.01462075, 0.00984151,
#          0.0088283 , 0.00600377, 0.0049434 ],
#         [0.02455185, 0.02623704, 0.02415741, 0.01466481, 0.00986481,
#          0.00888148, 0.00592037, 0.00487037],
#         [0.02437818, 0.02619818, 0.02425273, 0.01463818, 0.00985636,
#          0.00890909, 0.00584909, 0.00480364],
#         [0.02428929, 0.02620357, 0.02436429, 0.014625  , 0.00989286,
#          0.00899107, 0.00579107, 0.00474643],
#         [0.02419298, 0.02619298, 0.02449825, 0.01465439, 0.00987368,
#          0.00901228, 0.00573158, 0.0046807 ],
#         [0.02404138, 0.02614138, 0.02458276, 0.01464655, 0.00986724,
#          0.00904483, 0.00566897, 0.00461379],
#         [0.02382373, 0.02607458, 0.02461186, 0.0145678 , 0.00984915,
#          0.00905424, 0.00560339, 0.00455932],
#         [0.02369   , 0.02607833, 0.02469667, 0.01451833, 0.00988667,
#          0.00911   , 0.00552167, 0.00448667]]),
#  'AUTOCORR': array([0.3079096 , 0.59139071, 0.84983699, 1.0815648 , 1.28559981,
#         1.46051853, 1.60425993, 1.71516923, 1.7923346 , 1.83353647,
#         1.83634965, 1.83887313, 1.84122802, 1.84380862, 1.84666289,
#         1.84953198, 1.85195172, 1.85428547, 1.85679179, 1.85941661,
#         1.86208956, 1.8649575 , 1.86798827, 1.87112364, 1.87438403,
#         1.87769455, 1.88110731, 1.88461715, 1.88833782, 1.89227452,
#         1.89636802, 1.9004975 , 1.90484   , 1.90933287, 1.91420016,
#         1.91937041, 1.92481208, 1.93052239, 1.93658744, 1.94294688,
#         1.94975157, 1.95730589, 1.96559304, 1.97469869, 1.98474681,
#         1.9960125 , 2.0085902 , 2.02290368, 2.03905143, 2.05808097,
#         2.03548232, 1.97335339, 1.87391742, 1.73970129, 1.57272649,
#         1.37570598, 1.15282441, 0.91274838, 0.68581301, 0.91840757]),
#  'BESTLOGL': array([206.74419753, 293.68585725, 297.20385004, 302.52976373,
#         306.31547797, 308.70995067, 311.21772622, 326.05608788,
#         327.09744357, 334.37029872, 335.80852163, 339.47144133,
#         342.66100193, 343.88991368, 343.33572646, 344.99005256,
#         345.5225666 , 345.96049105, 349.19384509, 351.82131979,
#         352.27562007, 352.23244755, 352.13744677, 352.47093472,
#         353.46675123, 354.17276436, 353.88272897, 359.9797523 ,
#         366.40744983, 371.48665414, 371.48665414, 369.94615625,
#         370.55259639, 370.55259639, 370.55259639, 373.26332005,
#         374.83190316, 375.62896815, 375.62896815, 375.67307759,
#         375.12560299, 374.197983  , 373.72317587, 374.80321765,
#         376.47626023, 376.57788509, 377.66546172, 376.63009205,
#         376.27757794, 378.25993584, 376.16123762, 380.21351919,
#         380.05530026, 378.14951597, 376.62515174, 378.03202648,
#         379.9079307 , 380.45637915, 380.19949388, 380.17376333]),
#  'BESTSOLS': array([[0.22760049, 0.54334896, 0.9928606 , 0.53625521, 0.91835122,
#          0.46049559, 0.52516779, 0.28683147, 0.28272482, 0.48126485,
#          0.37289632, 0.80592664, 0.6653575 ],
#         [0.23738721, 0.5366399 , 0.98940762, 0.47388101, 0.91938958,
#          0.45262879, 0.51530775, 0.29333161, 0.285399  , 0.52118936,
#          0.37288558, 0.80689266, 0.65175663],
#         [0.23101104, 0.54378389, 0.99175093, 0.53164398, 0.91844966,
#          0.46001179, 0.52255144, 0.28664127, 0.28314838, 0.48487867,
#          0.37292151, 0.80554171, 0.66162413],
#         [0.24101746, 0.54374741, 0.98570917, 0.53137149, 0.91878047,
#          0.45844096, 0.5117885 , 0.29249139, 0.29198763, 0.48091446,
#          0.37311631, 0.80412624, 0.65021912],
#         [0.24258316, 0.53911837, 0.98050863, 0.49474539, 0.91940488,
#          0.45426018, 0.50971417, 0.29588019, 0.2888024 , 0.5065142 ,
#          0.37328916, 0.7998076 , 0.65110009],
#         [0.24318532, 0.54499958, 0.9732162 , 0.54352419, 0.91885333,
#          0.46039814, 0.5059396 , 0.29407862, 0.29245064, 0.47097367,
#          0.37377884, 0.79109839, 0.65929064],
#         [0.24900879, 0.54149957, 0.956434  , 0.50510513, 0.91998082,
#          0.45431143, 0.502931  , 0.29930118, 0.29115374, 0.5028878 ,
#          0.37392525, 0.78756737, 0.63968526],
#         [0.25874362, 0.53994351, 0.94305764, 0.48155098, 0.92046216,
#          0.45282062, 0.48811047, 0.30368219, 0.29517682, 0.51356945,
#          0.37436622, 0.77978476, 0.63370905],
#         [0.25510039, 0.54033388, 0.95045055, 0.48893303, 0.92020464,
#          0.45353996, 0.49364931, 0.30180403, 0.29310786, 0.51020129,
#          0.37412728, 0.78402736, 0.63708166],
#         [0.24957986, 0.53948351, 0.9415284 , 0.45483373, 0.92061157,
#          0.45178334, 0.46641166, 0.30010495, 0.31278052, 0.51833032,
#          0.37486385, 0.7763409 , 0.63244838],
#         [0.26043699, 0.54140551, 0.93656583, 0.49526488, 0.92049166,
#          0.4539003 , 0.4757325 , 0.30552551, 0.30530451, 0.4983497 ,
#          0.37487024, 0.77318175, 0.6349008 ],
#         [0.26236706, 0.53827189, 0.9258998 , 0.45571555, 0.9212528 ,
#          0.44955049, 0.47331241, 0.3069085 , 0.3048331 , 0.52810545,
#          0.37492113, 0.77184949, 0.619848  ],
#         [0.26573141, 0.5417461 , 0.92866382, 0.48941571, 0.92066862,
#          0.45400816, 0.4691686 , 0.30748871, 0.30571672, 0.49934373,
#          0.37506317, 0.76921681, 0.6312959 ],
#         [0.2679818 , 0.54195419, 0.92478254, 0.48815376, 0.92076042,
#          0.45401891, 0.464804  , 0.30863909, 0.30773495, 0.49845084,
#          0.37522038, 0.76668308, 0.62964964],
#         [0.26848022, 0.53733536, 0.91426129, 0.44374779, 0.92168189,
#          0.44820198, 0.46173175, 0.31191098, 0.31488213, 0.52890372,
#          0.37563852, 0.76084602, 0.61758894],
#         [0.26924373, 0.53333482, 0.91205994, 0.39703792, 0.92232425,
#          0.44324244, 0.46246136, 0.31364476, 0.30997316, 0.56014737,
#          0.37552719, 0.7610032 , 0.61235021],
#         [0.25941268, 0.53599202, 0.90964784, 0.42151138, 0.92210162,
#          0.44554126, 0.45993234, 0.3070161 , 0.31754832, 0.54905175,
#          0.37556535, 0.76361867, 0.6066811 ],
#         [0.26842405, 0.53853608, 0.91188523, 0.43691073, 0.92156318,
#          0.44965994, 0.45198682, 0.31093762, 0.32149239, 0.52614997,
#          0.37613366, 0.75310495, 0.62208321],
#         [0.27103054, 0.53478172, 0.88838991, 0.42089906, 0.92276766,
#          0.44405666, 0.44879341, 0.31398669, 0.32191698, 0.54451169,
#          0.37612943, 0.75331194, 0.59966427],
#         [0.26836388, 0.53942519, 0.90563413, 0.45644078, 0.92167556,
#          0.45000368, 0.45634988, 0.3105946 , 0.31881281, 0.52032967,
#          0.37590772, 0.75675476, 0.61457624],
#         [0.26934668, 0.53251131, 0.89092472, 0.37357933, 0.92294875,
#          0.44196914, 0.44431365, 0.31442465, 0.32742859, 0.56787196,
#          0.37666674, 0.7440072 , 0.60418683],
#         [0.2701238 , 0.53667093, 0.89897636, 0.44448955, 0.92221288,
#          0.44671766, 0.45194513, 0.31332755, 0.32187759, 0.52467673,
#          0.37623003, 0.75109908, 0.61383719],
#         [0.26955316, 0.53619571, 0.90389749, 0.41465107, 0.92212342,
#          0.44647518, 0.45360889, 0.3128828 , 0.32021609, 0.54487123,
#          0.37617778, 0.75142094, 0.61207787],
#         [0.26954985, 0.53239169, 0.89194681, 0.36856812, 0.92292721,
#          0.4419575 , 0.44817542, 0.3150737 , 0.33185935, 0.56999487,
#          0.37695012, 0.73984222, 0.60725743],
#         [0.269919  , 0.53231506, 0.89131502, 0.37493726, 0.92295076,
#          0.44187597, 0.4470672 , 0.31541723, 0.33147948, 0.56602575,
#          0.37692128, 0.74030831, 0.60727723],
#         [0.26658069, 0.53448681, 0.88260069, 0.44266609, 0.92294824,
#          0.44364518, 0.46062456, 0.31140494, 0.32524899, 0.53239563,
#          0.37640197, 0.74890411, 0.60343062],
#         [0.2705931 , 0.53189264, 0.88847115, 0.37317684, 0.92307582,
#          0.44136169, 0.44502814, 0.31620278, 0.33497933, 0.56611082,
#          0.37714919, 0.73690662, 0.60648426],
#         [0.25905791, 0.53471544, 0.89560827, 0.43589321, 0.92248047,
#          0.44504727, 0.4506814 , 0.30832288, 0.32928971, 0.53222706,
#          0.37667602, 0.7448281 , 0.60917934],
#         [0.24398307, 0.53121551, 0.87748198, 0.4435412 , 0.92336754,
#          0.44104367, 0.45147189, 0.30151991, 0.34403378, 0.53050184,
#          0.37758969, 0.73172542, 0.60493398],
#         [0.23505289, 0.53102031, 0.87581395, 0.4471945 , 0.92340735,
#          0.44103519, 0.45501329, 0.29635229, 0.34891598, 0.53009239,
#          0.37788012, 0.72767102, 0.60505409],
#         [0.23505289, 0.53102031, 0.87581395, 0.4471945 , 0.92340735,
#          0.44103519, 0.45501329, 0.29635229, 0.34891598, 0.53009239,
#          0.37788012, 0.72767102, 0.60505409],
#         [0.22672442, 0.53082847, 0.87264359, 0.46481538, 0.92348679,
#          0.44098076, 0.45701446, 0.29171795, 0.35237468, 0.52131766,
#          0.37806278, 0.72534732, 0.60469342],
#         [0.22816257, 0.53084124, 0.87338576, 0.4623274 , 0.92347349,
#          0.44095278, 0.45708817, 0.29250523, 0.35141281, 0.52276356,
#          0.37800812, 0.72608758, 0.60475978],
#         [0.22816257, 0.53084124, 0.87338576, 0.4623274 , 0.92347349,
#          0.44095278, 0.45708817, 0.29250523, 0.35141281, 0.52276356,
#          0.37800812, 0.72608758, 0.60475978],
#         [0.22816257, 0.53084124, 0.87338576, 0.4623274 , 0.92347349,
#          0.44095278, 0.45708817, 0.29250523, 0.35141281, 0.52276356,
#          0.37800812, 0.72608758, 0.60475978],
#         [0.23489693, 0.53116466, 0.87517023, 0.45684804, 0.92341227,
#          0.44112356, 0.45330989, 0.29562392, 0.3433106 , 0.52610089,
#          0.37753225, 0.73270595, 0.60246628],
#         [0.22894664, 0.53182633, 0.8767749 , 0.4594155 , 0.92320347,
#          0.44257538, 0.44860132, 0.29251278, 0.34949573, 0.52173289,
#          0.37790342, 0.72745609, 0.60436755],
#         [0.22908896, 0.53169691, 0.87630157, 0.45890627, 0.92323472,
#          0.44240291, 0.44847364, 0.29262033, 0.34951824, 0.52237164,
#          0.37790786, 0.72737082, 0.60409959],
#         [0.22908896, 0.53169691, 0.87630157, 0.45890627, 0.92323472,
#          0.44240291, 0.44847364, 0.29262033, 0.34951824, 0.52237164,
#          0.37790786, 0.72737082, 0.60409959],
#         [0.22788454, 0.53089714, 0.86961097, 0.47807736, 0.92352782,
#          0.44121777, 0.45930885, 0.29176203, 0.34713733, 0.51296773,
#          0.37775163, 0.72972375, 0.60139118],
#         [0.22181595, 0.53191678, 0.8738794 , 0.47574933, 0.92321568,
#          0.44302149, 0.44621283, 0.28822437, 0.35203851, 0.51378894,
#          0.37803885, 0.72572155, 0.60377138],
#         [0.22824687, 0.53108382, 0.87707558, 0.46580178, 0.92324242,
#          0.44213084, 0.43894806, 0.29243233, 0.34757241, 0.50844365,
#          0.37775803, 0.72983176, 0.60354027],
#         [0.22663134, 0.53115439, 0.87040298, 0.44767777, 0.92342012,
#          0.44194048, 0.44084401, 0.29119184, 0.34634833, 0.52102863,
#          0.37771414, 0.73011984, 0.59587936],
#         [0.22971234, 0.53469728, 0.88309808, 0.48378936, 0.92248288,
#          0.44745242, 0.42565833, 0.29140455, 0.34565201, 0.50407432,
#          0.37769286, 0.73019297, 0.6049709 ],
#         [0.22916716, 0.53127627, 0.8715801 , 0.45811273, 0.92335526,
#          0.44227084, 0.43700294, 0.29226408, 0.34574674, 0.52018684,
#          0.3777003 , 0.7300792 , 0.59776059],
#         [0.22096792, 0.53221215, 0.87129397, 0.46555283, 0.92312105,
#          0.44428837, 0.42757012, 0.28691912, 0.34671819, 0.50610323,
#          0.37777956, 0.72875453, 0.59775096],
#         [0.22123801, 0.53227309, 0.8713552 , 0.4670855 , 0.92311316,
#          0.44434573, 0.42804188, 0.28702742, 0.34653458, 0.50544818,
#          0.37776664, 0.72895297, 0.5980289 ],
#         [0.21800064, 0.53245214, 0.87055361, 0.47504223, 0.92307754,
#          0.44480055, 0.42615134, 0.28495531, 0.34669318, 0.50021746,
#          0.377777  , 0.72880083, 0.59771068],
#         [0.22873216, 0.53010676, 0.86973791, 0.56151303, 0.92338656,
#          0.44231504, 0.45182823, 0.29260926, 0.34691747, 0.44260221,
#          0.37774461, 0.72974503, 0.60387465],
#         [0.21589432, 0.52902201, 0.86329112, 0.50646872, 0.92387526,
#          0.43943491, 0.44761326, 0.28541003, 0.3526967 , 0.49792875,
#          0.37799633, 0.72722242, 0.59929116],
#         [0.22884517, 0.53009914, 0.86795905, 0.572834  , 0.92342935,
#          0.44230873, 0.45836107, 0.29286329, 0.34934738, 0.4369748 ,
#          0.37787642, 0.72802547, 0.60524018],
#         [0.21776058, 0.52823276, 0.86331736, 0.48196316, 0.92383559,
#          0.43971759, 0.42842111, 0.28676066, 0.34562822, 0.51298984,
#          0.37768152, 0.73046385, 0.58879098],
#         [0.21495162, 0.52789178, 0.86101987, 0.4793369 , 0.92391409,
#          0.43948045, 0.42434904, 0.28515856, 0.34582508, 0.51492334,
#          0.37769337, 0.73029384, 0.58641269],
#         [0.20966294, 0.52807478, 0.85633032, 0.5135432 , 0.92410238,
#          0.43881697, 0.44694285, 0.28206532, 0.35689476, 0.48320959,
#          0.37823416, 0.72403179, 0.597402  ],
#         [0.23122214, 0.51913285, 0.85107786, 0.561263  , 0.92557542,
#          0.42742867, 0.43960973, 0.2976798 , 0.34184845, 0.51181125,
#          0.37741279, 0.73471759, 0.58841343],
#         [0.21721158, 0.52720071, 0.86115434, 0.47524574, 0.92402073,
#          0.43855956, 0.42661242, 0.28640764, 0.34260856, 0.52605704,
#          0.37755019, 0.73179158, 0.58423102],
#         [0.22757682, 0.52883637, 0.87178126, 0.58850899, 0.92336937,
#          0.44204439, 0.44489608, 0.29365165, 0.3513787 , 0.41562369,
#          0.37796438, 0.72712666, 0.60300356],
#         [0.22844241, 0.52873383, 0.87112035, 0.58035349, 0.92342148,
#          0.44173354, 0.44357143, 0.29419361, 0.35080811, 0.42393854,
#          0.37793373, 0.7275145 , 0.60184698],
#         [0.20778194, 0.52783479, 0.85772626, 0.51428402, 0.92405413,
#          0.43891714, 0.44541033, 0.28122376, 0.35783592, 0.46857615,
#          0.3782847 , 0.723379  , 0.59877704],
#         [0.20790677, 0.52788989, 0.8574053 , 0.51476703, 0.92405744,
#          0.43895089, 0.44525237, 0.28125428, 0.35771406, 0.46867161,
#          0.3782815 , 0.72337857, 0.59878026]]),
#  'BETAS': array([[1.        , 0.57742505, 0.33041715, 0.18852931, 0.10721345,
#          0.06109048, 0.03476769, 0.02      ],
#         [1.        , 0.57899975, 0.3317052 , 0.18957679, 0.10750518,
#          0.0611932 , 0.03471883, 0.02      ],
#         [1.        , 0.57919292, 0.33291619, 0.19089731, 0.10795664,
#          0.06119784, 0.0346134 , 0.02      ],
#         [1.        , 0.5785223 , 0.33362484, 0.19182766, 0.10833695,
#          0.06123372, 0.03453161, 0.02      ],
#         [1.        , 0.57826002, 0.33410396, 0.1922014 , 0.10875638,
#          0.0613622 , 0.03445868, 0.02      ],
#         [1.        , 0.57712057, 0.33332594, 0.19235597, 0.10885181,
#          0.06136644, 0.03440119, 0.02      ],
#         [1.        , 0.5756792 , 0.3324097 , 0.19208171, 0.10892371,
#          0.06132967, 0.03436473, 0.02      ],
#         [1.        , 0.57190695, 0.32987119, 0.19148691, 0.10889988,
#          0.06129874, 0.03435505, 0.02      ],
#         [1.        , 0.57103582, 0.32766798, 0.19096398, 0.1087621 ,
#          0.06128323, 0.03434296, 0.02      ],
#         [1.        , 0.57278929, 0.32541761, 0.19049167, 0.10860869,
#          0.06122434, 0.03430574, 0.02      ],
#         [1.        , 0.57845133, 0.32260977, 0.18971917, 0.108388  ,
#          0.06110352, 0.03427494, 0.02      ],
#         [1.        , 0.58434336, 0.32036155, 0.18902737, 0.10819684,
#          0.06096726, 0.03424478, 0.02      ],
#         [1.        , 0.59016048, 0.31767625, 0.18839248, 0.10783667,
#          0.06083774, 0.0342194 , 0.02      ],
#         [1.        , 0.59561055, 0.31531753, 0.18775262, 0.1074632 ,
#          0.06073352, 0.034192  , 0.02      ],
#         [1.        , 0.60060829, 0.313249  , 0.18707367, 0.10716352,
#          0.06068185, 0.03416309, 0.02      ],
#         [1.        , 0.60420995, 0.31149505, 0.18643287, 0.10705873,
#          0.06059456, 0.03412848, 0.02      ],
#         [1.        , 0.60703438, 0.30996028, 0.18591636, 0.10690505,
#          0.06053796, 0.03412016, 0.02      ],
#         [1.        , 0.60988231, 0.30854255, 0.1856298 , 0.10659334,
#          0.06044273, 0.03408578, 0.02      ],
#         [1.        , 0.61229797, 0.30708544, 0.18518224, 0.1063585 ,
#          0.06036239, 0.03404934, 0.02      ],
#         [1.        , 0.61448025, 0.30588342, 0.18475778, 0.10622653,
#          0.06032937, 0.0340118 , 0.02      ],
#         [1.        , 0.61673435, 0.3047907 , 0.18457644, 0.10599885,
#          0.06029831, 0.03397905, 0.02      ],
#         [1.        , 0.61746076, 0.30318414, 0.18407756, 0.10578942,
#          0.06027497, 0.03394888, 0.02      ],
#         [1.        , 0.61777899, 0.30212259, 0.18358866, 0.10564388,
#          0.06024166, 0.0339463 , 0.02      ],
#         [1.        , 0.62026996, 0.30069217, 0.18304671, 0.1054842 ,
#          0.06018276, 0.0339329 , 0.02      ],
#         [1.        , 0.62089963, 0.29945853, 0.18242375, 0.10529683,
#          0.06011716, 0.03390545, 0.02      ],
#         [1.        , 0.62171302, 0.29767958, 0.18173065, 0.10512828,
#          0.06000288, 0.03386121, 0.02      ],
#         [1.        , 0.62283452, 0.29620721, 0.18119952, 0.10492699,
#          0.05988731, 0.03382177, 0.02      ],
#         [1.        , 0.62254481, 0.29453142, 0.1807308 , 0.10468445,
#          0.05976089, 0.03378012, 0.02      ],
#         [1.        , 0.62149627, 0.29364558, 0.18025674, 0.10453297,
#          0.05964197, 0.03374978, 0.02      ],
#         [1.        , 0.61971073, 0.29203501, 0.17957618, 0.10423137,
#          0.0595214 , 0.03372133, 0.02      ],
#         [1.        , 0.6173563 , 0.29099034, 0.17882795, 0.10390334,
#          0.0594165 , 0.03368636, 0.02      ],
#         [1.        , 0.61500747, 0.29057312, 0.17825395, 0.10365312,
#          0.05933897, 0.03365892, 0.02      ],
#         [1.        , 0.61241711, 0.28996749, 0.17779503, 0.10338618,
#          0.05926007, 0.03362478, 0.02      ],
#         [1.        , 0.60979176, 0.28957285, 0.17732286, 0.10310441,
#          0.05917604, 0.03359397, 0.02      ],
#         [1.        , 0.60743507, 0.28909173, 0.17675012, 0.10278949,
#          0.05906359, 0.0335577 , 0.02      ],
#         [1.        , 0.60638207, 0.28940504, 0.17596058, 0.10248561,
#          0.05895462, 0.03352373, 0.02      ],
#         [1.        , 0.60403778, 0.29073172, 0.17528661, 0.10220255,
#          0.0588693 , 0.03348391, 0.02      ],
#         [1.        , 0.60240492, 0.29142966, 0.17459237, 0.10196615,
#          0.058795  , 0.03343678, 0.02      ],
#         [1.        , 0.60154077, 0.29226037, 0.1737222 , 0.10166163,
#          0.05870195, 0.03340907, 0.02      ],
#         [1.        , 0.59981722, 0.29224161, 0.17280817, 0.10136545,
#          0.05860514, 0.03337649, 0.02      ],
#         [1.        , 0.59785979, 0.29305567, 0.17208951, 0.10108656,
#          0.05853435, 0.03334516, 0.02      ],
#         [1.        , 0.59554803, 0.29416311, 0.17134076, 0.10081054,
#          0.05843966, 0.03331796, 0.02      ],
#         [1.        , 0.59435544, 0.29535406, 0.17061058, 0.1005369 ,
#          0.05833749, 0.03328591, 0.02      ],
#         [1.        , 0.5941573 , 0.29665999, 0.16984208, 0.1002628 ,
#          0.05825111, 0.03325425, 0.02      ],
#         [1.        , 0.59415692, 0.29783828, 0.16919463, 0.1000602 ,
#          0.05816078, 0.03321779, 0.02      ],
#         [1.        , 0.59354832, 0.29959496, 0.16836195, 0.09979485,
#          0.05805918, 0.03317536, 0.02      ],
#         [1.        , 0.59354784, 0.30020916, 0.16736692, 0.09955249,
#          0.05792006, 0.03311838, 0.02      ],
#         [1.        , 0.59380113, 0.30201327, 0.1663941 , 0.0992981 ,
#          0.05776165, 0.03306424, 0.02      ],
#         [1.        , 0.5937817 , 0.30289217, 0.16554942, 0.0992016 ,
#          0.05759293, 0.03301002, 0.02      ],
#         [1.        , 0.59432352, 0.30319929, 0.16470696, 0.09923704,
#          0.05739166, 0.03295055, 0.02      ],
#         [1.        , 0.59488176, 0.30360605, 0.16379143, 0.09937571,
#          0.05713778, 0.03287005, 0.02      ],
#         [1.        , 0.59469045, 0.30369736, 0.16285167, 0.09941131,
#          0.0569117 , 0.0327929 , 0.02      ],
#         [1.        , 0.59478566, 0.30419307, 0.16201079, 0.09945354,
#          0.05671141, 0.0327263 , 0.02      ],
#         [1.        , 0.59509008, 0.30474192, 0.16119619, 0.09945582,
#          0.05652551, 0.03265888, 0.02      ],
#         [1.        , 0.59681174, 0.30474831, 0.16045762, 0.09942992,
#          0.05637142, 0.03259873, 0.02      ],
#         [1.        , 0.59814848, 0.30473339, 0.15965056, 0.09945741,
#          0.05619089, 0.03252756, 0.02      ],
#         [1.        , 0.59942142, 0.30501695, 0.15882054, 0.09936106,
#          0.05603824, 0.03246144, 0.02      ],
#         [1.        , 0.60087553, 0.30520624, 0.15806697, 0.099321  ,
#          0.05588316, 0.03239559, 0.02      ],
#         [1.        , 0.6029155 , 0.30492688, 0.1574381 , 0.0993052 ,
#          0.05573819, 0.03234261, 0.02      ],
#         [1.        , 0.6048504 , 0.30459388, 0.15670437, 0.09933548,
#          0.05553646, 0.03226938, 0.02      ]]),
#  'BOUNDS': array([[1.000e+00, 2.000e+01],
#         [5.350e+00, 5.360e+00],
#         [1.000e-06, 2.000e-01],
#         [8.500e+01, 9.500e+01],
#         [0.000e+00, 3.600e+02],
#         [0.000e+00, 3.600e+02],
#         [1.000e+00, 5.000e+01],
#         [1.183e+01, 1.184e+01],
#         [1.000e-06, 2.000e-01],
#         [8.500e+01, 9.500e+01],
#         [0.000e+00, 3.600e+02],
#         [0.000e+00, 3.600e+02],
#         [0.000e+00, 1.800e+02]]),
#  'BOUNDSP': array([[ 1.000e+00,  2.000e+01],
#         [ 5.350e+00,  5.360e+00],
#         [ 1.000e-06,  2.000e-01],
#         [ 8.500e+01,  9.500e+01],
#         [ 0.000e+00,  7.200e+02],
#         [-3.600e+02,  3.600e+02],
#         [ 1.000e+00,  5.000e+01],
#         [ 1.183e+01,  1.184e+01],
#         [ 1.000e-06,  2.000e-01],
#         [ 8.500e+01,  9.500e+01],
#         [ 0.000e+00,  7.200e+02],
#         [-3.600e+02,  3.600e+02],
#         [ 0.000e+00,  1.800e+02]]),
#  'CHAINS': array([[[[4.40461612e-01, 4.49881311e-01, 5.58642671e-01, ...,
#            8.69457497e-01, 2.95758720e-01, 5.15755756e-01],
#           [2.26738131e-01, 5.45338945e-01, 9.94225849e-01, ...,
#            3.72848006e-01, 8.06614790e-01, 6.66050223e-01],
#           [2.30958253e-01, 5.41942246e-01, 9.92509450e-01, ...,
#            3.72851542e-01, 8.06893975e-01, 6.60215647e-01],
#           ...,
#           [2.23234367e-01, 5.31994900e-01, 8.84957240e-01, ...,
#            3.77355678e-01, 7.35885661e-01, 6.08035682e-01],
#           [2.23234367e-01, 5.31994900e-01, 8.84957240e-01, ...,
#            3.77355678e-01, 7.35885661e-01, 6.08035682e-01],
#           [2.19943748e-01, 5.31151777e-01, 8.80466614e-01, ...,
#            3.77633957e-01, 7.32070525e-01, 6.08180000e-01]],
#
#          [[2.48335979e-01, 5.34254264e-01, 9.68164347e-01, ...,
#            3.72691732e-01, 8.10391548e-01, 6.21937222e-01],
#           [2.29184806e-01, 5.43001124e-01, 9.93100772e-01, ...,
#            3.72877075e-01, 8.06491285e-01, 6.63475930e-01],
#           [2.38322192e-01, 5.37595995e-01, 9.84551976e-01, ...,
#            3.73201986e-01, 8.00947889e-01, 6.55644226e-01],
#           ...,
#           [2.36025193e-01, 5.25052574e-01, 8.67793033e-01, ...,
#            3.77049478e-01, 7.39867963e-01, 5.84497406e-01],
#           [2.27196854e-01, 5.26596732e-01, 8.63699454e-01, ...,
#            3.77131524e-01, 7.37175936e-01, 5.88606819e-01],
#           [2.27196854e-01, 5.26596732e-01, 8.63699454e-01, ...,
#            3.77131524e-01, 7.37175936e-01, 5.88606819e-01]],
#
#          [[2.44122819e-01, 5.29856450e-01, 9.83887701e-01, ...,
#            3.72788192e-01, 8.09641607e-01, 6.36956822e-01],
#           [2.29616792e-01, 5.43162498e-01, 9.92032306e-01, ...,
#            3.72879635e-01, 8.06415292e-01, 6.62338340e-01],
#           [2.33073016e-01, 5.39853541e-01, 9.90048463e-01, ...,
#            3.72910624e-01, 8.06334503e-01, 6.58192501e-01],
#           ...,
#           [2.40567577e-01, 5.22337100e-01, 8.58931344e-01, ...,
#            3.77526148e-01, 7.34400748e-01, 5.90935232e-01],
#           [2.40645759e-01, 5.22299166e-01, 8.58818751e-01, ...,
#            3.77526647e-01, 7.34401342e-01, 5.90917166e-01],
#           [2.42671243e-01, 5.21252988e-01, 8.56286257e-01, ...,
#            3.77493727e-01, 7.35125651e-01, 5.88090070e-01]],
#
#          ...,
#
#          [[2.35097097e-01, 5.38536266e-01, 9.85456802e-01, ...,
#            3.72868083e-01, 8.07223890e-01, 6.51055331e-01],
#           [2.33075232e-01, 5.40602663e-01, 9.91422623e-01, ...,
#            3.72844869e-01, 8.07222515e-01, 6.57273921e-01],
#           [2.33161716e-01, 5.40396864e-01, 9.91596806e-01, ...,
#            3.72831965e-01, 8.07447135e-01, 6.56935357e-01],
#           ...,
#           [2.35928435e-01, 5.30304385e-01, 8.67498427e-01, ...,
#            3.77874603e-01, 7.27564006e-01, 5.98827343e-01],
#           [2.36340506e-01, 5.29738549e-01, 8.68063755e-01, ...,
#            3.77904799e-01, 7.27183965e-01, 5.97323858e-01],
#           [2.36340506e-01, 5.29738549e-01, 8.68063755e-01, ...,
#            3.77904799e-01, 7.27183965e-01, 5.97323858e-01]],
#
#          [[2.41870357e-01, 5.31981374e-01, 9.83623117e-01, ...,
#            3.72830022e-01, 8.08623319e-01, 6.40397164e-01],
#           [2.26131592e-01, 5.46656567e-01, 9.94269454e-01, ...,
#            3.72827971e-01, 8.06969903e-01, 6.66585065e-01],
#           [2.25700451e-01, 5.47004837e-01, 9.95870113e-01, ...,
#            3.72753652e-01, 8.08333626e-01, 6.66259935e-01],
#           ...,
#           [2.42691296e-01, 5.37341791e-01, 9.38129595e-01, ...,
#            3.75101551e-01, 7.76189889e-01, 6.19628690e-01],
#           [2.17129584e-01, 5.43129989e-01, 9.30814487e-01, ...,
#            3.75607412e-01, 7.73131638e-01, 6.09489634e-01],
#           [2.47655386e-01, 5.39936042e-01, 9.33575929e-01, ...,
#            3.75097716e-01, 7.75217978e-01, 6.08062260e-01]],
#
#          [[2.29082947e-01, 5.46674551e-01, 9.89412564e-01, ...,
#            3.72860387e-01, 8.06516049e-01, 6.60463595e-01],
#           [2.26759352e-01, 5.44846891e-01, 9.94584209e-01, ...,
#            3.72835508e-01, 8.06818684e-01, 6.65941448e-01],
#           [2.29559681e-01, 5.42798673e-01, 9.93464571e-01, ...,
#            3.72830532e-01, 8.07138156e-01, 6.61834499e-01],
#           ...,
#           [2.35312071e-01, 5.28304155e-01, 8.64582194e-01, ...,
#            3.77789111e-01, 7.28876300e-01, 5.93628968e-01],
#           [2.35312071e-01, 5.28304155e-01, 8.64582194e-01, ...,
#            3.77789111e-01, 7.28876300e-01, 5.93628968e-01],
#           [2.35436555e-01, 5.28215657e-01, 8.64640621e-01, ...,
#            3.77787890e-01, 7.28898240e-01, 5.93403600e-01]]],
#
#
#         [[[4.51516231e-01, 4.53775139e-01, 5.58841812e-01, ...,
#            8.70189244e-01, 3.05096736e-01, 5.14084381e-01],
#           [4.89253379e-01, 4.53156350e-01, 5.36491563e-01, ...,
#            8.70273432e-01, 2.69014245e-01, 5.02001243e-01],
#           [2.21436151e-01, 5.53448646e-01, 9.89370595e-01, ...,
#            3.72384622e-01, 8.11249430e-01, 6.73936273e-01],
#           ...,
#           [2.80513963e-01, 5.32240665e-01, 9.18347480e-01, ...,
#            3.74640388e-01, 7.71771634e-01, 6.27347288e-01],
#           [2.80513963e-01, 5.32240665e-01, 9.18347480e-01, ...,
#            3.74640388e-01, 7.71771634e-01, 6.27347288e-01],
#           [2.79586284e-01, 5.33409342e-01, 9.21248926e-01, ...,
#            3.74674752e-01, 7.71785073e-01, 6.27785945e-01]],
#
#          [[7.59181210e-02, 5.15186735e-01, 3.36885376e-01, ...,
#            3.74757458e-01, 4.37659854e-01, 6.61688569e-01],
#           [4.69833645e-01, 4.52136887e-01, 5.45271524e-01, ...,
#            8.69934424e-01, 2.75678711e-01, 5.06996026e-01],
#           [4.87810060e-01, 4.53237115e-01, 5.36910693e-01, ...,
#            8.70206627e-01, 2.67206248e-01, 5.04470255e-01],
#           ...,
#           [2.75655861e-01, 5.28827715e-01, 9.03281232e-01, ...,
#            3.75593308e-01, 7.64140132e-01, 5.96304378e-01],
#           [2.76869762e-01, 5.28192645e-01, 9.01337266e-01, ...,
#            3.75687336e-01, 7.62732351e-01, 5.94648756e-01],
#           [2.17679820e-01, 5.33249347e-01, 9.10713048e-01, ...,
#            3.76122820e-01, 7.55278101e-01, 6.01263350e-01]],
#
#          [[2.23958370e-01, 5.26984200e-01, 6.45736854e-01, ...,
#            8.69454197e-01, 9.94599837e-01, 3.16772267e-03],
#           [2.54382891e-01, 5.42697926e-01, 9.44823134e-01, ...,
#            3.72856127e-01, 8.06059884e-01, 6.12433727e-01],
#           [2.32612987e-01, 5.47773653e-01, 9.71877673e-01, ...,
#            3.72703088e-01, 8.06465286e-01, 6.62968572e-01],
#           ...,
#           [2.57595002e-01, 5.45524348e-01, 9.62113931e-01, ...,
#            3.74260941e-01, 7.83532243e-01, 6.44139658e-01],
#           [2.48257702e-01, 5.46813167e-01, 9.31844294e-01, ...,
#            3.74198077e-01, 7.83522217e-01, 6.40079672e-01],
#           [2.74829904e-01, 5.50235993e-01, 9.02495779e-01, ...,
#            3.74571831e-01, 7.70917425e-01, 6.49476953e-01]],
#
#          ...,
#
#          [[2.55754049e-01, 5.38564837e-01, 9.35752795e-01, ...,
#            3.73595486e-01, 7.94679037e-01, 6.10714939e-01],
#           [2.60840794e-01, 5.45699030e-01, 9.35014190e-01, ...,
#            3.72731783e-01, 8.08681827e-01, 5.92263951e-01],
#           [2.19983781e-01, 5.44815101e-01, 9.85003839e-01, ...,
#            3.72770870e-01, 8.04749253e-01, 6.93477371e-01],
#           ...,
#           [2.73335423e-01, 5.45561130e-01, 9.43311265e-01, ...,
#            3.74638200e-01, 7.73483584e-01, 6.34954338e-01],
#           [2.70996638e-01, 5.43822604e-01, 9.37916711e-01, ...,
#            3.74711921e-01, 7.72014806e-01, 6.32215462e-01],
#           [2.61456769e-01, 5.44683714e-01, 9.11697034e-01, ...,
#            3.74774486e-01, 7.71530331e-01, 6.34602688e-01]],
#
#          [[2.63048725e-01, 5.39506109e-01, 9.35266549e-01, ...,
#            3.72546181e-01, 8.11303772e-01, 5.82396473e-01],
#           [2.57011200e-01, 5.45137130e-01, 9.43833095e-01, ...,
#            3.72872741e-01, 8.05775403e-01, 6.08502271e-01],
#           [2.26303798e-01, 5.53913624e-01, 9.79595945e-01, ...,
#            3.72554057e-01, 8.08367205e-01, 6.74881659e-01],
#           ...,
#           [2.52959839e-01, 5.29267950e-01, 9.00208202e-01, ...,
#            3.74773855e-01, 7.76117342e-01, 6.09557081e-01],
#           [2.51014115e-01, 5.29118331e-01, 9.00495004e-01, ...,
#            3.74797873e-01, 7.75727483e-01, 6.09350207e-01],
#           [2.59683793e-01, 5.43305695e-01, 9.23185606e-01, ...,
#            3.75463226e-01, 7.61437950e-01, 6.28855525e-01]],
#
#          [[4.32722221e-01, 4.59872362e-01, 5.74049317e-01, ...,
#            8.69850670e-01, 2.92708544e-01, 5.49209672e-01],
#           [2.02622053e-01, 5.55892676e-01, 8.16033943e-01, ...,
#            8.74680170e-01, 9.47306087e-01, 5.68311972e-01],
#           [2.30984049e-01, 5.47356636e-01, 9.72020047e-01, ...,
#            3.72687904e-01, 8.06318008e-01, 6.64782901e-01],
#           ...,
#           [2.64371439e-01, 5.45618108e-01, 9.76534437e-01, ...,
#            3.75893969e-01, 7.60438729e-01, 6.39203048e-01],
#           [2.64371439e-01, 5.45618108e-01, 9.76534437e-01, ...,
#            3.75893969e-01, 7.60438729e-01, 6.39203048e-01],
#           [2.67360367e-01, 5.47078362e-01, 9.84836557e-01, ...,
#            3.76049907e-01, 7.57996774e-01, 6.41575641e-01]]],
#
#
#         [[[3.82158408e-01, 4.61272272e-01, 5.63786672e-01, ...,
#            8.70422124e-01, 3.78026489e-01, 4.73425712e-01],
#           [2.73823966e-01, 5.48224532e-01, 9.22435414e-01, ...,
#            3.73709621e-01, 7.84945311e-01, 5.92157018e-01],
#           [1.01975827e-01, 4.90000767e-01, 4.57690765e-01, ...,
#            3.76378056e-01, 4.66453199e-01, 5.99021579e-01],
#           ...,
#           [2.58424748e-01, 5.27269631e-01, 9.20314061e-01, ...,
#            3.74339680e-01, 7.82673711e-01, 6.24223385e-01],
#           [2.76024849e-01, 5.55306555e-01, 9.20784063e-01, ...,
#            3.73984610e-01, 7.76642243e-01, 6.40846553e-01],
#           [2.62374549e-01, 5.55684857e-01, 9.55344675e-01, ...,
#            3.73160438e-01, 7.91863660e-01, 6.52539345e-01]],
#
#          [[2.45755167e-01, 5.46908726e-01, 9.60240450e-01, ...,
#            3.73093243e-01, 8.02614533e-01, 6.22860656e-01],
#           [2.78226708e-01, 5.41446053e-01, 9.31552983e-01, ...,
#            3.73489286e-01, 7.95516397e-01, 5.93069640e-01],
#           [2.40820179e-01, 5.40246992e-01, 9.40281207e-01, ...,
#            3.74282949e-01, 7.86998372e-01, 6.33947854e-01],
#           ...,
#           [2.31718252e-01, 5.57776973e-01, 9.62021729e-01, ...,
#            3.72866664e-01, 8.02312403e-01, 6.87641320e-01],
#           [2.25351945e-01, 5.58610183e-01, 9.83590343e-01, ...,
#            3.72310212e-01, 8.10986311e-01, 6.63383598e-01],
#           [2.43640684e-01, 5.59655513e-01, 9.09830699e-01, ...,
#            3.74585556e-01, 7.71191486e-01, 6.76536888e-01]],
#
#          [[3.04621496e-04, 4.30929384e-01, 6.11587324e-01, ...,
#            3.56818920e-01, 1.43990294e-01, 6.30589559e-01],
#           [2.89642851e-01, 4.84359621e-01, 6.82539674e-01, ...,
#            3.71824361e-01, 4.11295836e-01, 4.33837181e-01],
#           [2.65393642e-01, 5.45873316e-01, 7.76205180e-01, ...,
#            8.66481510e-01, 8.51430720e-01, 5.46015789e-01],
#           ...,
#           [2.37374427e-01, 5.46060502e-01, 9.71647816e-01, ...,
#            3.72858497e-01, 8.05715200e-01, 6.50018310e-01],
#           [2.35798613e-01, 5.45115703e-01, 9.69980343e-01, ...,
#            3.72839265e-01, 8.06092931e-01, 6.49390220e-01],
#           [2.47049105e-01, 5.51521921e-01, 9.54723024e-01, ...,
#            3.73205760e-01, 7.96214201e-01, 6.55341385e-01]],
#
#          ...,
#
#          [[2.48460397e-01, 5.39230591e-01, 9.69010492e-01, ...,
#            3.73512872e-01, 8.06297974e-01, 6.25605092e-01],
#           [4.47914956e-01, 4.57727047e-01, 5.51182184e-01, ...,
#            8.69848672e-01, 3.16876863e-01, 5.00034539e-01],
#           [3.20382901e-01, 5.07054205e-01, 6.38259728e-01, ...,
#            8.57684138e-01, 6.10716114e-01, 4.71235863e-01],
#           ...,
#           [2.91776990e-01, 5.39181426e-01, 9.06035441e-01, ...,
#            3.75109227e-01, 7.58384456e-01, 6.33155709e-01],
#           [2.91776990e-01, 5.39181426e-01, 9.06035441e-01, ...,
#            3.75109227e-01, 7.58384456e-01, 6.33155709e-01],
#           [2.44040894e-01, 5.43415131e-01, 8.80435724e-01, ...,
#            3.74547465e-01, 7.73771479e-01, 6.43261685e-01]],
#
#          [[9.32010261e-02, 5.20925639e-01, 3.65034003e-01, ...,
#            3.81713279e-01, 5.27195390e-01, 6.17521134e-01],
#           [7.26181534e-02, 5.07216849e-01, 3.32324881e-01, ...,
#            3.78102553e-01, 4.70858114e-01, 6.87459044e-01],
#           [1.06521921e-01, 4.96974676e-01, 4.25154993e-01, ...,
#            3.78432504e-01, 4.90708983e-01, 5.79676617e-01],
#           ...,
#           [2.46817253e-01, 5.51803367e-01, 9.90860068e-01, ...,
#            3.73007092e-01, 8.00373409e-01, 6.56197950e-01],
#           [2.47289103e-01, 5.52140408e-01, 9.95261333e-01, ...,
#            3.72975624e-01, 8.00938911e-01, 6.56729043e-01],
#           [2.68452797e-01, 5.51414920e-01, 9.36529778e-01, ...,
#            3.73788297e-01, 7.81635824e-01, 6.44036696e-01]],
#
#          [[2.34894725e-01, 5.39281579e-01, 7.87265468e-01, ...,
#            8.66567964e-01, 8.61736981e-01, 5.57418093e-01],
#           [2.81579887e-01, 5.27474037e-01, 7.44655416e-01, ...,
#            8.62197742e-01, 7.75685331e-01, 5.48899062e-01],
#           [4.94156219e-01, 4.46630776e-01, 5.37971141e-01, ...,
#            8.70401459e-01, 2.77083469e-01, 5.04380253e-01],
#           ...,
#           [4.20666689e-01, 4.54384078e-01, 5.47863852e-01, ...,
#            8.69368221e-01, 2.78763165e-01, 5.06419991e-01],
#           [2.55345206e-01, 5.57506844e-01, 9.30046347e-01, ...,
#            3.73479306e-01, 7.87425322e-01, 6.53705885e-01],
#           [2.27284392e-01, 5.55668536e-01, 9.84115137e-01, ...,
#            3.72640706e-01, 8.06760194e-01, 6.62697842e-01]]],
#
#
#         ...,
#
#
#         [[[5.40931676e-01, 4.51448582e-01, 5.26871423e-01, ...,
#            8.62942718e-01, 2.64750273e-01, 4.86240430e-01],
#           [3.02860865e-01, 5.55800822e-01, 9.21175540e-01, ...,
#            3.75676414e-01, 7.84476604e-01, 5.30579996e-01],
#           [3.06109111e-01, 5.15895124e-01, 6.91744299e-01, ...,
#            8.59287562e-01, 6.59301160e-01, 5.13261704e-01],
#           ...,
#           [1.41323565e-02, 4.80953467e-01, 5.71789413e-01, ...,
#            8.63779979e-01, 5.50274699e-01, 1.58725904e-01],
#           [3.14710092e-02, 4.81165987e-01, 5.67971631e-01, ...,
#            8.63342561e-01, 5.47274703e-01, 1.24690573e-01],
#           [2.93382001e-01, 5.46595879e-01, 9.49398273e-01, ...,
#            3.74170736e-01, 7.78042283e-01, 6.40377602e-01]],
#
#          [[4.89250899e-02, 4.77875085e-01, 5.67517972e-01, ...,
#            3.59905791e-01, 2.11581516e-01, 6.28829602e-01],
#           [2.99894092e-01, 5.31299511e-01, 6.70323537e-01, ...,
#            8.56738456e-01, 6.76027038e-01, 4.76483455e-01],
#           [1.09929874e-01, 4.69717174e-01, 5.90863516e-01, ...,
#            3.70467816e-01, 3.90797754e-01, 5.58140973e-01],
#           ...,
#           [5.07736111e-01, 4.49414230e-01, 5.26457091e-01, ...,
#            8.70523024e-01, 2.28315619e-01, 5.31441490e-01],
#           [5.08098564e-01, 4.49023088e-01, 5.26367433e-01, ...,
#            8.70519449e-01, 2.27337024e-01, 5.32137182e-01],
#           [5.08098564e-01, 4.49023088e-01, 5.26367433e-01, ...,
#            8.70519449e-01, 2.27337024e-01, 5.32137182e-01]],
#
#          [[8.07205662e-02, 5.15836687e-01, 4.17161376e-01, ...,
#            3.70177143e-01, 3.93907002e-01, 5.63639114e-01],
#           [2.53633111e-01, 5.37543278e-01, 9.83136199e-01, ...,
#            3.75084546e-01, 8.05426276e-01, 6.33022088e-01],
#           [4.46838641e-01, 5.03492664e-01, 6.36494215e-01, ...,
#            8.60151680e-01, 5.54795773e-01, 4.73520882e-01],
#           ...,
#           [2.36197753e-01, 5.54891115e-01, 7.97040805e-01, ...,
#            8.72748558e-01, 9.26729794e-01, 5.73758757e-01],
#           [2.36197753e-01, 5.54891115e-01, 7.97040805e-01, ...,
#            8.72748558e-01, 9.26729794e-01, 5.73758757e-01],
#           [2.33158362e-01, 5.54755311e-01, 7.97389736e-01, ...,
#            8.72862863e-01, 9.28017687e-01, 5.72225945e-01]],
#
#          ...,
#
#          [[4.64250341e-01, 4.80079785e-01, 5.84942055e-01, ...,
#            8.62511578e-01, 4.08450782e-01, 5.06981020e-01],
#           [1.45828509e-01, 4.78515322e-01, 7.95043450e-01, ...,
#            8.50712442e-01, 7.51143458e-01, 3.45389713e-01],
#           [6.00181366e-01, 4.84010260e-01, 6.05241108e-01, ...,
#            8.68016940e-01, 3.93204167e-01, 6.04348712e-01],
#           ...,
#           [3.19170456e-01, 5.24972395e-01, 5.26739175e-01, ...,
#            8.67594361e-01, 8.58533199e-01, 1.81586550e-02],
#           [3.16729064e-01, 5.25250880e-01, 5.22791885e-01, ...,
#            8.67553541e-01, 8.57888212e-01, 1.42206463e-02],
#           [3.17185877e-01, 5.25224456e-01, 5.22384649e-01, ...,
#            8.67575411e-01, 8.58218364e-01, 1.26531902e-02]],
#
#          [[4.39078865e-01, 4.53688002e-01, 5.58637653e-01, ...,
#            8.62989003e-01, 2.88975779e-01, 5.06750051e-01],
#           [1.21557071e-01, 5.24112164e-01, 6.67370742e-01, ...,
#            8.60615824e-01, 6.72342945e-01, 4.19104602e-01],
#           [1.56991122e-01, 4.70241110e-01, 6.11199219e-01, ...,
#            3.74433419e-01, 4.55165427e-01, 4.90715326e-01],
#           ...,
#           [3.35332968e-01, 5.23670066e-01, 5.31632458e-01, ...,
#            8.68094088e-01, 8.66992758e-01, 9.84417437e-04],
#           [3.32951903e-01, 5.23422907e-01, 5.31221173e-01, ...,
#            8.68066822e-01, 8.66553710e-01, 1.11444515e-03],
#           [3.32626158e-01, 5.23461082e-01, 5.31133708e-01, ...,
#            8.68054856e-01, 8.66354225e-01, 1.55852921e-03]],
#
#          [[2.35805063e-01, 5.52120764e-01, 9.64629234e-01, ...,
#            3.75920979e-01, 8.00533780e-01, 6.55760632e-01],
#           [2.42988376e-01, 5.22202851e-01, 6.77331391e-01, ...,
#            8.61236814e-01, 6.85350168e-01, 4.67927047e-01],
#           [3.85640023e-01, 4.85515448e-01, 6.33650733e-01, ...,
#            8.64416601e-01, 5.29713732e-01, 4.98636694e-01],
#           ...,
#           [1.35955307e-01, 5.08773921e-01, 3.81291013e-01, ...,
#            3.80486326e-01, 5.16630735e-01, 6.15658387e-01],
#           [1.35955307e-01, 5.08773921e-01, 3.81291013e-01, ...,
#            3.80486326e-01, 5.16630735e-01, 6.15658387e-01],
#           [1.35955307e-01, 5.08773921e-01, 3.81291013e-01, ...,
#            3.80486326e-01, 5.16630735e-01, 6.15658387e-01]]],
#
#
#         [[[5.59155513e-02, 4.85641825e-01, 4.67673861e-01, ...,
#            3.89487026e-01, 4.54323138e-01, 6.94225142e-01],
#           [2.36569556e-01, 5.47305533e-01, 9.65466328e-01, ...,
#            3.73973361e-01, 8.09279248e-01, 6.37600983e-01],
#           [4.50506928e-01, 5.08421816e-01, 6.01124432e-01, ...,
#            8.61202620e-01, 5.15966681e-01, 4.77306410e-01],
#           ...,
#           [2.72620120e-01, 4.67327480e-01, 7.74215921e-01, ...,
#            8.61401939e-01, 6.19885639e-01, 6.35345613e-01],
#           [2.74701752e-01, 4.66863550e-01, 7.74342552e-01, ...,
#            8.61417392e-01, 6.19700448e-01, 6.37161852e-01],
#           [2.74701752e-01, 4.66863550e-01, 7.74342552e-01, ...,
#            8.61417392e-01, 6.19700448e-01, 6.37161852e-01]],
#
#          [[3.84506211e-01, 5.58807896e-01, 6.66433704e-01, ...,
#            8.53296750e-01, 5.79702578e-01, 5.10971083e-01],
#           [2.70066197e-01, 5.42330842e-01, 9.35700839e-01, ...,
#            3.75684446e-01, 8.00370212e-01, 5.78472683e-01],
#           [2.98090459e-01, 5.15522877e-01, 9.08066602e-01, ...,
#            3.76270379e-01, 7.74535686e-01, 5.50365273e-01],
#           ...,
#           [5.17544875e-01, 4.44432789e-01, 5.23732289e-01, ...,
#            8.70536024e-01, 2.17506923e-01, 5.36299934e-01],
#           [5.17544875e-01, 4.44432789e-01, 5.23732289e-01, ...,
#            8.70536024e-01, 2.17506923e-01, 5.36299934e-01],
#           [5.17544875e-01, 4.44432789e-01, 5.23732289e-01, ...,
#            8.70536024e-01, 2.17506923e-01, 5.36299934e-01]],
#
#          [[3.52227308e-01, 5.18481627e-01, 6.61777183e-01, ...,
#            8.48326676e-01, 6.07478696e-01, 5.11835092e-01],
#           [3.07024444e-01, 5.30345773e-01, 9.24474912e-01, ...,
#            3.77310710e-01, 7.79046722e-01, 5.47577766e-01],
#           [2.56328297e-01, 5.48439571e-01, 9.63963185e-01, ...,
#            3.74478162e-01, 8.06220365e-01, 6.22114228e-01],
#           ...,
#           [2.70601205e-01, 4.67317740e-01, 7.76997964e-01, ...,
#            8.61478437e-01, 6.19765753e-01, 6.36523319e-01],
#           [2.72022511e-01, 4.66916783e-01, 7.77047079e-01, ...,
#            8.61485489e-01, 6.19464200e-01, 6.37672538e-01],
#           [2.71359476e-01, 4.67090027e-01, 7.77346637e-01, ...,
#            8.61489287e-01, 6.19641875e-01, 6.37372761e-01]],
#
#          ...,
#
#          [[4.12122883e-01, 4.69552997e-01, 5.94854213e-01, ...,
#            8.58853317e-01, 3.65710093e-01, 5.37833782e-01],
#           [2.51078613e-01, 5.46675808e-01, 9.47782508e-01, ...,
#            3.74761400e-01, 7.97903265e-01, 6.29614684e-01],
#           [9.20454764e-02, 4.68699275e-01, 5.92348263e-01, ...,
#            3.67444563e-01, 3.47600144e-01, 5.59386438e-01],
#           ...,
#           [1.75187016e-01, 4.86806102e-01, 7.89948687e-01, ...,
#            8.60592567e-01, 6.81363916e-01, 5.75706730e-01],
#           [1.59393582e-01, 4.88094928e-01, 7.93288663e-01, ...,
#            8.60790069e-01, 6.81200561e-01, 5.73036235e-01],
#           [1.59323021e-01, 4.88122255e-01, 7.93317256e-01, ...,
#            8.60792152e-01, 6.81124018e-01, 5.73007668e-01]],
#
#          [[2.72616732e-01, 5.46149874e-01, 9.42270144e-01, ...,
#            3.73183182e-01, 7.95572314e-01, 6.22576463e-01],
#           [3.29192584e-01, 5.22477296e-01, 6.51480593e-01, ...,
#            8.55872839e-01, 6.56328059e-01, 4.77069512e-01],
#           [1.17985651e-01, 4.77758534e-01, 5.90946658e-01, ...,
#            3.71381655e-01, 4.07443708e-01, 5.23972558e-01],
#           ...,
#           [2.70455185e-01, 4.67701074e-01, 7.75849087e-01, ...,
#            8.61436373e-01, 6.20080230e-01, 6.34942403e-01],
#           [2.70455185e-01, 4.67701074e-01, 7.75849087e-01, ...,
#            8.61436373e-01, 6.20080230e-01, 6.34942403e-01],
#           [2.73232330e-01, 4.66929389e-01, 7.76425891e-01, ...,
#            8.61464394e-01, 6.20598456e-01, 6.38122459e-01]],
#
#          [[4.52256275e-01, 4.53265147e-01, 5.60746775e-01, ...,
#            8.60401636e-01, 3.04709691e-01, 5.08321992e-01],
#           [3.14783669e-01, 4.91729343e-01, 8.78280000e-01, ...,
#            3.76684088e-01, 7.65374074e-01, 5.27064332e-01],
#           [2.61474334e-01, 5.44139313e-01, 9.47787123e-01, ...,
#            3.74785792e-01, 8.00313411e-01, 6.04535653e-01],
#           ...,
#           [5.35805855e-01, 4.34172862e-01, 5.37863541e-01, ...,
#            8.70809311e-01, 2.98907273e-01, 4.89913210e-01],
#           [5.35638193e-01, 4.34192472e-01, 5.37878698e-01, ...,
#            8.70806989e-01, 2.98878113e-01, 4.89962212e-01],
#           [5.35638193e-01, 4.34192472e-01, 5.37878698e-01, ...,
#            8.70806989e-01, 2.98878113e-01, 4.89962212e-01]]],
#
#
#         [[[3.60775967e-01, 4.97904965e-01, 6.45320150e-01, ...,
#            8.50912131e-01, 5.87036322e-01, 5.42035970e-01],
#           [1.65162292e-01, 4.82779440e-01, 8.52396780e-01, ...,
#            8.59569976e-01, 8.03811594e-01, 4.43971197e-01],
#           [1.32143378e-01, 4.77475279e-01, 5.85643579e-01, ...,
#            3.78879179e-01, 5.00811453e-01, 5.21476252e-01],
#           ...,
#           [1.20889132e-01, 4.86915632e-01, 6.59224403e-01, ...,
#            8.53328303e-01, 6.87702793e-01, 1.49374766e-01],
#           [2.14165287e-01, 5.42174816e-01, 8.25839963e-01, ...,
#            3.70959538e-01, 8.39509279e-01, 4.24194570e-01],
#           [2.14165287e-01, 5.42174816e-01, 8.25839963e-01, ...,
#            3.70959538e-01, 8.39509279e-01, 4.24194570e-01]],
#
#          [[1.19966785e-01, 4.83950372e-01, 4.75817553e-01, ...,
#            3.86287277e-01, 6.21330190e-01, 6.34984338e-01],
#           [9.56706714e-02, 4.77029083e-01, 5.37623072e-01, ...,
#            3.78931222e-01, 4.51535654e-01, 6.21148876e-01],
#           [5.10124581e-01, 4.86187499e-01, 6.48998090e-01, ...,
#            8.56229650e-01, 5.65297696e-01, 4.77626961e-01],
#           ...,
#           [1.32156441e-02, 5.25964088e-01, 2.59306278e-01, ...,
#            3.77730548e-01, 4.70198412e-01, 8.38080692e-01],
#           [1.24817289e-02, 5.26543716e-01, 2.57062558e-01, ...,
#            3.77761462e-01, 4.70360473e-01, 8.41199913e-01],
#           [1.53600414e-02, 5.24289678e-01, 2.67327193e-01, ...,
#            3.77676641e-01, 4.70306333e-01, 8.28802851e-01]],
#
#          [[2.90648864e-01, 5.22993816e-01, 7.17136023e-01, ...,
#            8.33191908e-01, 6.64638077e-01, 5.52842616e-01],
#           [4.22614753e-01, 4.80837870e-01, 5.93328396e-01, ...,
#            8.60905966e-01, 4.33679859e-01, 4.78617445e-01],
#           [2.29062301e-01, 5.49305422e-01, 9.69815627e-01, ...,
#            3.72468738e-01, 8.14437076e-01, 6.81243733e-01],
#           ...,
#           [3.74378878e-01, 5.59518280e-01, 7.66662858e-01, ...,
#            3.68674560e-01, 8.91079499e-01, 1.37921214e-01],
#           [3.74378878e-01, 5.59518280e-01, 7.66662858e-01, ...,
#            3.68674560e-01, 8.91079499e-01, 1.37921214e-01],
#           [3.74378878e-01, 5.59518280e-01, 7.66662858e-01, ...,
#            3.68674560e-01, 8.91079499e-01, 1.37921214e-01]],
#
#          ...,
#
#          [[3.28783331e-01, 5.60548257e-01, 7.09861939e-01, ...,
#            8.43947090e-01, 6.84668379e-01, 5.21176133e-01],
#           [8.29579805e-02, 4.68261309e-01, 6.18309114e-01, ...,
#            3.63620657e-01, 2.57412392e-01, 5.77102755e-01],
#           [8.26607898e-02, 4.76171937e-01, 5.29643958e-01, ...,
#            3.72174612e-01, 3.68297064e-01, 6.36663384e-01],
#           ...,
#           [1.57609721e-02, 5.22103982e-01, 2.73691759e-01, ...,
#            3.77671442e-01, 4.70769239e-01, 8.22353201e-01],
#           [1.55781653e-02, 5.22249976e-01, 2.73009836e-01, ...,
#            3.77676622e-01, 4.70766646e-01, 8.23166552e-01],
#           [1.24152931e-02, 5.24493409e-01, 2.69325085e-01, ...,
#            3.77836971e-01, 4.72604610e-01, 8.31228303e-01]],
#
#          [[2.53664821e-01, 5.62358876e-01, 9.34873585e-01, ...,
#            3.65658904e-01, 7.80084204e-01, 5.90050430e-01],
#           [7.33014333e-02, 4.75156657e-01, 5.40676907e-01, ...,
#            3.71000730e-01, 3.45736309e-01, 6.12523444e-01],
#           [1.49478989e-01, 5.09405991e-01, 6.78245161e-01, ...,
#            8.57675235e-01, 7.85642628e-01, 1.35860579e-01],
#           ...,
#           [1.70033555e-01, 4.73221261e-01, 6.41367058e-01, ...,
#            3.78363300e-01, 6.76014593e-01, 1.73411199e-01],
#           [1.70033555e-01, 4.73221261e-01, 6.41367058e-01, ...,
#            3.78363300e-01, 6.76014593e-01, 1.73411199e-01],
#           [1.70033555e-01, 4.73221261e-01, 6.41367058e-01, ...,
#            3.78363300e-01, 6.76014593e-01, 1.73411199e-01]],
#
#          [[2.40286875e-01, 4.87910207e-01, 5.65703519e-01, ...,
#            4.04016254e-01, 5.64672629e-01, 5.39935270e-01],
#           [4.87646432e-02, 4.74452095e-01, 4.95898320e-01, ...,
#            3.67776399e-01, 2.89649928e-01, 6.86580496e-01],
#           [2.83183443e-01, 5.21391387e-01, 9.29340284e-01, ...,
#            3.75952018e-01, 7.83453848e-01, 5.77456138e-01],
#           ...,
#           [3.28912287e-02, 4.38768752e-01, 6.06183443e-01, ...,
#            3.56080995e-01, 1.74090483e-01, 6.33124110e-01],
#           [3.28912287e-02, 4.38768752e-01, 6.06183443e-01, ...,
#            3.56080995e-01, 1.74090483e-01, 6.33124110e-01],
#           [3.28912287e-02, 4.38768752e-01, 6.06183443e-01, ...,
#            3.56080995e-01, 1.74090483e-01, 6.33124110e-01]]]]),
#  'COL_NAMES': 'mass1  period1  ecc1  inclination1  argument1  mean_anomaly1  mass2  period2  ecc2  inclination2  argument2  mean_anomaly2  ascending_node2',
#  'CORES': array([8]),
#  'INDEX': array([59]),
#  'INTRA_STEPS': array([50]),
#  'ITER_LAST': array([3000]),
#  'ITMAX': array([3000]),
#  'MEANLOGL': array([-1.55138870e+04, -1.44432375e+01,  2.29421013e+02,  2.82775151e+02,
#          2.92572223e+02,  2.94424138e+02,  2.96375861e+02,  3.01676708e+02,
#          3.06941904e+02,  3.11348061e+02,  3.17248400e+02,  3.20137623e+02,
#          3.25270824e+02,  3.29171162e+02,  3.32495907e+02,  3.33541923e+02,
#          3.34858797e+02,  3.35794018e+02,  3.37177032e+02,  3.38659770e+02,
#          3.38860339e+02,  3.39791423e+02,  3.41039977e+02,  3.41981186e+02,
#          3.42738924e+02,  3.43048779e+02,  3.42729310e+02,  3.44007802e+02,
#          3.43946536e+02,  3.44536626e+02,  3.45594002e+02,  3.45748795e+02,
#          3.47074107e+02,  3.47400663e+02,  3.47970748e+02,  3.49769881e+02,
#          3.50177379e+02,  3.51226343e+02,  3.51751518e+02,  3.53199962e+02,
#          3.54014931e+02,  3.54676377e+02,  3.54587581e+02,  3.55966050e+02,
#          3.57360682e+02,  3.57882098e+02,  3.58814097e+02,  3.58827929e+02,
#          3.59167328e+02,  3.59468104e+02,  3.60372960e+02,  3.61452025e+02,
#          3.62031342e+02,  3.63033597e+02,  3.63371853e+02,  3.64224608e+02,
#          3.64767838e+02,  3.65792625e+02,  3.66344466e+02,  3.66895381e+02]),
#  'MSTAR': array([0.9132]),
#  'NAME': 'SystemX',
#  'NDIM': array([13]),
#  'NPLA': array([2]),
#  'NTEMPS': array([8]),
#  'NWALKERS': array([100]),
#  'REF_EPOCH': array([0]),
#  'RSTAR': array([0.8632]),
#  'p0': array([[[0.22687075, 0.58001579, 0.96066522, ..., 0.35915864,
#           0.80808025, 0.7048657 ],
#          [0.38588563, 0.4490815 , 0.55356219, ..., 0.84283633,
#           0.29292975, 0.51436711],
#          [0.19424508, 0.58581311, 0.999893  , ..., 0.37494783,
#           0.80206257, 0.71145919],
#          ...,
#          [0.21294865, 0.57273046, 0.98023919, ..., 0.3716435 ,
#           0.78350681, 0.70894834],
#          [0.39430039, 0.4273135 , 0.59965839, ..., 0.85722581,
#           0.30388046, 0.55517061],
#          [0.26704834, 0.51932037, 0.98213521, ..., 0.37587743,
#           0.80648635, 0.61110413]],
#
#         [[0.27002676, 0.57926444, 0.77611811, ..., 0.86522903,
#           0.87683858, 0.58818956],
#          [0.27409471, 0.47160757, 0.92094428, ..., 0.340068  ,
#           0.82304624, 0.65341971],
#          [0.27632533, 0.483088  , 0.96187726, ..., 0.42548597,
#           0.80989421, 0.58324891],
#          ...,
#          [0.23899802, 0.51104077, 0.98751116, ..., 0.40828227,
#           0.77177322, 0.63087572],
#          [0.26147167, 0.51419078, 0.98653542, ..., 0.40288878,
#           0.82742778, 0.63446748],
#          [0.25500111, 0.55158141, 0.92905046, ..., 0.41231262,
#           0.77399384, 0.56704178]],
#
#         [[0.19967361, 0.55888079, 0.81761367, ..., 0.87622878,
#           0.93797401, 0.57273308],
#          [0.44010713, 0.47924504, 0.57102492, ..., 0.81489428,
#           0.30502305, 0.55813284],
#          [0.21758776, 0.51944503, 0.82380744, ..., 0.8234001 ,
#           0.94158328, 0.56869327],
#          ...,
#          [0.37741794, 0.4464562 , 0.53363188, ..., 0.83805487,
#           0.30315645, 0.54199514],
#          [0.24839178, 0.53642133, 0.96323661, ..., 0.36099522,
#           0.81934552, 0.62682827],
#          [0.405728  , 0.4622144 , 0.5904073 , ..., 0.82775888,
#           0.34713584, 0.5119043 ]],
#
#         ...,
#
#         [[0.23606128, 0.47881289, 0.71830101, ..., 0.39451784,
#           0.79590906, 0.00393662],
#          [0.21512715, 0.56360044, 0.7875622 , ..., 0.83664316,
#           0.91162691, 0.56660914],
#          [0.29295396, 0.48995072, 0.95347951, ..., 0.35114307,
#           0.81333142, 0.61406136],
#          ...,
#          [0.86924447, 0.46130554, 0.36660856, ..., 0.87700088,
#           0.10753476, 0.35237033],
#          [0.87738498, 0.43531113, 0.40456299, ..., 0.8615459 ,
#           0.10167626, 0.37352151],
#          [0.19339987, 0.58445777, 0.99813134, ..., 0.37271181,
#           0.80048919, 0.71306678]],
#
#         [[0.03626568, 0.38258729, 0.7427933 , ..., 0.349226  ,
#           0.94874949, 0.48404565],
#          [0.00702884, 0.42765992, 0.6041723 , ..., 0.36510264,
#           0.14532713, 0.63694166],
#          [0.21895887, 0.52868074, 0.64143721, ..., 0.85364736,
#           0.98588243, 0.01186412],
#          ...,
#          [0.4301244 , 0.42946605, 0.57615908, ..., 0.80826509,
#           0.34641999, 0.4896773 ],
#          [0.1127039 , 0.55955124, 0.26552837, ..., 0.39072416,
#           0.49214151, 0.58961049],
#          [0.41066169, 0.45310413, 0.57413564, ..., 0.85459514,
#           0.30595965, 0.51543714]],
#
#         [[0.26415337, 0.48925873, 0.37262393, ..., 0.84029808,
#           0.46450113, 0.1449769 ],
#          [0.29192743, 0.50021346, 0.36413766, ..., 0.83774726,
#           0.48405782, 0.15278759],
#          [0.39290812, 0.56255759, 0.73067176, ..., 0.36810106,
#           0.90254745, 0.06129997],
#          ...,
#          [0.1264005 , 0.53484228, 0.31215702, ..., 0.40649632,
#           0.51104397, 0.59492185],
#          [0.05126576, 0.41083835, 0.74652471, ..., 0.35377241,
#           0.92055301, 0.47638257],
#          [0.43674413, 0.53260221, 0.21366686, ..., 0.37155418,
#           0.95322465, 0.00113749]]])}

# %% [markdown]
# If you want just specific results from the hdf5 file, pass a list with the keyword names through the -keywords- argument in get_mcmc_results().
#
# Not all the attributes in RESULTS_mcmc are stored in the .hdf5 file (ie., in the results_hdf5 variable) but just those necessary to analize the MCMC performance and many properties of the planetary system.
#
# Let's access, for example, to the mean autocorrelation of the chains:

# %%
results_hdf5['AUTOCORR']
# Out:
# array([0.3079096 , 0.59139071, 0.84983699, 1.0815648 , 1.28559981,
#        1.46051853, 1.60425993, 1.71516923, 1.7923346 , 1.83353647,
#        1.83634965, 1.83887313, 1.84122802, 1.84380862, 1.84666289,
#        1.84953198, 1.85195172, 1.85428547, 1.85679179, 1.85941661,
#        1.86208956, 1.8649575 , 1.86798827, 1.87112364, 1.87438403,
#        1.87769455, 1.88110731, 1.88461715, 1.88833782, 1.89227452,
#        1.89636802, 1.9004975 , 1.90484   , 1.90933287, 1.91420016,
#        1.91937041, 1.92481208, 1.93052239, 1.93658744, 1.94294688,
#        1.94975157, 1.95730589, 1.96559304, 1.97469869, 1.98474681,
#        1.9960125 , 2.0085902 , 2.02290368, 2.03905143, 2.05808097,
#        2.03548232, 1.97335339, 1.87391742, 1.73970129, 1.57272649,
#        1.37570598, 1.15282441, 0.91274838, 0.68581301, 0.91840757])

# %% [markdown]
# ### 4.3.1 Visualization

# %% [markdown]
# An easy way of looking into the results is generating descriptive figures using the 'Plots' module.

# %%
# Instantiate the Plots module

nauplot = nau.Plots(PS, hdf5_file=f'{PS.system_name}.hdf5', burnin=burn)

# %% [markdown]
# **MCMC performance**
#
# We can take a look into the MCMC performance

# %%
nauplot.plot_monitor()

# %% [markdown]
# It shows the movement of the adaptive temperatures, the swap between walkers of different temperatures, the Mean log likelihood and the Maximum log likelihood, and the mean autocorrelation time.

# %% [markdown]
# **Histograms**
#
# Take a look into the posterior distributions, and set as titles the median and errors within $1-\sigma$

# %%
nauplot.plot_hist(titles=True)

# %% [markdown]
# **Chains**
#
# If you are interested in visualizing the chains movement, use the  'plot_chains' method:

# %%
nauplot.plot_chains(plot_means=True)  # Plot the mean movement of the chains as black lines

# %% [markdown]
# **Corner plot**
#
# And now a corner plot to visualize possible correlations between variables

# %%
nauplot.plot_corner(color='blue', titles=True)

# %% [markdown]
# **TTVs**
#
# In order to visualize the TTVs that the posteriors represent, use the function 'plot_TTVs'. It takes solutions from the MCMC chains to calculate the mid-transit times and the resulting TTVs. Two modes are available: mode 'random' take random samples from the chains; 'best' take the best solutions from the chains until complete -nsols-.

# %%
nauplot.plot_TTVs(mode='random',  # Take random samples from the posteriors.
                  nsols=10)       # Number of solutions to draw
plt.savefig('TTVs_mcmc.png')
# Out:
# E3
# random

# %% [markdown]
# That's a much better fitting than the done before with the optimizers in the previous tutorial. Compare yourself both images!

# %% [markdown]
# **At this point, we have seen how the MCMC module works. We also see the fast way of getting the results and how visualize them. If you are interested in going further in Nauyaca, the next tutorial will show all that extra features in the modules. See you there!**

# %% [markdown]
# _______________
